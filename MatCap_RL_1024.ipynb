# %% [markdown]
# # Matrix Capsule Network for RL

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import cv2
import sys
import pong_fun as game # whichever is imported "as game" will be used
import random
import time 
import numpy as np
from collections import deque
# Out:
# /home/cn1lab005/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Parameters for the MatrixNet

# %%
iter_routing = 2
ac_lambda0 = 0.01, 
#'\lambda in the activation function a_c, iteration 0')
ac_lambda_step = 0.01,
#'It is described that \lambda increases at each iteration with a fixed schedule, however specific super parameters is absent.')
epsilon = 1e-9

################################
A = 32 # , 'number of channels in output from ReLU Conv1')
B = 8 # , 'number of capsules in output from PrimaryCaps')
C = 16 #, 'number of channels in output from ConvCaps1')
D = 16 # , 'number of channels in output from ConvCaps2')
is_train = True
num_classes = 10
train_freq = 10

# %% [markdown]
# # Parameters for the Agent

# %%
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 500. # timesteps to observe before training
EXPLORE = 5000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.05 # final value of epsilon
INITIAL_EPSILON = 1.0 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
step-85 loss= 2.2954699993133545, train_accuracy= 10.0, test_acc= 13.333333969116211
step-90 loss= 2.2949106693267822, train_accuracy= 12.0, test_acc= 6.6666669845581055
step-95 loss= 2.2778632640838623, train_accuracy= 10.0, test_acc= 20.0
step-100 loss= 2.258962631225586, train_accuracy= 16.0, test_acc= 13.333333969116211
step-105 loss= 2.262554883956909, train_accuracy= 22.0, test_acc= 20.0
step-110 loss= 2.2702789306640625, train_accuracy= 22.0, test_acc= 26.666667938232422
BATCH = 32 # size of minibatch
batch_size = BATCH

# %% [markdown]
# # Function for the MatrixNet

# %%
def kernel_tile(input, kernel, stride):
    # output = tf.extract_image_patches(input, ksizes=[1, kernel, kernel, 1], strides=[1, stride, stride, 1], rates=[1, 1, 1, 1], padding='VALID')

    input_shape = input.get_shape()
    tile_filter = np.zeros(shape=[kernel, kernel, input_shape[3],
                                  kernel * kernel], dtype=np.float32)
    for i in range(kernel):
        for j in range(kernel):
            tile_filter[i, j, :, i * kernel + j] = 1.0

    tile_filter_op = tf.constant(tile_filter, dtype=tf.float32)
    output = tf.nn.depthwise_conv2d(input, tile_filter_op, strides=[
                                    1, stride, stride, 1], padding='VALID')
    output_shape = output.get_shape()
    output = tf.reshape(output, shape=[-1, int( # -1== int(output_shape[0])
        output_shape[1]), int(output_shape[2]), int(input_shape[3]), kernel * kernel])
    #print(output.get_shape(),"fdsggs")
    output = tf.transpose(output, perm=[0, 1, 2, 4, 3])

    return output

# input should be a tensor with size as [batch_size, caps_num_i, 16]
def mat_transform(input, caps_num_c, regularizer, bs):
    #batch_size = input.get_shape()[0]
    caps_num_i = int(input.get_shape()[1])
    output = tf.reshape(input, shape=[-1, caps_num_i, 1, 4, 4])# batch_size = -1
    # the output of capsule is miu, the mean of a Gaussian, and activation, the sum of probabilities
    # it has no relationship with the absolute values of w and votes
    # using weights with bigger stddev helps numerical stability
    w = slim.variable('w', shape=[1, caps_num_i, caps_num_c, 4, 4], dtype=tf.float32,
                      initializer=tf.truncated_normal_initializer(mean=0.0, stddev=1.0),
                      regularizer=regularizer)
    #print("w",w.get_shape())
    with tf.variable_scope('tile___1'):
        w = tf.tile(w, [bs, 1, 1, 1, 1])
    #print("w",w.get_shape())
    with tf.variable_scope('tile___2'):
        output = tf.tile(output, [1, 1, caps_num_c, 1, 1])
    with tf.variable_scope('tile___3'):
        k = tf.matmul(output, w)
        votes = tf.reshape(k, [-1, caps_num_i, caps_num_c, 16]) #batch_size = -1
    #votes = tf.reshape(tf.matmul(output, w), [batch_size, caps_num_i, caps_num_c, 16])

    return votes

# %%
def em_routing(votes, activation, caps_num_c, regularizer, r_in):
    test = []

    #batch_size = votes.get_shape()[0]
    caps_num_i = int(activation.get_shape()[1])
    n_channels = int(votes.get_shape()[-1])

    sigma_square = []
    miu = []
    activation_out = []
    beta_v = slim.variable('beta_v', shape=[caps_num_c, n_channels], dtype=tf.float32,
                           initializer=tf.constant_initializer(0.0),#tf.truncated_normal_initializer(mean=0.0, stddev=0.01),
                           regularizer=regularizer)
    beta_a = slim.variable('beta_a', shape=[caps_num_c], dtype=tf.float32,
                           initializer=tf.constant_initializer(0.0),#tf.truncated_normal_initializer(mean=0.0, stddev=0.01),
                           regularizer=regularizer)

    # votes_in = tf.stop_gradient(votes, name='stop_gradient_votes')
    # activation_in = tf.stop_gradient(activation, name='stop_gradient_activation')
    votes_in = votes
    #print(votes_in,' = votes')
    activation_in = activation

    for iters in range(iter_routing):
        # if iters == cfg.iter_routing-1:

        # e-step
        if iters == 0:
            r = r_in# tf.constant(np.ones([batch_size, caps_num_i, caps_num_c], dtype=np.float32) / caps_num_c)
            #print(r.get_shape(),"r shape__________")
        else:
            # Contributor: Yunzhi Shi
            # log and exp here provide higher numerical stability especially for bigger number of iterations
            log_p_c_h = -tf.log(tf.sqrt(sigma_square)) - \
                        (tf.square(votes_in - miu) / (2 * sigma_square))
            log_p_c_h = log_p_c_h - \
                        (tf.reduce_max(log_p_c_h, axis=[2, 3], keep_dims=True) - tf.log(10.0))
            p_c = tf.exp(tf.reduce_sum(log_p_c_h, axis=3))

            ap = p_c * tf.reshape(activation_out, shape=[-1, 1, caps_num_c]) # batch_size
            #print(ap.get_shape(),"ap")
            # ap = tf.reshape(activation_out, shape=[batch_size, 1, caps_num_c])

            r = ap / (tf.reduce_sum(ap, axis=2, keepdims=True) + epsilon)

        # m-step
        r = r * activation_in
        r = r / (tf.reduce_sum(r, axis=2, keepdims=True)+epsilon)

        r_sum = tf.reduce_sum(r, axis=1, keepdims=True)
        r1 = tf.reshape(r / (r_sum + epsilon),
                        shape=[-1 , caps_num_i, caps_num_c, 1]) # batch_size
        #print(r1.get_shape(),"r1")
        miu = tf.reduce_sum(votes_in * r1, axis=1, keepdims=True)
        sigma_square = tf.reduce_sum(tf.square(votes_in - miu) * r1,
                                     axis=1, keepdims=True) + epsilon

        if iters == iter_routing-1:
            r_sum = tf.reshape(r_sum, [-1, caps_num_c, 1])  # batch_size
            #print(r_sum.get_shape(),"r_sum")
            cost_h = (beta_v + tf.log(tf.sqrt(tf.reshape(sigma_square,
                                                         shape=[-1, caps_num_c, n_channels])))) * r_sum
            #print(cost_h.get_shape(),"cost_h") # batch_size
            activation_out = tf.nn.softmax(ac_lambda0 * (beta_a - tf.reduce_sum(cost_h, axis=2)))
        else:
            activation_out = tf.nn.softmax(r_sum)
        # if iters <= cfg.iter_routing-1:
        #     activation_out = tf.stop_gradient(activation_out, name='stop_gradient_activation')

    return miu, activation_out, test

# %%
def get_coord_add(dataset_name: str):
    # TODO: get coord add for cifar10/100 datasets (32x32x3)
    options = {'mnist': ([[[8., 8.], [12., 8.], [16., 8.]],
                          [[8., 12.], [12., 12.], [16., 12.]],
                          [[8., 16.], [12., 16.], [16., 16.]]], 28.),
               'smallNORB': ([[[8., 8.], [12., 8.], [16., 8.], [24., 8.]],
                              [[8., 12.], [12., 12.], [16., 12.], [24., 12.]],
                              [[8., 16.], [12., 16.], [16., 16.], [24., 16.]],
                              [[8., 24.], [12., 24.], [16., 24.], [24., 24.]]], 32.)
               }
    coord_add, scale = options[dataset_name]

    coord_add = np.array(coord_add, dtype=np.float32) / scale

    return coord_add

# %% [markdown]
# # Agent for the MatCap DON

# %%
def createNetwork():
    # -------------------------------------------------------------------------------------
    s = tf.placeholder(tf.float32, shape=(None, 80, 80, 4), name='X')
    bs = tf.placeholder(tf.int32, shape=(), name='bs')
    #bs = batch_size
    r_conv_caps1= tf.placeholder(tf.float32,[None, 72, C], name='r_conv_caps1') # 5*5*batch_size
    #r_conv_caps1= tf.placeholder(tf.float32,[5*5*batch_size, 72, C], name='r_conv_caps1') # 5*5*batch_size

    r_conv_caps2 = tf.placeholder(tf.float32,[None, 144, D], name='r_conv_caps2') # 3*3*batch_size
    #r_conv_caps2 = tf.placeholder(tf.float32,[3*3*batch_size, 144, D], name='r_conv_caps2') # 3*3*batch_size

    r_class_caps = tf.placeholder(tf.float32,[None, 16, num_classes], name='r_class_caps') # 3*3*batch_size
    #r_class_caps = tf.placeholder(tf.float32,[3*3*batch_size, 16, num_classes], name='r_class_caps') # 3*3*batch_size

    #coord_add_op_class_caps  = tf.placeholder(tf.float32,[3*3*batch_size, 16, num_classes, 2], name='coord_add_op_class_caps')
                                                                     # 3*3*batch_size
    coord_add_op_class_caps  = tf.placeholder(tf.float32,[None, 16, num_classes, 2], name='coord_add_op_class_caps')
    # 3*3*batch_size
    # -------------------------------------------------------------------------------------
    data_size = int(s.get_shape()[1])
    # xavier initialization is necessary here to provide higher stability
    initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)
    # instead of initializing bias with constant 0, 
    # a truncated normal initializer is exploited here for higher stability 
    bias_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)  # tf.constant_initializer(0.0)
    # The paper didnot mention any regularization, a common l2 regularizer to weights is added here
    weights_regularizer = tf.contrib.layers.l2_regularizer(5e-04)
    # weights_initializer=initializer,
    with slim.arg_scope([slim.conv2d], trainable=is_train, biases_initializer=bias_initializer, weights_regularizer=weights_regularizer):
        with tf.variable_scope('relu_conv1'):
            output = slim.conv2d(s, num_outputs=A, kernel_size=[10, 10], stride=6, padding='VALID', scope='relu_conv1', activation_fn=tf.nn.relu)
            data_size = int(np.floor((data_size - 10) / 6)) + 1
            #print(output.get_shape())
            #print(data_size)
            #assert output.get_shape() == [batch_size, data_size, data_size, 32]
            votes__1 = output
        with tf.variable_scope('primary_caps'):
            pose = slim.conv2d(output, num_outputs=B * 16,kernel_size=[1, 1], stride=1, padding='VALID', scope='primary_caps', activation_fn=None)
            activation = slim.conv2d(output, num_outputs=B, kernel_size=[
                                     1, 1], stride=1, padding='VALID', scope='primary_caps/activation', activation_fn=tf.nn.sigmoid)
            pose = tf.reshape(pose, shape=[-1, data_size, data_size, B, 16]) # (50, 12, 12, 8, 16)

            #print(pose.get_shape())
            activation = tf.reshape(activation, shape=[-1, data_size, data_size, B, 1]) # (50, 12, 12, 8, 1)
            #print(activation.get_shape())
            output = tf.concat([pose, activation], axis=4)
            output = tf.reshape(output, shape=[-1, data_size, data_size, B * 17]) # (50, 12, 12, 136)
            #print(output.get_shape())

            #assert output.get_shape() == [batch_size, data_size, data_size, B * 17]
        with tf.variable_scope('conv_caps1') as scope:
            output = kernel_tile(output, 3, 2)
            data_size = int(np.floor((data_size - 2) / 2))
            #print(data_size) # 5 
            output = tf.reshape(output, shape=[-1, 3 * 3 * B, 17]) 
            # batch_size * data_size * data_size  (1250, 72, 17) 
            #print("1",output.get_shape())
            activation = tf.reshape(output[:, :, 16], shape=[-1, 3 * 3 * B, 1])
            #print("output shape ---------------",output.get_shape())
            #print("activation shape----------------------",activation.get_shape()) #  (1250, 72, 1)

            with tf.variable_scope('v') as scope:
                votes = mat_transform(output[:, :, :16], C, weights_regularizer, bs = bs*data_size*data_size)
                #bs*data_size*data_size)

                #print(votes.get_shape(),"votes shape")
            with tf.variable_scope('routing') as scope:
                caps_num_i = int(activation.get_shape()[1])

                miu, activation, _ = em_routing(votes, activation, C, weights_regularizer,r_conv_caps1)
                # miu, activation, _ = em_routing(votes, activation, C, weights_regularizer)
                #print("activation",activation.get_shape())
            pose = tf.reshape(miu, shape=[-1, data_size, data_size, C, 16])
            #print("3",pose.get_shape()) # 50, 5, 5, 16, 16)
            activation = tf.reshape(activation, shape=[-1, data_size, data_size, C, 1])
            #print("activation",activation.get_shape())
            cat_size =  activation.get_shape()[3]*activation.get_shape()[4] + pose.get_shape()[3] *pose.get_shape()[4]
            #print(cat_size)
            output = tf.reshape(tf.concat([pose, activation], axis=4),[-1, data_size, data_size, cat_size])
            #print("5",output.get_shape()) # (50, 5, 5, 272)


        with tf.variable_scope('conv_caps2') as scope:
            output = kernel_tile(output, 3, 1)

            data_size = int(np.floor((data_size - 2) / 1))

            output = tf.reshape(output, shape=[-1, 3 * 3 * C, 17]) # batch_size * data_size * data_size
            #print("canv_caps2",output.get_shape(), data_size)
            activation = tf.reshape(output[:, :, 16], shape=[-1 , 3 * 3 * C, 1]) # batch_size * data_size * data_size
            #print("canv_caps2_activation",activation.get_shape(), data_size)

            with tf.variable_scope('v') as scope:
                votes = mat_transform(output[:, :, :16], D, weights_regularizer,bs = bs*data_size*data_size)
                #print(votes.get_shape(),"votes shape")

            with tf.variable_scope('routing') as scope:
                caps_num_i = int(activation.get_shape()[1])
                #print(caps_num_i,"for 1")
                miu, activation, _ = em_routing(votes, activation, D, weights_regularizer, r_conv_caps2)

            pose = tf.reshape(miu, shape=[-1, D, 16]) # batch_size * data_size * data_size
            #print("4",pose.get_shape())
            #tf.logging.info('conv cap 2 pose shape: {}'.format(votes.get_shape()))
            activation = tf.reshape(activation, shape=[-1, D, 1]) # batch_size * data_size * data_size
            #print("4 ---activation",activation.get_shape())

        with tf.variable_scope('class_caps') as scope:
            with tf.variable_scope('v') as scope:
                votes = mat_transform(pose, num_classes, weights_regularizer,bs = bs*data_size*data_size)
                #print(votes.get_shape(),"votes.getshape")
                #assert votes.get_shape()[1:] == [D, num_classes, 16]
                #tf.logging.info('class cap votes original shape: {}'.format(votes.get_shape()))
                '''coord_add = get_coord_add('mnist') 
                coord_add = np.reshape(coord_add, newshape=[data_size * data_size, 1, 1, 2])
                coord_add = np.tile(coord_add, [bs, D, num_classes, 1])
                coord_add_op = tf.constant(coord_add, dtype=tf.float32)
                print("___coord_add______",coord_add_op.shape)'''

                votes = tf.concat([coord_add_op_class_caps, votes], axis=3)
                #tf.logging.info('class cap votes coord add shape: {}'.format(votes.get_shape()))
                #print(votes.get_shape(),"coorr vote shape after  jnbfv")
            with tf.variable_scope('routing') as scope:
                caps_num_i = int(activation.get_shape()[1])
                #print("_____",caps_num_i)
                miu, activation, test2 = em_routing(votes, activation, num_classes, weights_regularizer,r_class_caps)

            output = tf.reshape(activation, shape=[-1, data_size, data_size, num_classes]) #batch_size
            #print("d op",output.get_shape())
        output = tf.reshape(tf.nn.avg_pool(output, ksize=[1, data_size, data_size, 1], strides=[
                    1, 1, 1, 1], padding='VALID'), shape=[-1, num_classes]) # batch_size
        #print("miu  2",miu.get_shape())
        pose = tf.nn.avg_pool(tf.reshape(miu, shape=[-1, data_size, data_size,miu.get_shape()[2]*miu.get_shape()[3]
                                    ]), ksize=[1, data_size, data_size, 1], strides=[1, 1, 1, 1], padding='VALID')
        #print("output_size_posssss",pose.get_shape())
        #miu  2 (450, 1, 10, 18)
        #output_size_posssss (50, 1, 1, 180)
        pose_out = tf.reshape(pose, shape=[-1, num_classes, 18])
        #print("output_size",pose_out.get_shape())
        vector_j = tf.reshape(pose_out, shape= [-1, num_classes * 18])
        #print("pose_out",pose_out.get_shape())
        #print("vector_j",vector_j.get_shape())
    with tf.variable_scope('output_layer') as scope:
        readout = tf.contrib.layers.fully_connected(vector_j, num_outputs=ACTIONS, activation_fn=None) 
    print("Network has been created successfully")
    return s, readout, bs, r_conv_caps1, r_conv_caps2, r_class_caps, coord_add_op_class_caps

# %% [markdown]
# # Environment for Training of the Agent

# %%
def trainNetwork(sess, s, readout, bs, r_conv_caps1, r_conv_caps2, r_class_caps, coord_add_op_class_caps):
    tick = time.time()
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices = 1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()
    # store the previous observations in replay memory
    replay_memory = deque()
    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal, bar1_score, bar2_score = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)  
    # saving and loading networks
    # saver = tf.train.Saver()
    # sess.run(tf.initialize_all_variables())
    sess.run(tf.global_variables_initializer())
    #-------------- initialization for EM routing ------------------------------------
    # ----------- for taking actions ---------------------
    batch_size_pred = 1
    coord_add_p = get_coord_add('mnist') 
    coord_add_p = np.reshape(coord_add_p, newshape=[3 * 3, 1, 1, 2]) #data_size =3
    coord_add_p = np.tile(coord_add_p, [batch_size_pred, D, num_classes, 1])
    r_conv_caps1_p = np.ones([5*5*batch_size_pred, 72, C]) / C
    r_conv_caps2_p = np.ones([3*3*batch_size_pred, 144, D]) / D
    r_class_caps_p = np.ones([3*3*batch_size_pred, 16, num_classes]) / num_classes
    
    # --------- initialization for training -------------------------------------------
    batch_size_train = batch_size
    coord_add_t = get_coord_add('mnist') 
    coord_add_t = np.reshape(coord_add_t, newshape=[3 * 3, 1, 1, 2]) #data_size =3
    coord_add_t = np.tile(coord_add_t, [batch_size_train, D, num_classes, 1])
    r_conv_caps1_t = np.ones([5*5*batch_size_train, 72, C]) / C
    r_conv_caps2_t = np.ones([3*3*batch_size_train, 144, D]) / D
    r_class_caps_t = np.ones([3*3*batch_size_train, 16, num_classes]) / num_classes
    #------------------------------------ ENDS ---------------------------------------
    
    epsilon = INITIAL_EPSILON
    t = 0
    episode = 0
    while True:
        # choose an action epsilon greedily
        # readout_t = readout.eval(feed_dict = {s : [s_t].reshape((1,80,80,4))})[0]
        readout_t = readout.eval(feed_dict = {s:s_t.reshape((1,80,80,4)),
                                              r_conv_caps1: r_conv_caps1_p,
                                              r_conv_caps2: r_conv_caps2_p,
                                              r_class_caps: r_class_caps_p,
                                              coord_add_op_class_caps: coord_add_p,
                                              bs: np.int32(batch_size_pred)})
        #readout_t = readout.eval(feed_dict = {s:s_t.reshape((1,84,84,4)), coeff:b_IJ1})
        
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if random.random() <= epsilon or t <= OBSERVE:
            action_index = random.randrange(ACTIONS)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(readout_t)
            a_t[action_index] = 1

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # run the selected action and observe next state and reward
        x_t1_col, r_t, terminal, bar1_score, bar2_score = game_state.frame_step(a_t)
        if(terminal == 1):
            episode +=1
        x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (80, 80)), cv2.COLOR_BGR2GRAY)
        ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
        x_t1 = np.reshape(x_t1, (80, 80, 1))
        s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)

        # store the transition in D
        replay_memory.append((s_t, a_t, r_t, s_t1, terminal))
        if len(replay_memory ) > REPLAY_MEMORY:
            replay_memory.popleft()
            
        # only train if done observing
        if t > OBSERVE and t%train_freq==0:
            # sample a minibatch to train on
            minibatch = random.sample(replay_memory , BATCH)
            
            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s:s_j1_batch,
                                                         r_conv_caps1: r_conv_caps1_t,
                                                         r_conv_caps2: r_conv_caps2_t,
                                                         r_class_caps: r_class_caps_t,
                                                         coord_add_op_class_caps: coord_add_t,
                                                         bs: np.int32(batch_size_train)})
            #readout_j1_batch = readout.eval(feed_dict = {s:s_j1_batch, coeff:b_IJ2 })

            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch,
                r_conv_caps1: r_conv_caps1_t,
                r_conv_caps2: r_conv_caps2_t,
                r_class_caps: r_class_caps_t,
                coord_add_op_class_caps: coord_add_t,
                bs: np.int32(batch_size_train)})

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        #if t % 10000 == 0:
        #    saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)
        if r_t!= 0:
            print ("TIMESTEP", t, "/ e", episode, "/ bar1_score", bar1_score, "/ bar2_score", bar2_score, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t))

        if( (bar1_score - bar2_score) > 18): 
            print("Game_Ends_in Time:",int(time.time() - tick))
            break;   
            
        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

# %%
def playGame():
    tf.reset_default_graph()
    sess = tf.InteractiveSession()
    s, readout, bs, r_conv_caps1, r_conv_caps2, r_class_caps, coord_add_op_class_caps = createNetwork()
    trainNetwork(sess, s, readout, bs, r_conv_caps1, r_conv_caps2, r_class_caps, coord_add_op_class_caps)

# %%
def main():
    playGame()

if __name__ == "__main__":
    tick = time.time()
    main()
    print("Game_Ends_in Time:",int(time.time() - tick))
    print("____________ END HERE _____________")
# Out:
# WARNING:tensorflow:From <ipython-input-5-91962e308f30>:35: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Network has been created successfully
# TIMESTEP 129 / e 0 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 175 / e 0 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 221 / e 0 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 267 / e 0 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 313 / e 0 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 359 / e 0 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 405 / e 0 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 451 / e 0 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 497 / e 0 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 543 / e 0 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 589 / e 0 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 635 / e 0 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 681 / e 0 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 0.000000e+00
# TIMESTEP 810 / e 0 / bar1_score 1 / bar2_score 13 / REWARD 1 / Q_MAX -4.429366e-04
# TIMESTEP 939 / e 0 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX -9.458855e-04
# TIMESTEP 985 / e 0 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX -1.032681e-03
# TIMESTEP 1031 / e 0 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX -1.077702e-03
# TIMESTEP 1077 / e 0 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX -1.114313e-03
# TIMESTEP 1123 / e 0 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX -1.136846e-03
# TIMESTEP 1169 / e 0 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX -1.148404e-03
# TIMESTEP 1215 / e 1 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.237200e-03
# TIMESTEP 1261 / e 1 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.360915e-03
# TIMESTEP 1307 / e 1 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -1.593652e-03
# TIMESTEP 1436 / e 1 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX -1.676185e-03
# TIMESTEP 1565 / e 1 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX -1.698354e-03
# TIMESTEP 1611 / e 1 / bar1_score 1 / bar2_score 4 / REWARD -1 / Q_MAX -1.700965e-03
# TIMESTEP 1657 / e 1 / bar1_score 1 / bar2_score 5 / REWARD -1 / Q_MAX -1.702954e-03
# TIMESTEP 1786 / e 1 / bar1_score 2 / bar2_score 5 / REWARD 1 / Q_MAX -2.027868e-03
# TIMESTEP 2169 / e 1 / bar1_score 3 / bar2_score 5 / REWARD 1 / Q_MAX -2.274026e-03
# TIMESTEP 2298 / e 1 / bar1_score 3 / bar2_score 6 / REWARD -1 / Q_MAX -2.693032e-03
# TIMESTEP 2344 / e 1 / bar1_score 3 / bar2_score 7 / REWARD -1 / Q_MAX -2.761053e-03
# TIMESTEP 2390 / e 1 / bar1_score 3 / bar2_score 8 / REWARD -1 / Q_MAX -2.864649e-03
# TIMESTEP 2436 / e 1 / bar1_score 3 / bar2_score 9 / REWARD -1 / Q_MAX -3.071863e-03
# TIMESTEP 2482 / e 1 / bar1_score 3 / bar2_score 10 / REWARD -1 / Q_MAX -3.089126e-03
# TIMESTEP 2528 / e 1 / bar1_score 3 / bar2_score 11 / REWARD -1 / Q_MAX -3.097698e-03
# TIMESTEP 2574 / e 1 / bar1_score 3 / bar2_score 12 / REWARD -1 / Q_MAX -3.104349e-03
# TIMESTEP 2620 / e 1 / bar1_score 3 / bar2_score 13 / REWARD -1 / Q_MAX -3.196898e-03
# TIMESTEP 2666 / e 1 / bar1_score 3 / bar2_score 14 / REWARD -1 / Q_MAX -3.357922e-03
# TIMESTEP 2712 / e 1 / bar1_score 3 / bar2_score 15 / REWARD -1 / Q_MAX -3.621502e-03
# TIMESTEP 2758 / e 1 / bar1_score 3 / bar2_score 16 / REWARD -1 / Q_MAX -3.799540e-03
# TIMESTEP 2804 / e 1 / bar1_score 3 / bar2_score 17 / REWARD -1 / Q_MAX -3.850638e-03
# TIMESTEP 2850 / e 1 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX -3.861735e-03
# TIMESTEP 2896 / e 1 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX -3.886877e-03
# TIMESTEP 2942 / e 2 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.910091e-03
# TIMESTEP 2988 / e 2 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -3.987587e-03
# TIMESTEP 3034 / e 2 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.181750e-03
# TIMESTEP 3080 / e 2 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.312524e-03
# TIMESTEP 3126 / e 2 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.457454e-03
# TIMESTEP 3172 / e 2 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.611549e-03
# TIMESTEP 3218 / e 2 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.688479e-03
# TIMESTEP 3264 / e 2 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.748856e-03
# TIMESTEP 3310 / e 2 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.778804e-03
# TIMESTEP 3356 / e 2 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.802066e-03
# TIMESTEP 3402 / e 2 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.815546e-03
# TIMESTEP 3448 / e 2 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.822026e-03
# TIMESTEP 3494 / e 2 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.921949e-03
# TIMESTEP 3540 / e 2 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -5.064350e-03
# TIMESTEP 3586 / e 2 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -5.176190e-03
# TIMESTEP 3632 / e 2 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.494133e-03
# TIMESTEP 3678 / e 2 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.844096e-03
# TIMESTEP 3724 / e 2 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -5.897155e-03
# TIMESTEP 3770 / e 2 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -6.043498e-03
# TIMESTEP 3816 / e 2 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -6.181358e-03
# TIMESTEP 3862 / e 3 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -6.225969e-03
# TIMESTEP 3908 / e 3 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -6.248089e-03
# TIMESTEP 3954 / e 3 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -6.314270e-03
# TIMESTEP 4000 / e 3 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -6.394860e-03
# TIMESTEP 4046 / e 3 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -6.458013e-03
# TIMESTEP 4092 / e 3 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -6.369284e-03
# TIMESTEP 4138 / e 3 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -6.295611e-03
# TIMESTEP 4184 / e 3 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -6.237500e-03
# TIMESTEP 4230 / e 3 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -6.208330e-03
# TIMESTEP 4276 / e 3 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -6.421509e-03
# TIMESTEP 4322 / e 3 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -6.671357e-03
# TIMESTEP 4368 / e 3 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -6.795965e-03
# TIMESTEP 4414 / e 3 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -6.893800e-03
# TIMESTEP 4460 / e 3 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -6.942505e-03
# TIMESTEP 4506 / e 3 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -6.980559e-03
# TIMESTEP 4552 / e 3 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -7.002896e-03
# TIMESTEP 4598 / e 3 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -7.044033e-03
# TIMESTEP 4644 / e 3 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -7.220500e-03
# TIMESTEP 4690 / e 3 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -7.363307e-03
# TIMESTEP 4736 / e 3 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -7.475342e-03
# TIMESTEP 4782 / e 4 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -7.541637e-03
# TIMESTEP 4828 / e 4 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -7.574475e-03
# TIMESTEP 4874 / e 4 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -7.785437e-03
# TIMESTEP 4920 / e 4 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -8.021789e-03
# TIMESTEP 4966 / e 4 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -8.232967e-03
# TIMESTEP 5012 / e 4 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -8.387912e-03
# TIMESTEP 5058 / e 4 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -8.542572e-03
# TIMESTEP 5104 / e 4 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -8.693588e-03
# TIMESTEP 5150 / e 4 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -8.846310e-03
# TIMESTEP 5196 / e 4 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -8.891963e-03
# TIMESTEP 5242 / e 4 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -8.899615e-03
# TIMESTEP 5288 / e 4 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -8.903151e-03
# TIMESTEP 5334 / e 4 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -9.048581e-03
# TIMESTEP 5380 / e 4 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -9.143887e-03
# TIMESTEP 5426 / e 4 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -9.218414e-03
# TIMESTEP 5472 / e 4 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -9.403991e-03
# TIMESTEP 5518 / e 4 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -9.519003e-03
# TIMESTEP 5564 / e 4 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -9.774879e-03
# TIMESTEP 5610 / e 4 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -9.902191e-03
# TIMESTEP 5656 / e 4 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.003198e-02
# TIMESTEP 5702 / e 5 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.010540e-02
# TIMESTEP 5748 / e 5 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.016859e-02
# TIMESTEP 5794 / e 5 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -1.036806e-02
# TIMESTEP 5840 / e 5 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.049818e-02
# TIMESTEP 5886 / e 5 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -1.062665e-02
# TIMESTEP 5932 / e 5 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.078549e-02
# TIMESTEP 5978 / e 5 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -1.095614e-02
# TIMESTEP 6024 / e 5 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.108975e-02
# TIMESTEP 6070 / e 5 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -1.111087e-02
# TIMESTEP 6116 / e 5 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.111978e-02
# TIMESTEP 6162 / e 5 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -1.112468e-02
# TIMESTEP 6208 / e 5 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.112683e-02
# TIMESTEP 6254 / e 5 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -1.124518e-02
# TIMESTEP 6300 / e 5 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.135421e-02
# TIMESTEP 6346 / e 5 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -1.143926e-02
# TIMESTEP 6392 / e 5 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.148913e-02
# TIMESTEP 6438 / e 5 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -1.151367e-02
# TIMESTEP 6484 / e 5 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.153253e-02
# TIMESTEP 6530 / e 5 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -1.154163e-02
# TIMESTEP 6576 / e 5 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.154833e-02
# TIMESTEP 6622 / e 6 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.155174e-02
# TIMESTEP 6668 / e 6 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.170503e-02
# TIMESTEP 6714 / e 6 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -1.182484e-02
# TIMESTEP 6760 / e 6 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.188405e-02
# TIMESTEP 6806 / e 6 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -1.192987e-02
# TIMESTEP 6852 / e 6 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.195648e-02
# TIMESTEP 6898 / e 6 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -1.196916e-02
# TIMESTEP 6944 / e 6 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.216073e-02
# TIMESTEP 6990 / e 6 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -1.237330e-02
# TIMESTEP 7036 / e 6 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.257732e-02
# TIMESTEP 7082 / e 6 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -1.269766e-02
# TIMESTEP 7128 / e 6 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.275707e-02
# TIMESTEP 7174 / e 6 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -1.295321e-02
# TIMESTEP 7220 / e 6 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.315550e-02
# TIMESTEP 7266 / e 6 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -1.356183e-02
# TIMESTEP 7312 / e 6 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.380228e-02
# TIMESTEP 7358 / e 6 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -1.396322e-02
# TIMESTEP 7404 / e 6 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.435048e-02
# TIMESTEP 7450 / e 6 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -1.470308e-02
# TIMESTEP 7496 / e 6 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.501890e-02
# TIMESTEP 7542 / e 7 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.532938e-02
# TIMESTEP 7588 / e 7 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.548342e-02
# TIMESTEP 7634 / e 7 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -1.560343e-02
# TIMESTEP 7680 / e 7 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.563257e-02
# TIMESTEP 7726 / e 7 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -1.564075e-02
# TIMESTEP 7772 / e 7 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.564509e-02
# TIMESTEP 7818 / e 7 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -1.564685e-02
# TIMESTEP 7864 / e 7 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.578477e-02
# TIMESTEP 7910 / e 7 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -1.587491e-02
# TIMESTEP 7956 / e 7 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.594501e-02
# TIMESTEP 8002 / e 7 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -1.612224e-02
# TIMESTEP 8048 / e 7 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.640970e-02
# TIMESTEP 8094 / e 7 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -1.673819e-02
# TIMESTEP 8140 / e 7 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.690117e-02
# TIMESTEP 8186 / e 7 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -1.702832e-02
# TIMESTEP 8232 / e 7 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.710291e-02
# TIMESTEP 8278 / e 7 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -1.713938e-02
# TIMESTEP 8324 / e 7 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.727352e-02
# TIMESTEP 8370 / e 7 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -1.761920e-02
# TIMESTEP 8416 / e 7 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.807385e-02
# TIMESTEP 8462 / e 8 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.834253e-02
# TIMESTEP 8508 / e 8 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.854683e-02
# TIMESTEP 8554 / e 8 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -1.878688e-02
# TIMESTEP 8600 / e 8 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.881280e-02
# TIMESTEP 8646 / e 8 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -1.883281e-02
# TIMESTEP 8692 / e 8 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.893602e-02
# TIMESTEP 8738 / e 8 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -1.902662e-02
# TIMESTEP 8784 / e 8 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.921304e-02
# TIMESTEP 8830 / e 8 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -1.932415e-02
# TIMESTEP 8876 / e 8 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.941101e-02
# TIMESTEP 8922 / e 8 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -1.946217e-02
# TIMESTEP 8968 / e 8 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.948723e-02
# TIMESTEP 9014 / e 8 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -1.950651e-02
# TIMESTEP 9060 / e 8 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.951570e-02
# TIMESTEP 9106 / e 8 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -1.952231e-02
# TIMESTEP 9152 / e 8 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.956027e-02
# TIMESTEP 9198 / e 8 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -1.970219e-02
# TIMESTEP 9244 / e 8 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.991016e-02
# TIMESTEP 9290 / e 8 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -2.001329e-02
# TIMESTEP 9336 / e 8 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -2.009366e-02
# TIMESTEP 9382 / e 9 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -2.014048e-02
# TIMESTEP 9428 / e 9 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -2.016320e-02
# TIMESTEP 9474 / e 9 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -2.030854e-02
# TIMESTEP 9520 / e 9 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -2.050494e-02
# TIMESTEP 9566 / e 9 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -2.079487e-02
# TIMESTEP 9612 / e 9 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -2.096602e-02
# TIMESTEP 9658 / e 9 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.105065e-02
# TIMESTEP 9704 / e 9 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -2.132167e-02
# TIMESTEP 9750 / e 9 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -2.151313e-02
# TIMESTEP 9796 / e 9 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -2.166249e-02
# TIMESTEP 9842 / e 9 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -2.175018e-02
# TIMESTEP 9888 / e 9 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -2.188418e-02
# TIMESTEP 9934 / e 9 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -2.201766e-02
# TIMESTEP 9980 / e 9 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -2.214701e-02
# TIMESTEP 10026 / e 9 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -2.228423e-02
# TIMESTEP 10072 / e 9 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -2.234680e-02
# TIMESTEP 10118 / e 9 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -2.237749e-02
# TIMESTEP 10164 / e 9 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -2.240090e-02
# TIMESTEP 10210 / e 9 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -2.241198e-02
# TIMESTEP 10256 / e 9 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -2.247598e-02
# TIMESTEP 10302 / e 10 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -2.257787e-02
# TIMESTEP 10348 / e 10 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -2.262798e-02
# TIMESTEP 10394 / e 10 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -2.266651e-02
# TIMESTEP 10440 / e 10 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -2.274132e-02
# TIMESTEP 10486 / e 10 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -2.285356e-02
# TIMESTEP 10532 / e 10 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -2.302090e-02
# TIMESTEP 10578 / e 10 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.311987e-02
# TIMESTEP 10624 / e 10 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -2.334679e-02
# TIMESTEP 10670 / e 10 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -2.353520e-02
# TIMESTEP 10716 / e 10 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -2.387978e-02
# TIMESTEP 10762 / e 10 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -2.417807e-02
# TIMESTEP 10808 / e 10 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -2.443382e-02
# TIMESTEP 10854 / e 10 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -2.468618e-02
# TIMESTEP 10900 / e 10 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -2.481116e-02
# TIMESTEP 10946 / e 10 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -2.496348e-02
# TIMESTEP 10992 / e 10 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -2.521611e-02
# TIMESTEP 11038 / e 10 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -2.541059e-02
# TIMESTEP 11084 / e 10 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -2.544365e-02
# TIMESTEP 11130 / e 10 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -2.554945e-02
# TIMESTEP 11176 / e 10 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -2.563174e-02
# TIMESTEP 11222 / e 11 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -2.572959e-02
# TIMESTEP 11268 / e 11 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -2.592258e-02
# TIMESTEP 11314 / e 11 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -2.624576e-02
# TIMESTEP 11360 / e 11 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -2.652024e-02
# TIMESTEP 11406 / e 11 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -2.673461e-02
# TIMESTEP 11452 / e 11 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -2.686089e-02
# TIMESTEP 11498 / e 11 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.692323e-02
# TIMESTEP 11544 / e 11 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -2.709143e-02
# TIMESTEP 11590 / e 11 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -2.725291e-02
# TIMESTEP 11636 / e 11 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -2.732953e-02
# TIMESTEP 11682 / e 11 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -2.738864e-02
# TIMESTEP 11728 / e 11 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -2.745458e-02
# TIMESTEP 11774 / e 11 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -2.750519e-02
# TIMESTEP 11820 / e 11 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -2.758647e-02
# TIMESTEP 11866 / e 11 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -2.771521e-02
# TIMESTEP 11912 / e 11 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -2.773192e-02
# TIMESTEP 11958 / e 11 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -2.773984e-02
# TIMESTEP 12004 / e 11 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -2.774566e-02
# TIMESTEP 12050 / e 11 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -2.781855e-02
# TIMESTEP 12096 / e 11 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -2.794324e-02
# TIMESTEP 12142 / e 12 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -2.816711e-02
# TIMESTEP 12188 / e 12 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -2.837663e-02
# TIMESTEP 12234 / e 12 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -2.857173e-02
# TIMESTEP 12280 / e 12 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -2.866817e-02
# TIMESTEP 12326 / e 12 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -2.874291e-02
# TIMESTEP 12372 / e 12 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -2.893658e-02
# TIMESTEP 12418 / e 12 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.903229e-02
# TIMESTEP 12464 / e 12 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -2.925586e-02
# TIMESTEP 12510 / e 12 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -2.936618e-02
# TIMESTEP 12556 / e 12 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -2.945150e-02
# TIMESTEP 12602 / e 12 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -2.950098e-02
# TIMESTEP 12648 / e 12 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -2.956163e-02
# TIMESTEP 12694 / e 12 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -2.971530e-02
# TIMESTEP 12740 / e 12 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -2.979102e-02
# TIMESTEP 12786 / e 12 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -2.984965e-02
# TIMESTEP 12832 / e 12 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -2.988341e-02
# TIMESTEP 12878 / e 12 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -2.989933e-02
# TIMESTEP 12924 / e 12 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -3.003856e-02
# TIMESTEP 12970 / e 12 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -3.012747e-02
# TIMESTEP 13016 / e 12 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -3.026624e-02
# TIMESTEP 13062 / e 13 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.042865e-02
# TIMESTEP 13108 / e 13 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -3.063485e-02
# TIMESTEP 13154 / e 13 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -3.079545e-02
# TIMESTEP 13200 / e 13 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -3.087444e-02
# TIMESTEP 13246 / e 13 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -3.093528e-02
# TIMESTEP 13292 / e 13 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -3.097010e-02
# TIMESTEP 13338 / e 13 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -3.098639e-02
# TIMESTEP 13384 / e 13 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -3.099759e-02
# TIMESTEP 13430 / e 13 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -3.100223e-02
# TIMESTEP 13476 / e 13 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -3.100475e-02
# TIMESTEP 13522 / e 13 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -3.113456e-02
# TIMESTEP 13568 / e 13 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -3.128966e-02
# TIMESTEP 13614 / e 13 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -3.147795e-02
# TIMESTEP 13660 / e 13 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -3.157043e-02
# TIMESTEP 13706 / e 13 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -3.171270e-02
# TIMESTEP 13752 / e 13 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -3.187779e-02
# TIMESTEP 13798 / e 13 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -3.208618e-02
# TIMESTEP 13844 / e 13 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -3.231789e-02
# TIMESTEP 13890 / e 13 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -3.235267e-02
# TIMESTEP 13936 / e 13 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -3.238830e-02
# TIMESTEP 13982 / e 14 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.249484e-02
# TIMESTEP 14028 / e 14 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -3.254699e-02
# TIMESTEP 14074 / e 14 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -3.266285e-02
# TIMESTEP 14120 / e 14 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -3.275235e-02
# TIMESTEP 14166 / e 14 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -3.282166e-02
# TIMESTEP 14212 / e 14 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -3.286148e-02
# TIMESTEP 14258 / e 14 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -3.288040e-02
# TIMESTEP 14304 / e 14 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -3.289424e-02
# TIMESTEP 14350 / e 14 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -3.297732e-02
# TIMESTEP 14396 / e 14 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -3.306624e-02
# TIMESTEP 14442 / e 14 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -3.311780e-02
# TIMESTEP 14488 / e 14 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -3.314268e-02
# TIMESTEP 14534 / e 14 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -3.333593e-02
# TIMESTEP 14580 / e 14 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -3.350814e-02
# TIMESTEP 14626 / e 14 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -3.372399e-02
# TIMESTEP 14672 / e 14 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -3.390465e-02
# TIMESTEP 14718 / e 14 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -3.404600e-02
# TIMESTEP 14764 / e 14 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -3.415584e-02
# TIMESTEP 14810 / e 14 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -3.430729e-02
# TIMESTEP 14856 / e 14 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -3.454047e-02
# TIMESTEP 14902 / e 15 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.492180e-02
# TIMESTEP 14948 / e 15 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -3.524158e-02
# TIMESTEP 14994 / e 15 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -3.566711e-02
# TIMESTEP 15040 / e 15 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -3.601126e-02
# TIMESTEP 15086 / e 15 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -3.632951e-02
# TIMESTEP 15132 / e 15 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -3.661065e-02
# TIMESTEP 15178 / e 15 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -3.681613e-02
# TIMESTEP 15224 / e 15 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -3.707775e-02
# TIMESTEP 15270 / e 15 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -3.725698e-02
# TIMESTEP 15316 / e 15 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -3.744502e-02
# TIMESTEP 15362 / e 15 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -3.761563e-02
# TIMESTEP 15408 / e 15 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -3.769972e-02
# TIMESTEP 15454 / e 15 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -3.782894e-02
# TIMESTEP 15500 / e 15 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -3.795467e-02
# TIMESTEP 15546 / e 15 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -3.814320e-02
# TIMESTEP 15592 / e 15 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -3.830025e-02
# TIMESTEP 15638 / e 15 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -3.837724e-02
# TIMESTEP 15684 / e 15 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -3.843663e-02
# TIMESTEP 15730 / e 15 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -3.849923e-02
# TIMESTEP 15776 / e 15 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -3.864158e-02
# TIMESTEP 15822 / e 16 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.874825e-02
# TIMESTEP 15868 / e 16 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -3.887491e-02
# TIMESTEP 15914 / e 16 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -3.899673e-02
# TIMESTEP 15960 / e 16 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -3.905641e-02
# TIMESTEP 16006 / e 16 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -3.910155e-02
# TIMESTEP 16052 / e 16 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -3.912667e-02
# TIMESTEP 16098 / e 16 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -3.926827e-02
# TIMESTEP 16144 / e 16 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -3.955622e-02
# TIMESTEP 16190 / e 16 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -3.969802e-02
# TIMESTEP 16236 / e 16 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -3.986189e-02
# TIMESTEP 16282 / e 16 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.019838e-02
# TIMESTEP 16328 / e 16 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.049615e-02
# TIMESTEP 16374 / e 16 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.066001e-02
# TIMESTEP 16420 / e 16 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.072001e-02
# TIMESTEP 16466 / e 16 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.086646e-02
# TIMESTEP 16512 / e 16 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.110355e-02
# TIMESTEP 16558 / e 16 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.122066e-02
# TIMESTEP 16604 / e 16 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.131107e-02
# TIMESTEP 16650 / e 16 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.135504e-02
# TIMESTEP 16696 / e 16 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.149874e-02
# TIMESTEP 16742 / e 17 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.160387e-02
# TIMESTEP 16788 / e 17 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.165525e-02
# TIMESTEP 16834 / e 17 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.169406e-02
# TIMESTEP 16880 / e 17 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.174433e-02
# TIMESTEP 16926 / e 17 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.196321e-02
# TIMESTEP 16972 / e 17 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.213592e-02
# TIMESTEP 17018 / e 17 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.222067e-02
# TIMESTEP 17064 / e 17 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.228599e-02
# TIMESTEP 17110 / e 17 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.234968e-02
# TIMESTEP 17156 / e 17 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.252472e-02
# TIMESTEP 17202 / e 17 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.272644e-02
# TIMESTEP 17248 / e 17 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.285760e-02
# TIMESTEP 17294 / e 17 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.292283e-02
# TIMESTEP 17340 / e 17 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.292083e-02
# TIMESTEP 17386 / e 17 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.291839e-02
# TIMESTEP 17432 / e 17 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.294858e-02
# TIMESTEP 17478 / e 17 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.304812e-02
# TIMESTEP 17524 / e 17 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.312537e-02
# TIMESTEP 17570 / e 17 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.319587e-02
# TIMESTEP 17616 / e 17 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.334548e-02
# TIMESTEP 17662 / e 18 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.343269e-02
# TIMESTEP 17708 / e 18 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.347511e-02
# TIMESTEP 17754 / e 18 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.350720e-02
# TIMESTEP 17800 / e 18 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.355514e-02
# TIMESTEP 17846 / e 18 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.368728e-02
# TIMESTEP 17892 / e 18 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.376347e-02
# TIMESTEP 17938 / e 18 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.386028e-02
# TIMESTEP 17984 / e 18 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.408192e-02
# TIMESTEP 18030 / e 18 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.422919e-02
# TIMESTEP 18076 / e 18 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.434355e-02
# TIMESTEP 18122 / e 18 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.452326e-02
# TIMESTEP 18168 / e 18 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.469375e-02
# TIMESTEP 18214 / e 18 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.501223e-02
# TIMESTEP 18260 / e 18 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.516938e-02
# TIMESTEP 18306 / e 18 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.540227e-02
# TIMESTEP 18352 / e 18 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.555980e-02
# TIMESTEP 18398 / e 18 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.563690e-02
# TIMESTEP 18444 / e 18 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.569567e-02
# TIMESTEP 18490 / e 18 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.583522e-02
# TIMESTEP 18536 / e 18 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.594273e-02
# TIMESTEP 18582 / e 19 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.609253e-02
# TIMESTEP 18628 / e 19 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.620370e-02
# TIMESTEP 18674 / e 19 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.642197e-02
# TIMESTEP 18720 / e 19 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.656129e-02
# TIMESTEP 18766 / e 19 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.676224e-02
# TIMESTEP 18812 / e 19 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.697235e-02
# TIMESTEP 18858 / e 19 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.713206e-02
# TIMESTEP 18904 / e 19 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.728532e-02
# TIMESTEP 18950 / e 19 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.751297e-02
# TIMESTEP 18996 / e 19 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.772953e-02
# TIMESTEP 19042 / e 19 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.778423e-02
# TIMESTEP 19088 / e 19 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.784280e-02
# TIMESTEP 19134 / e 19 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.798066e-02
# TIMESTEP 19180 / e 19 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.804782e-02
# TIMESTEP 19226 / e 19 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.809897e-02
# TIMESTEP 19272 / e 19 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.821784e-02
# TIMESTEP 19318 / e 19 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.836382e-02
# TIMESTEP 19364 / e 19 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.851954e-02
# TIMESTEP 19410 / e 19 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.861432e-02
# TIMESTEP 19456 / e 19 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.872096e-02
# TIMESTEP 19502 / e 20 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.877099e-02
# TIMESTEP 19548 / e 20 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.877622e-02
# TIMESTEP 19594 / e 20 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.877927e-02
# TIMESTEP 19640 / e 20 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.889490e-02
# TIMESTEP 19686 / e 20 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.898392e-02
# TIMESTEP 19732 / e 20 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.906822e-02
# TIMESTEP 19778 / e 20 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.928583e-02
# TIMESTEP 19824 / e 20 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.948353e-02
# TIMESTEP 19870 / e 20 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.958060e-02
# TIMESTEP 19916 / e 20 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.965471e-02
# TIMESTEP 19962 / e 20 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.969705e-02
# TIMESTEP 20008 / e 20 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.971674e-02
# TIMESTEP 20054 / e 20 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.973084e-02
# TIMESTEP 20100 / e 20 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.985251e-02
# TIMESTEP 20146 / e 20 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.994643e-02
# TIMESTEP 20192 / e 20 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.000039e-02
# TIMESTEP 20238 / e 20 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.013614e-02
# TIMESTEP 20284 / e 20 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -5.024049e-02
# TIMESTEP 20330 / e 20 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -5.038255e-02
# TIMESTEP 20376 / e 20 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -5.069153e-02
# TIMESTEP 20422 / e 21 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -5.112258e-02
# TIMESTEP 20468 / e 21 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -5.143211e-02
# TIMESTEP 20514 / e 21 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -5.167279e-02
# TIMESTEP 20560 / e 21 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -5.179109e-02
# TIMESTEP 20606 / e 21 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -5.188205e-02
# TIMESTEP 20652 / e 21 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -5.206999e-02
# TIMESTEP 20698 / e 21 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -5.216197e-02
# TIMESTEP 20744 / e 21 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -5.223226e-02
# TIMESTEP 20790 / e 21 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -5.226570e-02
# TIMESTEP 20836 / e 21 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -5.235319e-02
# TIMESTEP 20882 / e 21 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -5.247680e-02
# TIMESTEP 20928 / e 21 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -5.253684e-02
# TIMESTEP 20974 / e 21 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -5.267311e-02
# TIMESTEP 21020 / e 21 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -5.286847e-02
# TIMESTEP 21066 / e 21 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -5.299102e-02
# TIMESTEP 21112 / e 21 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.300908e-02
# TIMESTEP 21158 / e 21 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.301696e-02
# TIMESTEP 21204 / e 21 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -5.310198e-02
# TIMESTEP 21250 / e 21 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -5.325705e-02
# TIMESTEP 21296 / e 21 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -5.340275e-02
# TIMESTEP 21342 / e 22 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -5.348751e-02
# TIMESTEP 21388 / e 22 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -5.352865e-02
# TIMESTEP 21434 / e 22 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -5.368054e-02
# TIMESTEP 21480 / e 22 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -5.381294e-02
# TIMESTEP 21526 / e 22 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -5.400312e-02
# TIMESTEP 21572 / e 22 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -5.419772e-02
# TIMESTEP 21618 / e 22 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -5.433183e-02
# TIMESTEP 21664 / e 22 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -5.443493e-02
# TIMESTEP 21710 / e 22 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -5.457551e-02
# TIMESTEP 21756 / e 22 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -5.471282e-02
# TIMESTEP 21802 / e 22 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -5.497864e-02
# TIMESTEP 21848 / e 22 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -5.529436e-02
# TIMESTEP 21894 / e 22 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -5.587167e-02
# TIMESTEP 21940 / e 22 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -5.613241e-02
# TIMESTEP 21986 / e 22 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -5.625082e-02
# TIMESTEP 22032 / e 22 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.639755e-02
# TIMESTEP 22078 / e 22 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.650300e-02
# TIMESTEP 22124 / e 22 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -5.666196e-02
# TIMESTEP 22170 / e 22 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -5.677346e-02
# TIMESTEP 22216 / e 22 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -5.685950e-02
# TIMESTEP 22262 / e 23 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -5.693796e-02
# TIMESTEP 22308 / e 23 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -5.708010e-02
# TIMESTEP 22354 / e 23 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -5.750358e-02
# TIMESTEP 22400 / e 23 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -5.771258e-02
# TIMESTEP 22446 / e 23 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -5.787477e-02
# TIMESTEP 22492 / e 23 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -5.796943e-02
# TIMESTEP 22538 / e 23 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -5.801534e-02
# TIMESTEP 22584 / e 23 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -5.804982e-02
# TIMESTEP 22630 / e 23 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -5.806591e-02
# TIMESTEP 22676 / e 23 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -5.807700e-02
# TIMESTEP 22722 / e 23 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -5.811086e-02
# TIMESTEP 22768 / e 23 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -5.832966e-02
# TIMESTEP 22814 / e 23 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -5.868027e-02
# TIMESTEP 22860 / e 23 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -5.896098e-02
# TIMESTEP 22906 / e 23 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -5.917897e-02
# TIMESTEP 22952 / e 23 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.930581e-02
# TIMESTEP 22998 / e 23 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.939587e-02
# TIMESTEP 23044 / e 23 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -5.954746e-02
# TIMESTEP 23090 / e 23 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -5.962131e-02
# TIMESTEP 23136 / e 23 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -5.980444e-02
# TIMESTEP 23182 / e 24 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -6.001850e-02
# TIMESTEP 23228 / e 24 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -6.012328e-02
# TIMESTEP 23274 / e 24 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -6.020307e-02
# TIMESTEP 23320 / e 24 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -6.036870e-02
# TIMESTEP 23366 / e 24 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -6.057974e-02
# TIMESTEP 23412 / e 24 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -6.070256e-02
# TIMESTEP 23458 / e 24 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -6.076202e-02
# TIMESTEP 23504 / e 24 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -6.080629e-02
# TIMESTEP 23550 / e 24 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -6.082641e-02
# TIMESTEP 23596 / e 24 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -6.083998e-02
# TIMESTEP 23642 / e 24 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -6.109796e-02
# TIMESTEP 23688 / e 24 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -6.133336e-02
# TIMESTEP 23734 / e 24 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -6.146650e-02
# TIMESTEP 23780 / e 24 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -6.153163e-02
# TIMESTEP 23826 / e 24 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -6.158128e-02
# TIMESTEP 23872 / e 24 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -6.174108e-02
# TIMESTEP 23918 / e 24 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -6.191270e-02
# TIMESTEP 23964 / e 24 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -6.204502e-02
# TIMESTEP 24010 / e 24 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -6.213876e-02
# TIMESTEP 24056 / e 24 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -6.237663e-02
# TIMESTEP 24102 / e 25 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -6.263641e-02
# TIMESTEP 24148 / e 25 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -6.290724e-02
# TIMESTEP 24194 / e 25 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -6.334601e-02
# TIMESTEP 24240 / e 25 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -6.344955e-02
# TIMESTEP 24286 / e 25 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -6.352118e-02
# TIMESTEP 24332 / e 25 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -6.366864e-02
# TIMESTEP 24378 / e 25 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -6.384849e-02
# TIMESTEP 24424 / e 25 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -6.398725e-02
# TIMESTEP 24470 / e 25 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -6.413223e-02
# TIMESTEP 24516 / e 25 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -6.457746e-02
# TIMESTEP 24562 / e 25 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -6.507419e-02
# TIMESTEP 24608 / e 25 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -6.530642e-02
# TIMESTEP 24654 / e 25 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -6.557181e-02
# TIMESTEP 24700 / e 25 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -6.584758e-02
# TIMESTEP 24746 / e 25 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -6.610610e-02
# TIMESTEP 24792 / e 25 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -6.621738e-02
# TIMESTEP 24838 / e 25 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -6.641507e-02
# TIMESTEP 24884 / e 25 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -6.659177e-02
# TIMESTEP 24930 / e 25 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -6.667800e-02
# TIMESTEP 24976 / e 25 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -6.674396e-02
# TIMESTEP 25022 / e 26 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -6.678063e-02
# TIMESTEP 25068 / e 26 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -6.679717e-02
# TIMESTEP 25114 / e 26 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -6.694802e-02
# TIMESTEP 25160 / e 26 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -6.714407e-02
# TIMESTEP 25206 / e 26 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -6.745645e-02
# TIMESTEP 25252 / e 26 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -6.763881e-02
# TIMESTEP 25298 / e 26 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -6.772767e-02
# TIMESTEP 25344 / e 26 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -6.779489e-02
# TIMESTEP 25390 / e 26 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -6.790581e-02
# TIMESTEP 25436 / e 26 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -6.814734e-02
# TIMESTEP 25482 / e 26 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -6.837231e-02
# TIMESTEP 25528 / e 26 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -6.855632e-02
# TIMESTEP 25574 / e 26 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -6.872195e-02
# TIMESTEP 25620 / e 26 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -6.892336e-02
# TIMESTEP 25666 / e 26 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -6.911344e-02
# TIMESTEP 25712 / e 26 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -6.926457e-02
# TIMESTEP 25758 / e 26 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -6.929214e-02
# TIMESTEP 25887 / e 26 / bar1_score 1 / bar2_score 16 / REWARD 1 / Q_MAX -6.943718e-02
# TIMESTEP 26016 / e 26 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX -7.009939e-02
# TIMESTEP 26062 / e 26 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX -7.024884e-02
# TIMESTEP 26108 / e 26 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX -7.050386e-02
# TIMESTEP 26154 / e 27 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -7.060475e-02
# TIMESTEP 26200 / e 27 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -7.065350e-02
# TIMESTEP 26246 / e 27 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -7.078387e-02
# TIMESTEP 26292 / e 27 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -7.098850e-02
# TIMESTEP 26338 / e 27 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -7.108839e-02
# TIMESTEP 26384 / e 27 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -7.123690e-02
# TIMESTEP 26430 / e 27 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -7.122904e-02
# TIMESTEP 26476 / e 27 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -7.123999e-02
# TIMESTEP 26522 / e 27 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -7.124367e-02
# TIMESTEP 26568 / e 27 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -7.124139e-02
# TIMESTEP 26614 / e 27 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -7.123790e-02
# TIMESTEP 26660 / e 27 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -7.123410e-02
# ...
# TIMESTEP 187143 / e 200 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.562169e-01
# TIMESTEP 187189 / e 200 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.563763e-01
# TIMESTEP 187235 / e 200 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.565476e-01
# TIMESTEP 187281 / e 200 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.567373e-01
# TIMESTEP 187327 / e 200 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.568689e-01
# TIMESTEP 187373 / e 200 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.569291e-01
# TIMESTEP 187419 / e 200 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.569474e-01
# TIMESTEP 187465 / e 200 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.569481e-01
# TIMESTEP 187511 / e 200 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.569328e-01
# TIMESTEP 187557 / e 200 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.569045e-01
# TIMESTEP 187603 / e 200 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.568729e-01
# TIMESTEP 187649 / e 200 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.568411e-01
# TIMESTEP 187695 / e 200 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.567975e-01
# TIMESTEP 187741 / e 200 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.567966e-01
# TIMESTEP 187787 / e 200 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.571260e-01
# TIMESTEP 187833 / e 200 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.573543e-01
# TIMESTEP 187879 / e 200 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.575493e-01
# TIMESTEP 187925 / e 200 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.577132e-01
# TIMESTEP 187971 / e 201 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.578997e-01
# TIMESTEP 188017 / e 201 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.580264e-01
# TIMESTEP 188063 / e 201 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.580828e-01
# TIMESTEP 188109 / e 201 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.580945e-01
# TIMESTEP 188155 / e 201 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.581530e-01
# TIMESTEP 188201 / e 201 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.583316e-01
# TIMESTEP 188247 / e 201 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.586073e-01
# TIMESTEP 188293 / e 201 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.588075e-01
# TIMESTEP 188339 / e 201 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.589809e-01
# TIMESTEP 188385 / e 201 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.591994e-01
# TIMESTEP 188431 / e 201 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.594778e-01
# TIMESTEP 188477 / e 201 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.597767e-01
# TIMESTEP 188523 / e 201 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.600022e-01
# TIMESTEP 188569 / e 201 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.602291e-01
# TIMESTEP 188615 / e 201 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.604494e-01
# TIMESTEP 188661 / e 201 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.605439e-01
# TIMESTEP 188707 / e 201 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.606043e-01
# TIMESTEP 188753 / e 201 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.606225e-01
# TIMESTEP 188799 / e 201 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.606131e-01
# TIMESTEP 188845 / e 201 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.605815e-01
# TIMESTEP 188891 / e 202 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.606689e-01
# TIMESTEP 188937 / e 202 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.607155e-01
# TIMESTEP 188983 / e 202 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.607871e-01
# TIMESTEP 189029 / e 202 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.609330e-01
# TIMESTEP 189075 / e 202 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.612086e-01
# TIMESTEP 189121 / e 202 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.613482e-01
# TIMESTEP 189167 / e 202 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.614719e-01
# TIMESTEP 189213 / e 202 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.616272e-01
# TIMESTEP 189259 / e 202 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.617848e-01
# TIMESTEP 189305 / e 202 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.619181e-01
# TIMESTEP 189351 / e 202 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.620224e-01
# TIMESTEP 189397 / e 202 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.621013e-01
# TIMESTEP 189443 / e 202 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.621255e-01
# TIMESTEP 189489 / e 202 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.621208e-01
# TIMESTEP 189535 / e 202 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.621662e-01
# TIMESTEP 189581 / e 202 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.622361e-01
# TIMESTEP 189627 / e 202 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.623006e-01
# TIMESTEP 189673 / e 202 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.626057e-01
# TIMESTEP 189719 / e 202 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.628862e-01
# TIMESTEP 189765 / e 202 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.632858e-01
# TIMESTEP 189811 / e 203 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.634693e-01
# TIMESTEP 189857 / e 203 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.635922e-01
# TIMESTEP 189903 / e 203 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.636420e-01
# TIMESTEP 189949 / e 203 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.637136e-01
# TIMESTEP 189995 / e 203 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.639766e-01
# TIMESTEP 190041 / e 203 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.641330e-01
# TIMESTEP 190087 / e 203 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.642305e-01
# TIMESTEP 190133 / e 203 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.642664e-01
# TIMESTEP 190179 / e 203 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.642667e-01
# TIMESTEP 190225 / e 203 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.642470e-01
# TIMESTEP 190271 / e 203 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.644038e-01
# TIMESTEP 190317 / e 203 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.646297e-01
# TIMESTEP 190363 / e 203 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.648537e-01
# TIMESTEP 190409 / e 203 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.650357e-01
# TIMESTEP 190455 / e 203 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.651639e-01
# TIMESTEP 190501 / e 203 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.653363e-01
# TIMESTEP 190547 / e 203 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.654154e-01
# TIMESTEP 190593 / e 203 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.654727e-01
# TIMESTEP 190639 / e 203 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.655269e-01
# TIMESTEP 190685 / e 203 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.655553e-01
# TIMESTEP 190731 / e 204 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.655588e-01
# TIMESTEP 190777 / e 204 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.655495e-01
# TIMESTEP 190823 / e 204 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.656590e-01
# TIMESTEP 190869 / e 204 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.658177e-01
# TIMESTEP 190915 / e 204 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.660427e-01
# TIMESTEP 190961 / e 204 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.661423e-01
# TIMESTEP 191007 / e 204 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.662873e-01
# TIMESTEP 191053 / e 204 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.664003e-01
# TIMESTEP 191099 / e 204 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.665026e-01
# TIMESTEP 191145 / e 204 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.666232e-01
# TIMESTEP 191191 / e 204 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.666738e-01
# TIMESTEP 191237 / e 204 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.666995e-01
# TIMESTEP 191283 / e 204 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.666995e-01
# TIMESTEP 191329 / e 204 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.666885e-01
# TIMESTEP 191375 / e 204 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.666677e-01
# TIMESTEP 191421 / e 204 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.666449e-01
# TIMESTEP 191467 / e 204 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.666975e-01
# TIMESTEP 191513 / e 204 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.667593e-01
# TIMESTEP 191559 / e 204 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.668850e-01
# TIMESTEP 191605 / e 204 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.669689e-01
# TIMESTEP 191651 / e 205 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.671048e-01
# TIMESTEP 191697 / e 205 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.674287e-01
# TIMESTEP 191743 / e 205 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.676538e-01
# TIMESTEP 191789 / e 205 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.679205e-01
# TIMESTEP 191835 / e 205 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.683617e-01
# TIMESTEP 191881 / e 205 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.685866e-01
# TIMESTEP 191927 / e 205 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.687523e-01
# TIMESTEP 191973 / e 205 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.689392e-01
# TIMESTEP 192019 / e 205 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.690368e-01
# TIMESTEP 192065 / e 205 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.691050e-01
# TIMESTEP 192111 / e 205 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.691278e-01
# TIMESTEP 192157 / e 205 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.691334e-01
# TIMESTEP 192203 / e 205 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.691222e-01
# TIMESTEP 192249 / e 205 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.691069e-01
# TIMESTEP 192295 / e 205 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.691877e-01
# TIMESTEP 192341 / e 205 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.692318e-01
# TIMESTEP 192387 / e 205 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.692500e-01
# TIMESTEP 192433 / e 205 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.692719e-01
# TIMESTEP 192479 / e 205 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.693532e-01
# TIMESTEP 192525 / e 205 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.694054e-01
# TIMESTEP 192571 / e 206 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.694159e-01
# TIMESTEP 192617 / e 206 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.695168e-01
# TIMESTEP 192663 / e 206 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.697996e-01
# TIMESTEP 192709 / e 206 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.700617e-01
# TIMESTEP 192755 / e 206 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.702510e-01
# TIMESTEP 192801 / e 206 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.703626e-01
# TIMESTEP 192847 / e 206 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.708918e-01
# TIMESTEP 192893 / e 206 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.713142e-01
# TIMESTEP 192939 / e 206 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.715119e-01
# TIMESTEP 192985 / e 206 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.716530e-01
# TIMESTEP 193031 / e 206 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.717150e-01
# TIMESTEP 193077 / e 206 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.717484e-01
# TIMESTEP 193123 / e 206 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.717534e-01
# TIMESTEP 193169 / e 206 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.717432e-01
# TIMESTEP 193215 / e 206 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.718433e-01
# TIMESTEP 193261 / e 206 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.719108e-01
# TIMESTEP 193307 / e 206 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.720403e-01
# TIMESTEP 193353 / e 206 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.723838e-01
# TIMESTEP 193399 / e 206 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.726151e-01
# TIMESTEP 193445 / e 206 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.728387e-01
# TIMESTEP 193491 / e 207 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.730508e-01
# TIMESTEP 193537 / e 207 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.732523e-01
# TIMESTEP 193583 / e 207 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.734119e-01
# TIMESTEP 193629 / e 207 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.734635e-01
# TIMESTEP 193675 / e 207 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.736935e-01
# TIMESTEP 193721 / e 207 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.738342e-01
# TIMESTEP 193767 / e 207 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.739791e-01
# TIMESTEP 193813 / e 207 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.740004e-01
# TIMESTEP 193859 / e 207 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.739971e-01
# TIMESTEP 193905 / e 207 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.740345e-01
# TIMESTEP 193951 / e 207 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.740962e-01
# TIMESTEP 193997 / e 207 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.741252e-01
# TIMESTEP 194043 / e 207 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.741524e-01
# TIMESTEP 194089 / e 207 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.741828e-01
# TIMESTEP 194135 / e 207 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.742754e-01
# TIMESTEP 194181 / e 207 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.744413e-01
# TIMESTEP 194227 / e 207 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.745529e-01
# TIMESTEP 194273 / e 207 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.746705e-01
# TIMESTEP 194319 / e 207 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.746588e-01
# TIMESTEP 194365 / e 207 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.746403e-01
# TIMESTEP 194411 / e 208 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.746208e-01
# TIMESTEP 194457 / e 208 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.746238e-01
# TIMESTEP 194503 / e 208 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.747048e-01
# TIMESTEP 194549 / e 208 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -4.747669e-01
# TIMESTEP 194595 / e 208 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -4.748909e-01
# TIMESTEP 194811 / e 208 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -4.757560e-01
# TIMESTEP 194857 / e 208 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -4.759972e-01
# TIMESTEP 194903 / e 208 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.762195e-01
# TIMESTEP 194949 / e 208 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.763231e-01
# TIMESTEP 194995 / e 208 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -4.763948e-01
# TIMESTEP 195041 / e 208 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.764214e-01
# TIMESTEP 195087 / e 208 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -4.764178e-01
# TIMESTEP 195133 / e 208 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.765182e-01
# TIMESTEP 195179 / e 208 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.766160e-01
# TIMESTEP 195225 / e 208 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -4.767345e-01
# TIMESTEP 195271 / e 208 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -4.767823e-01
# TIMESTEP 195317 / e 208 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -4.768054e-01
# TIMESTEP 195363 / e 208 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -4.769695e-01
# TIMESTEP 195409 / e 208 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.772115e-01
# TIMESTEP 195455 / e 208 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.774878e-01
# TIMESTEP 195501 / e 209 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -4.775955e-01
# TIMESTEP 195547 / e 209 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.776317e-01

# %%
JAI GURUDEV

# %% [markdown]
# # Back up code

# %%
tf.reset_default_graph()
s, readout, bs, r_conv_caps1, r_conv_caps2, r_class_caps, coord_add_op_class_caps = createNetwork()
# Out:
# (?, 12, 12, 32)
# 12
# (?, 12, 12, 8, 16)
# (?, 12, 12, 8, 1)
# (?, 12, 12, 136)
# (?, 5, 5, 136, 9) fdsggs
# 5
# 1 (?, 72, 17)
# output shape --------------- (?, 72, 17)
# activation shape---------------------- (?, 72, 1)
# w (1, 72, 16, 4, 4)
# w (?, 72, 16, 4, 4)
# (?, 72, 16, 16) votes shape
# Tensor("conv_caps1/v/tile___3/Reshape:0", shape=(?, 72, 16, 16), dtype=float32)  = votes
# (?, 72, 16) r shape__________
# (?, 72, 16, 1) r1
# (?, 72, 16) ap
# (?, 72, 16, 1) r1
# (?, 16, 1) r_sum
# (?, 16, 16) cost_h
# activation (?, 16)
# 3 (?, 5, 5, 16, 16)
# activation (?, 5, 5, 16, 1)
# 272
# 5 (?, 5, 5, 272)
# (?, 3, 3, 272, 9) fdsggs
# canv_caps2 (?, 144, 17) 3
# canv_caps2_activation (?, 144, 1) 3
# w (1, 144, 16, 4, 4)
# w (?, 144, 16, 4, 4)
# (?, 144, 16, 16) votes shape
# 144 for 1
# Tensor("conv_caps2/v/tile___3/Reshape:0", shape=(?, 144, 16, 16), dtype=float32)  = votes
# (?, 144, 16) r shape__________
# (?, 144, 16, 1) r1
# (?, 144, 16) ap
# (?, 144, 16, 1) r1
# (?, 16, 1) r_sum
# (?, 16, 16) cost_h
# 4 (?, 16, 16)
# 4 ---activation (?, 16, 1)
# w (1, 16, 10, 4, 4)
# w (?, 16, 10, 4, 4)
# (?, 16, 10, 16) votes.getshape
# (?, 16, 10, 18) coorr vote shape after  jnbfv
# _____ 16
# Tensor("class_caps/v/concat:0", shape=(?, 16, 10, 18), dtype=float32)  = votes
# (?, 16, 10) r shape__________
# (?, 16, 10, 1) r1
# (?, 16, 10) ap
# (?, 16, 10, 1) r1
# (?, 10, 1) r_sum
# (?, 10, 18) cost_h
# d op (?, 3, 3, 10)
# miu  2 (?, 1, 10, 18)
# output_size_posssss (?, 1, 1, 180)
# output_size (?, 10, 18)
# pose_out (?, 10, 18)
# vector_j (?, 180)
# output_size (?, 6)

# %%
tf.reset_default_graph()
#batch_size = 50
X = tf.placeholder(tf.float32, shape=(None, 80, 80, 1), name='X')
#X = tf.placeholder(tf.float32, shape=(batch_size, 80, 80, 4), name='X')
Y = tf.placeholder(tf.float32, [None, 10], name='Y')
#Y = tf.placeholder(tf.float32, [batch_size, 10], name='Y')
# -------------------------------------------------------------------------------------
bs = tf.placeholder(tf.int32, shape=(), name='bs')
#bs = batch_size
r_conv_caps1= tf.placeholder(tf.float32,[None, 72, C], name='r_conv_caps1') # 5*5*batch_size
#r_conv_caps1= tf.placeholder(tf.float32,[5*5*batch_size, 72, C], name='r_conv_caps1') # 5*5*batch_size

r_conv_caps2 = tf.placeholder(tf.float32,[None, 144, D], name='r_conv_caps2') # 3*3*batch_size
#r_conv_caps2 = tf.placeholder(tf.float32,[3*3*batch_size, 144, D], name='r_conv_caps2') # 3*3*batch_size

r_class_caps = tf.placeholder(tf.float32,[None, 16, num_classes], name='r_class_caps') # 3*3*batch_size
#r_class_caps = tf.placeholder(tf.float32,[3*3*batch_size, 16, num_classes], name='r_class_caps') # 3*3*batch_size

#coord_add_op_class_caps  = tf.placeholder(tf.float32,[3*3*batch_size, 16, num_classes, 2], name='coord_add_op_class_caps')
                                                                 # 3*3*batch_size
coord_add_op_class_caps  = tf.placeholder(tf.float32,[None, 16, num_classes, 2], name='coord_add_op_class_caps')
# 3*3*batch_size

# -------------------------------------------------------------------------------------
data_size = int(X.get_shape()[1])
# xavier initialization is necessary here to provide higher stability
initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)
# instead of initializing bias with constant 0, 
# a truncated normal initializer is exploited here for higher stability 
bias_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)  # tf.constant_initializer(0.0)
# The paper didnot mention any regularization, a common l2 regularizer to weights is added here
weights_regularizer = tf.contrib.layers.l2_regularizer(5e-04)
# weights_initializer=initializer,
with slim.arg_scope([slim.conv2d], trainable=is_train, biases_initializer=bias_initializer, weights_regularizer=weights_regularizer):
    with tf.variable_scope('relu_conv1'):
        output = slim.conv2d(X, num_outputs=A, kernel_size=[10, 10], stride=6, padding='VALID', scope='relu_conv1', activation_fn=tf.nn.relu)
        data_size = int(np.floor((data_size - 10) / 6)) + 1
        print(output.get_shape())
        print(data_size)
        #assert output.get_shape() == [batch_size, data_size, data_size, 32]
        votes__1 = output
    with tf.variable_scope('primary_caps'):
        pose = slim.conv2d(output, num_outputs=B * 16,kernel_size=[1, 1], stride=1, padding='VALID', scope='primary_caps', activation_fn=None)
        activation = slim.conv2d(output, num_outputs=B, kernel_size=[
                                 1, 1], stride=1, padding='VALID', scope='primary_caps/activation', activation_fn=tf.nn.sigmoid)
        pose = tf.reshape(pose, shape=[-1, data_size, data_size, B, 16]) # (50, 12, 12, 8, 16)
        
        print(pose.get_shape())
        activation = tf.reshape(activation, shape=[-1, data_size, data_size, B, 1]) # (50, 12, 12, 8, 1)
        print(activation.get_shape())
        output = tf.concat([pose, activation], axis=4)
        output = tf.reshape(output, shape=[-1, data_size, data_size, B * 17]) # (50, 12, 12, 136)
        print(output.get_shape())
        
        #assert output.get_shape() == [batch_size, data_size, data_size, B * 17]
    with tf.variable_scope('conv_caps1') as scope:
        output = kernel_tile(output, 3, 2)
        data_size = int(np.floor((data_size - 2) / 2))
        print(data_size) # 5 
        output = tf.reshape(output, shape=[-1, 3 * 3 * B, 17]) 
        # batch_size * data_size * data_size  (1250, 72, 17) 
        print("1",output.get_shape())
        activation = tf.reshape(output[:, :, 16], shape=[-1, 3 * 3 * B, 1])
        print("output shape ---------------",output.get_shape())
        print("activation shape----------------------",activation.get_shape()) #  (1250, 72, 1)
        
        with tf.variable_scope('v') as scope:
            votes = mat_transform(output[:, :, :16], C, weights_regularizer, bs = bs*data_size*data_size)
            #bs*data_size*data_size)
            
            print(votes.get_shape(),"votes shape")
        with tf.variable_scope('routing') as scope:
            caps_num_i = int(activation.get_shape()[1])
            
            miu, activation, _ = em_routing(votes, activation, C, weights_regularizer,r_conv_caps1)
            # miu, activation, _ = em_routing(votes, activation, C, weights_regularizer)
            print("activation",activation.get_shape())
        pose = tf.reshape(miu, shape=[-1, data_size, data_size, C, 16])
        print("3",pose.get_shape()) # 50, 5, 5, 16, 16)
        activation = tf.reshape(activation, shape=[-1, data_size, data_size, C, 1])
        print("activation",activation.get_shape())
        cat_size =  activation.get_shape()[3]*activation.get_shape()[4] + pose.get_shape()[3] *pose.get_shape()[4]
        print(cat_size)
        output = tf.reshape(tf.concat([pose, activation], axis=4),[-1, data_size, data_size, cat_size])
        print("5",output.get_shape()) # (50, 5, 5, 272)
        
        
    with tf.variable_scope('conv_caps2') as scope:
        output = kernel_tile(output, 3, 1)
        
        data_size = int(np.floor((data_size - 2) / 1))
        
        output = tf.reshape(output, shape=[-1, 3 * 3 * C, 17]) # batch_size * data_size * data_size
        print("canv_caps2",output.get_shape(), data_size)
        activation = tf.reshape(output[:, :, 16], shape=[-1 , 3 * 3 * C, 1]) # batch_size * data_size * data_size
        print("canv_caps2_activation",activation.get_shape(), data_size)
        
        with tf.variable_scope('v') as scope:
            votes = mat_transform(output[:, :, :16], D, weights_regularizer,bs = bs*data_size*data_size)
            print(votes.get_shape(),"votes shape")
            
        with tf.variable_scope('routing') as scope:
            caps_num_i = int(activation.get_shape()[1])
            print(caps_num_i,"for 1")
            miu, activation, _ = em_routing(votes, activation, D, weights_regularizer, r_conv_caps2)

        pose = tf.reshape(miu, shape=[-1, D, 16]) # batch_size * data_size * data_size
        print("4",pose.get_shape())
        #tf.logging.info('conv cap 2 pose shape: {}'.format(votes.get_shape()))
        activation = tf.reshape(activation, shape=[-1, D, 1]) # batch_size * data_size * data_size
        print("4 ---activation",activation.get_shape())
        
    with tf.variable_scope('class_caps') as scope:
        with tf.variable_scope('v') as scope:
            votes = mat_transform(pose, num_classes, weights_regularizer,bs = bs*data_size*data_size)
            print(votes.get_shape(),"votes.getshape")
            assert votes.get_shape()[1:] == [D, num_classes, 16]
            #tf.logging.info('class cap votes original shape: {}'.format(votes.get_shape()))
            '''coord_add = get_coord_add('mnist') 
            coord_add = np.reshape(coord_add, newshape=[data_size * data_size, 1, 1, 2])
            coord_add = np.tile(coord_add, [bs, D, num_classes, 1])
            coord_add_op = tf.constant(coord_add, dtype=tf.float32)
            print("___coord_add______",coord_add_op.shape)'''
            
            votes = tf.concat([coord_add_op_class_caps, votes], axis=3)
            #tf.logging.info('class cap votes coord add shape: {}'.format(votes.get_shape()))
            print(votes.get_shape(),"coorr vote shape after  jnbfv")
        with tf.variable_scope('routing') as scope:
            caps_num_i = int(activation.get_shape()[1])
            print("_____",caps_num_i)
            miu, activation, test2 = em_routing(votes, activation, num_classes, weights_regularizer,r_class_caps)
            
        output = tf.reshape(activation, shape=[-1, data_size, data_size, num_classes]) #batch_size
        print("d op",output.get_shape())
    output = tf.reshape(tf.nn.avg_pool(output, ksize=[1, data_size, data_size, 1], strides=[
                1, 1, 1, 1], padding='VALID'), shape=[-1, num_classes]) # batch_size
    print("miu  2",miu.get_shape())
    pose = tf.nn.avg_pool(tf.reshape(miu, shape=[-1, data_size, data_size,miu.get_shape()[2]*miu.get_shape()[3]
                                ]), ksize=[1, data_size, data_size, 1], strides=[1, 1, 1, 1], padding='VALID')
    print("output_size_posssss",pose.get_shape())
    #miu  2 (450, 1, 10, 18)
    #output_size_posssss (50, 1, 1, 180)
    pose_out = tf.reshape(pose, shape=[-1, num_classes, 18])
    print("output_size",pose_out.get_shape())
    vector_j = tf.reshape(pose_out, shape= [-1, num_classes * 18])
    print("pose_out",pose_out.get_shape())
    print("vector_j",vector_j.get_shape())
with tf.variable_scope('output_layer') as scope:
    logits = tf.contrib.layers.fully_connected(vector_j, num_outputs=ACTIONS, activation_fn=None)
print("output_size",logits.get_shape())
# Out:
# (?, 12, 12, 32)
# 12
# (?, 12, 12, 8, 16)
# (?, 12, 12, 8, 1)
# (?, 12, 12, 136)
# (?, 5, 5, 136, 9) fdsggs
# 5
# 1 (?, 72, 17)
# output shape --------------- (?, 72, 17)
# activation shape---------------------- (?, 72, 1)
# w (1, 72, 16, 4, 4)
# w (?, 72, 16, 4, 4)
# (?, 72, 16, 16) votes shape
# Tensor("conv_caps1/v/tile___3/Reshape:0", shape=(?, 72, 16, 16), dtype=float32)  = votes
# (?, 72, 16) r shape__________
# (?, 72, 16, 1) r1
# (?, 72, 16) ap
# (?, 72, 16, 1) r1
# (?, 16, 1) r_sum
# (?, 16, 16) cost_h
# activation (?, 16)
# 3 (?, 5, 5, 16, 16)
# activation (?, 5, 5, 16, 1)
# 272
# 5 (?, 5, 5, 272)
# (?, 3, 3, 272, 9) fdsggs
# canv_caps2 (?, 144, 17) 3
# canv_caps2_activation (?, 144, 1) 3
# w (1, 144, 16, 4, 4)
# w (?, 144, 16, 4, 4)
# (?, 144, 16, 16) votes shape
# 144 for 1
# Tensor("conv_caps2/v/tile___3/Reshape:0", shape=(?, 144, 16, 16), dtype=float32)  = votes
# (?, 144, 16) r shape__________
# (?, 144, 16, 1) r1
# (?, 144, 16) ap
# (?, 144, 16, 1) r1
# (?, 16, 1) r_sum
# (?, 16, 16) cost_h
# 4 (?, 16, 16)
# 4 ---activation (?, 16, 1)
# w (1, 16, 10, 4, 4)
# w (?, 16, 10, 4, 4)
# (?, 16, 10, 16) votes.getshape
# (?, 16, 10, 18) coorr vote shape after  jnbfv
# _____ 16
# Tensor("class_caps/v/concat:0", shape=(?, 16, 10, 18), dtype=float32)  = votes
# (?, 16, 10) r shape__________
# (?, 16, 10, 1) r1
# (?, 16, 10) ap
# (?, 16, 10, 1) r1
# (?, 10, 1) r_sum
# (?, 10, 18) cost_h
# d op (?, 3, 3, 10)
# miu  2 (?, 1, 10, 18)
# output_size_posssss (?, 1, 1, 180)
# output_size (?, 10, 18)
# pose_out (?, 10, 18)
# vector_j (?, 180)
# output_size (?, 6)

# %%
(50, 12, 12, 32)
final shape pose (50, 12, 12, 128)
final shape activation (50, 12, 12, 8)
(50, 12, 12, 8, 16)
(50, 12, 12, 8, 1)
(50, 12, 12, 136)
# Out:
#   File "<ipython-input-62-3a57a218cc8c>", line 2
#     final shape pose (50, 12, 12, 128)
#               ^
# SyntaxError: invalid syntax
