# %% [markdown]
# # Capsule Network for RL

# %%
import tensorflow as tf
import cv2
import sys
import pong_fun as game # whichever is imported "as game" will be used
import random
import time 
import numpy as np
from collections import deque
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
epsilon = 1e-9
iter_routing = 2
train_freq = 10

# %%
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 1000. # timesteps to observe before training
EXPLORE = 5000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.05 # final value of epsilon
INITIAL_EPSILON = 1.0 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch

# %% [markdown]
# # UPDATED CAPSULE NETWORK

# %%
def squash(vector):
    vec_squared_norm = reduce_sum(tf.square(vector), -2, keepdims=True)
    scalar_factor = vec_squared_norm / (1 + vec_squared_norm) / tf.sqrt(vec_squared_norm + epsilon)
    vec_squashed = scalar_factor * vector  # element-wise
    return(vec_squashed)
def routing(input, b_IJ):
    # W: [1, num_caps_i, num_caps_j * len_v_j, len_u_j, 1]
    W = tf.get_variable('Weight', shape=(1, 1024, 160, 8, 1), dtype=tf.float32,
                        initializer=tf.random_normal_initializer(stddev=0.01))
    biases = tf.get_variable('bias', shape=(1, 1, 10, 16, 1))
    # A better solution is using element-wise multiply, reduce_sum and reshape
    # ops instead. Matmul [a, b] x [b, c] is equal to a series ops as
    # element-wise multiply [a*c, b] * [a*c, b], reduce_sum at axis=1 and
    # reshape to [a, c]
    input = tf.tile(input, [1, 1, 160, 1, 1])
    #assert input.get_shape() == [cfg.batch_size, 1024, 160, 8, 1]

    u_hat = reduce_sum(W * input, axis=3, keepdims=True)
    u_hat = tf.reshape(u_hat, shape=[-1, 1024, 10, 16, 1])
    #assert u_hat.get_shape() == [cfg.batch_size, 1024, 10, 16, 1]

    # In forward, u_hat_stopped = u_hat; in backward, no gradient passed back from u_hat_stopped to u_hat
    u_hat_stopped = tf.stop_gradient(u_hat, name='stop_gradient')

    # line 3,for r iterations do
    for r_iter in range(iter_routing):
        with tf.variable_scope('iter_' + str(r_iter)):
            # line 4:
            # => [batch_size, 1024, 10, 1, 1]
            c_IJ = softmax(b_IJ, axis=2)

            # At last iteration, use `u_hat` in order to receive gradients from the following graph
            if r_iter == iter_routing - 1:
                # line 5:
                # weighting u_hat with c_IJ, element-wise in the last two dims
                # => [batch_size, 1024, 10, 16, 1]
                s_J = tf.multiply(c_IJ, u_hat)
                # then sum in the second dim, resulting in [batch_size, 1, 10, 16, 1]
                s_J = reduce_sum(s_J, axis=1, keepdims=True) + biases
                #assert s_J.get_shape() == [cfg.batch_size, 1, 10, 16, 1]

                # line 6:
                # squash using Eq.1,
                v_J = squash(s_J)
                #assert v_J.get_shape() == [cfg.batch_size, 1, 10, 16, 1]
            elif r_iter < iter_routing - 1:  # Inner iterations, do not apply backpropagation
                s_J = tf.multiply(c_IJ, u_hat_stopped)
                s_J = reduce_sum(s_J, axis=1, keepdims=True) + biases
                v_J = squash(s_J)

                # line 7:
                # reshape & tile v_j from [batch_size ,1, 10, 16, 1] to [batch_size, 1024, 10, 16, 1]
                # then matmul in the last tow dim: [16, 1].T x [16, 1] => [1, 1], reduce mean in the
                # batch_size dim, resulting in [1, 1024, 10, 1, 1]
                v_J_tiled = tf.tile(v_J, [1, 1024, 1, 1, 1])
                u_produce_v = reduce_sum(u_hat_stopped * v_J_tiled, axis=3, keepdims=True)
                #assert u_produce_v.get_shape() == [cfg.batch_size, 1024, 10, 1, 1]

                # b_IJ += tf.reduce_sum(u_produce_v, axis=0, keep_dims=True)
                b_IJ += u_produce_v
    return(v_J)
# For version compatibility
def reduce_sum(input_tensor, axis=None, keepdims=False):
    return tf.reduce_sum(input_tensor, axis=axis, keepdims=keepdims)
# For version compatibility
def softmax(logits, axis=None):
    return tf.nn.softmax(logits, axis=axis)

# %%
def createNetwork():
    # input layer
    s= tf.placeholder("float", [None, 84, 84, 4])
    coeff = tf.placeholder(tf.float32, shape=(None, 1024, 10, 1, 1))
    ####################### New Network COnfiguration #####################    
    w_initializer, b_initializer = tf.random_normal_initializer(0., 0.01), tf.constant_initializer(0.01)
    w1 = tf.get_variable('w1',[8, 8, 4, 64],initializer=w_initializer)
    b1 = tf.get_variable('b1',[64],initializer=b_initializer)
    # Convolution Layer
    # Conv1, [batch_size, 20, 20, 64]
    l1 = tf.nn.conv2d(s, w1, strides=[1, 4, 4, 1], padding="VALID")
    
    conv1 = tf.nn.relu(tf.nn.bias_add(l1, b1))
    
    conv1 = tf.reshape(conv1,[-1,20,20,64])
    
    capsules = tf.contrib.layers.conv2d(conv1, 16 * 8, kernel_size=6, stride=2, padding="VALID",
                    activation_fn = tf.nn.relu,
                    weights_initializer = tf.contrib.layers.xavier_initializer(uniform=False),
                    biases_initializer=tf.constant_initializer(0))
    
    capsules = tf.reshape(capsules, (-1, 1024, 8, 1)) #Reshape to(batch_szie, 1152, 8, 1)
    
    capsules = squash(capsules)
    
    input_caps2 = tf.reshape(capsules, shape=(-1, 1024, 1, capsules.shape[-2].value, 1))
    
    caps2 = routing(input_caps2, coeff)
    
    vector_j = tf.reshape(caps2, shape=(-1, 160))
    print(vector_j)
    q_eval = tf.contrib.layers.fully_connected(vector_j, num_outputs=ACTIONS, activation_fn=None)

    print(q_eval)
    readout = q_eval
    return s, coeff, readout

# %%
def trainNetwork(s, coeff, readout, sess):
    tick = time.time()
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices = 1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()
    # store the previous observations in replay memory
    D = deque()
    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal, bar1_score, bar2_score = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (84, 84)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)  
    # saving and loading networks
    # saver = tf.train.Saver()
    # sess.run(tf.initialize_all_variables())
    sess.run(tf.global_variables_initializer())
    b_IJ1 = np.zeros((1, 1024, 10, 1, 1)).astype(np.float32) # batch_size=1
    b_IJ2 = np.zeros((BATCH, 1024, 10, 1, 1)).astype(np.float32) # batch_size=BATCH
    epsilon = INITIAL_EPSILON
    t = 0
    episode = 0
    while True:
        # choose an action epsilon greedily
        # readout_t = readout.eval(feed_dict = {s : [s_t].reshape((1,80,80,4))})[0]
        
        readout_t = readout.eval(feed_dict = {s:s_t.reshape((1,84,84,4)), coeff:b_IJ1})
        
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if random.random() <= epsilon or t <= OBSERVE:
            action_index = random.randrange(ACTIONS)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(readout_t)
            a_t[action_index] = 1

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # run the selected action and observe next state and reward
        x_t1_col, r_t, terminal, bar1_score, bar2_score = game_state.frame_step(a_t)
        if(terminal == 1):
            episode +=1
        x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (84, 84)), cv2.COLOR_BGR2GRAY)
        ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
        x_t1 = np.reshape(x_t1, (84, 84, 1))
        s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)

        # store the transition in D
        D.append((s_t, a_t, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()
        
        # only train if done observing
        if t > OBSERVE and t%train_freq==0:
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s:s_j1_batch, coeff:b_IJ2 })
            #readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch,
                coeff: b_IJ2})

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        #if t % 10000 == 0:
        #    saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)
        if r_t!= 0:
            print ("TIMESTEP", t, "/ e", episode, "/ bar1_score", bar1_score, "/ bar2_score", bar2_score, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t))

        if( (bar1_score - bar2_score) > 18): 
            print("Game_Ends_in Time:",int(time.time() - tick))
            break;   
            
        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

# %%
def playGame():
    tf.reset_default_graph()
    sess = tf.InteractiveSession()
    s, coeff, readout = createNetwork()
    trainNetwork(s, coeff, readout, sess)

# %%
def main():
    playGame()

if __name__ == "__main__":
    tick = time.time()
    main()
    print("Game_Ends_in Time:",int(time.time() - tick))
    print("____________ END HERE _____________")
# Out:
# Tensor("Reshape_4:0", shape=(?, 160), dtype=float32)
# Tensor("fully_connected/BiasAdd:0", shape=(?, 6), dtype=float32)
# TIMESTEP 129 / e 0 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 7.505484e-02
# TIMESTEP 175 / e 0 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 8.441585e-02
# TIMESTEP 221 / e 0 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 7.697585e-02
# TIMESTEP 267 / e 0 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 8.209936e-02
# TIMESTEP 313 / e 0 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 7.899049e-02
# TIMESTEP 359 / e 0 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 8.756793e-02
# TIMESTEP 405 / e 0 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 8.355741e-02
# TIMESTEP 451 / e 0 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 8.483987e-02
# TIMESTEP 497 / e 0 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 8.355837e-02
# TIMESTEP 543 / e 0 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 8.666156e-02
# TIMESTEP 589 / e 0 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 8.064666e-02
# TIMESTEP 635 / e 0 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 8.101321e-02
# TIMESTEP 681 / e 0 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 8.205989e-02
# TIMESTEP 727 / e 0 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 7.835755e-02
# TIMESTEP 773 / e 0 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 8.215580e-02
# TIMESTEP 819 / e 0 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 8.138028e-02
# TIMESTEP 865 / e 0 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 8.217647e-02
# TIMESTEP 911 / e 0 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 8.194131e-02
# TIMESTEP 957 / e 0 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 8.156504e-02
# TIMESTEP 1003 / e 1 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 8.889616e-02
# TIMESTEP 1049 / e 1 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.291275e-01
# TIMESTEP 1095 / e 1 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.136976e-01
# TIMESTEP 1141 / e 1 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 3.377466e-01
# TIMESTEP 1187 / e 1 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 4.719657e-01
# TIMESTEP 1233 / e 1 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 6.245111e-01
# TIMESTEP 1279 / e 1 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 7.205823e-01
# TIMESTEP 1325 / e 1 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 8.977579e-01
# TIMESTEP 1371 / e 1 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.008305e+00
# TIMESTEP 1417 / e 1 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.150118e+00
# TIMESTEP 1463 / e 1 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.258161e+00
# TIMESTEP 1509 / e 1 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.308318e+00
# TIMESTEP 1555 / e 1 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.363135e+00
# TIMESTEP 1601 / e 1 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.387657e+00
# TIMESTEP 1732 / e 1 / bar1_score 1 / bar2_score 13 / REWARD 1 / Q_MAX 1.440136e+00
# TIMESTEP 1861 / e 1 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 1.426173e+00
# TIMESTEP 1907 / e 1 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 1.434892e+00
# TIMESTEP 1953 / e 1 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.446800e+00
# TIMESTEP 1999 / e 1 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.472187e+00
# TIMESTEP 2045 / e 1 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.530397e+00
# TIMESTEP 2091 / e 1 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.579741e+00
# TIMESTEP 2304 / e 2 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.675001e+00
# TIMESTEP 2350 / e 2 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.748908e+00
# TIMESTEP 2396 / e 2 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.709129e+00
# TIMESTEP 2442 / e 2 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.785261e+00
# TIMESTEP 2488 / e 2 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.774413e+00
# TIMESTEP 2534 / e 2 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.777232e+00
# TIMESTEP 2580 / e 2 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.853736e+00
# TIMESTEP 2626 / e 2 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.827799e+00
# TIMESTEP 2672 / e 2 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.795698e+00
# TIMESTEP 2718 / e 2 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.824600e+00
# TIMESTEP 2764 / e 2 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.830588e+00
# TIMESTEP 2810 / e 2 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.873310e+00
# TIMESTEP 2856 / e 2 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.915352e+00
# TIMESTEP 2902 / e 2 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.869061e+00
# TIMESTEP 2948 / e 2 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.860029e+00
# TIMESTEP 2994 / e 2 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.864357e+00
# TIMESTEP 3040 / e 2 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.951228e+00
# TIMESTEP 3086 / e 2 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.903483e+00
# TIMESTEP 3132 / e 2 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.892042e+00
# TIMESTEP 3178 / e 2 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.918061e+00
# TIMESTEP 3224 / e 3 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.946929e+00
# TIMESTEP 3270 / e 3 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.946848e+00
# TIMESTEP 3316 / e 3 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.903388e+00
# TIMESTEP 3445 / e 3 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX 1.915056e+00
# TIMESTEP 3828 / e 3 / bar1_score 2 / bar2_score 2 / REWARD 1 / Q_MAX 1.906268e+00
# TIMESTEP 3957 / e 3 / bar1_score 2 / bar2_score 3 / REWARD -1 / Q_MAX 1.959885e+00
# TIMESTEP 4003 / e 3 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 2.017633e+00
# TIMESTEP 4049 / e 3 / bar1_score 2 / bar2_score 5 / REWARD -1 / Q_MAX 2.039189e+00
# TIMESTEP 4095 / e 3 / bar1_score 2 / bar2_score 6 / REWARD -1 / Q_MAX 1.995008e+00
# TIMESTEP 4141 / e 3 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 1.973908e+00
# TIMESTEP 4187 / e 3 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 2.030490e+00
# TIMESTEP 4233 / e 3 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 2.022845e+00
# TIMESTEP 4279 / e 3 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 2.069130e+00
# TIMESTEP 4325 / e 3 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 2.029059e+00
# TIMESTEP 4371 / e 3 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.985775e+00
# TIMESTEP 4417 / e 3 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 2.011693e+00
# TIMESTEP 4463 / e 3 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 2.036422e+00
# TIMESTEP 4509 / e 3 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 2.038101e+00
# TIMESTEP 4555 / e 3 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 2.060868e+00
# TIMESTEP 4601 / e 3 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 2.024790e+00
# TIMESTEP 4647 / e 3 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 2.081318e+00
# TIMESTEP 4693 / e 3 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 2.043616e+00
# TIMESTEP 4824 / e 3 / bar1_score 3 / bar2_score 19 / REWARD 1 / Q_MAX 2.025720e+00
# TIMESTEP 4953 / e 4 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.049492e+00
# TIMESTEP 4999 / e 4 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.006788e+00
# TIMESTEP 5045 / e 4 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.982480e+00
# TIMESTEP 5091 / e 4 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.046742e+00
# TIMESTEP 5137 / e 4 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.018316e+00
# TIMESTEP 5183 / e 4 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.075197e+00
# TIMESTEP 5397 / e 4 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 2.056491e+00
# TIMESTEP 5443 / e 4 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 2.083023e+00
# TIMESTEP 5489 / e 4 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.004580e+00
# TIMESTEP 5535 / e 4 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.015596e+00
# TIMESTEP 5581 / e 4 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.053529e+00
# TIMESTEP 5627 / e 4 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 2.026624e+00
# TIMESTEP 5673 / e 4 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 2.018518e+00
# TIMESTEP 5719 / e 4 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 2.118860e+00
# TIMESTEP 5765 / e 4 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 2.032273e+00
# TIMESTEP 5811 / e 4 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 2.022390e+00
# TIMESTEP 5857 / e 4 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 2.043667e+00
# TIMESTEP 5903 / e 4 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 2.049613e+00
# TIMESTEP 5949 / e 4 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 2.003599e+00
# TIMESTEP 5995 / e 4 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 2.038406e+00
# TIMESTEP 6041 / e 5 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.017385e+00
# TIMESTEP 6087 / e 5 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.041587e+00
# TIMESTEP 6133 / e 5 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.012958e+00
# TIMESTEP 6179 / e 5 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.101731e+00
# TIMESTEP 6225 / e 5 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.032404e+00
# TIMESTEP 6271 / e 5 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.083940e+00
# TIMESTEP 6487 / e 5 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 2.037361e+00
# TIMESTEP 6533 / e 5 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 2.114208e+00
# TIMESTEP 6579 / e 5 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.090528e+00
# TIMESTEP 6708 / e 5 / bar1_score 1 / bar2_score 8 / REWARD 1 / Q_MAX 2.105932e+00
# TIMESTEP 6837 / e 5 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 2.096428e+00
# TIMESTEP 6966 / e 5 / bar1_score 2 / bar2_score 9 / REWARD 1 / Q_MAX 2.072861e+00
# TIMESTEP 7263 / e 5 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 2.134658e+00
# TIMESTEP 7476 / e 5 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 2.155907e+00
# TIMESTEP 7522 / e 5 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 2.153911e+00
# TIMESTEP 7736 / e 5 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 2.173222e+00
# TIMESTEP 7782 / e 5 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 2.157580e+00
# TIMESTEP 7828 / e 5 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 2.154382e+00
# TIMESTEP 7874 / e 5 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 2.155215e+00
# TIMESTEP 7920 / e 5 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 2.135443e+00
# TIMESTEP 7966 / e 5 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 2.137602e+00
# TIMESTEP 8012 / e 5 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 2.127243e+00
# TIMESTEP 8058 / e 6 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.151425e+00
# TIMESTEP 8104 / e 6 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.168492e+00
# TIMESTEP 8235 / e 6 / bar1_score 1 / bar2_score 1 / REWARD 1 / Q_MAX 2.157033e+00
# TIMESTEP 8616 / e 6 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 2.070416e+00
# TIMESTEP 8745 / e 6 / bar1_score 2 / bar2_score 2 / REWARD -1 / Q_MAX 2.166539e+00
# TIMESTEP 8791 / e 6 / bar1_score 2 / bar2_score 3 / REWARD -1 / Q_MAX 2.185122e+00
# TIMESTEP 8837 / e 6 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 2.162186e+00
# TIMESTEP 8883 / e 6 / bar1_score 2 / bar2_score 5 / REWARD -1 / Q_MAX 2.124943e+00
# TIMESTEP 8929 / e 6 / bar1_score 2 / bar2_score 6 / REWARD -1 / Q_MAX 2.156127e+00
# TIMESTEP 8975 / e 6 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 2.165474e+00
# TIMESTEP 9021 / e 6 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 2.169102e+00
# TIMESTEP 9067 / e 6 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 2.153160e+00
# TIMESTEP 9280 / e 6 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 2.153644e+00
# TIMESTEP 9409 / e 6 / bar1_score 3 / bar2_score 10 / REWARD 1 / Q_MAX 2.166243e+00
# TIMESTEP 9538 / e 6 / bar1_score 3 / bar2_score 11 / REWARD -1 / Q_MAX 2.168079e+00
# TIMESTEP 9584 / e 6 / bar1_score 3 / bar2_score 12 / REWARD -1 / Q_MAX 2.151474e+00
# TIMESTEP 9630 / e 6 / bar1_score 3 / bar2_score 13 / REWARD -1 / Q_MAX 2.122894e+00
# TIMESTEP 9676 / e 6 / bar1_score 3 / bar2_score 14 / REWARD -1 / Q_MAX 2.120777e+00
# TIMESTEP 9722 / e 6 / bar1_score 3 / bar2_score 15 / REWARD -1 / Q_MAX 2.079638e+00
# TIMESTEP 9768 / e 6 / bar1_score 3 / bar2_score 16 / REWARD -1 / Q_MAX 2.093154e+00
# TIMESTEP 9814 / e 6 / bar1_score 3 / bar2_score 17 / REWARD -1 / Q_MAX 2.135300e+00
# TIMESTEP 9860 / e 6 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX 2.119470e+00
# TIMESTEP 9906 / e 6 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 2.164144e+00
# TIMESTEP 9952 / e 7 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.158785e+00
# TIMESTEP 9998 / e 7 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.155529e+00
# TIMESTEP 10044 / e 7 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.105386e+00
# TIMESTEP 10090 / e 7 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.137554e+00
# TIMESTEP 10136 / e 7 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.146356e+00
# TIMESTEP 10182 / e 7 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.168822e+00
# TIMESTEP 10311 / e 7 / bar1_score 1 / bar2_score 5 / REWARD 1 / Q_MAX 2.123356e+00
# TIMESTEP 10608 / e 7 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 2.119216e+00
# TIMESTEP 10654 / e 7 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 2.069120e+00
# TIMESTEP 10783 / e 7 / bar1_score 2 / bar2_score 7 / REWARD 1 / Q_MAX 2.065528e+00
# TIMESTEP 10912 / e 7 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 2.112130e+00
# TIMESTEP 10958 / e 7 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 2.098040e+00
# TIMESTEP 11004 / e 7 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 2.051872e+00
# TIMESTEP 11050 / e 7 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 2.110685e+00
# TIMESTEP 11096 / e 7 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 2.036183e+00
# TIMESTEP 11142 / e 7 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 2.000008e+00
# TIMESTEP 11188 / e 7 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 2.041556e+00
# TIMESTEP 11234 / e 7 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 2.083064e+00
# TIMESTEP 11280 / e 7 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 2.019438e+00
# TIMESTEP 11326 / e 7 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 2.082400e+00
# TIMESTEP 11372 / e 7 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 2.099660e+00
# TIMESTEP 11418 / e 7 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 2.092427e+00
# TIMESTEP 11464 / e 8 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.091906e+00
# TIMESTEP 11510 / e 8 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.078242e+00
# TIMESTEP 11556 / e 8 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.071129e+00
# TIMESTEP 11602 / e 8 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.104908e+00
# TIMESTEP 11648 / e 8 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.077453e+00
# TIMESTEP 11694 / e 8 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.057691e+00
# TIMESTEP 11740 / e 8 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 2.086217e+00
# TIMESTEP 11786 / e 8 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 2.105676e+00
# TIMESTEP 11832 / e 8 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.087041e+00
# TIMESTEP 11878 / e 8 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.087740e+00
# TIMESTEP 11924 / e 8 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.061332e+00
# TIMESTEP 11970 / e 8 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 2.083761e+00
# TIMESTEP 12016 / e 8 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 2.102168e+00
# TIMESTEP 12062 / e 8 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 2.113557e+00
# TIMESTEP 12108 / e 8 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 2.070138e+00
# TIMESTEP 12154 / e 8 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 2.048529e+00
# TIMESTEP 12200 / e 8 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 2.058128e+00
# TIMESTEP 12246 / e 8 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 2.038544e+00
# TIMESTEP 12292 / e 8 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 2.099584e+00
# TIMESTEP 12338 / e 8 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 2.062430e+00
# TIMESTEP 12552 / e 9 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.098321e+00
# TIMESTEP 12598 / e 9 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.058228e+00
# TIMESTEP 12644 / e 9 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.996181e+00
# TIMESTEP 12690 / e 9 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.111104e+00
# TIMESTEP 12736 / e 9 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.090608e+00
# TIMESTEP 12782 / e 9 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.024384e+00
# TIMESTEP 12828 / e 9 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 2.058839e+00
# TIMESTEP 12874 / e 9 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 2.115083e+00
# TIMESTEP 12920 / e 9 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.101838e+00
# TIMESTEP 12966 / e 9 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.097155e+00
# TIMESTEP 13264 / e 9 / bar1_score 1 / bar2_score 9 / REWARD 1 / Q_MAX 2.178133e+00
# TIMESTEP 13393 / e 9 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 2.257582e+00
# TIMESTEP 13439 / e 9 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 2.282442e+00
# TIMESTEP 13485 / e 9 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 2.220992e+00
# TIMESTEP 13531 / e 9 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 2.277754e+00
# TIMESTEP 13577 / e 9 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 2.214921e+00
# TIMESTEP 13623 / e 9 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 2.229576e+00
# TIMESTEP 13669 / e 9 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 2.237151e+00
# TIMESTEP 13715 / e 9 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 2.238285e+00
# TIMESTEP 13761 / e 9 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 2.224105e+00
# TIMESTEP 13807 / e 9 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 2.214803e+00
# TIMESTEP 13853 / e 10 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.151228e+00
# TIMESTEP 13899 / e 10 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.175052e+00
# TIMESTEP 13945 / e 10 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.144855e+00
# TIMESTEP 13991 / e 10 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.145145e+00
# TIMESTEP 14037 / e 10 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.213433e+00
# TIMESTEP 14083 / e 10 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 2.155340e+00
# TIMESTEP 14129 / e 10 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 2.163266e+00
# TIMESTEP 14175 / e 10 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 2.178009e+00
# TIMESTEP 14221 / e 10 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.135597e+00
# TIMESTEP 14267 / e 10 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.170757e+00
# TIMESTEP 14313 / e 10 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.163191e+00
# TIMESTEP 14359 / e 10 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 2.130763e+00
# TIMESTEP 14405 / e 10 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 2.102471e+00
# TIMESTEP 14451 / e 10 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 2.111794e+00
# TIMESTEP 14497 / e 10 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 2.178604e+00
# TIMESTEP 14626 / e 10 / bar1_score 1 / bar2_score 14 / REWARD 1 / Q_MAX 2.105960e+00
# TIMESTEP 14755 / e 10 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 2.149239e+00
# TIMESTEP 14801 / e 10 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 2.054063e+00
# TIMESTEP 14847 / e 10 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 2.098953e+00
# TIMESTEP 14893 / e 10 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 2.023729e+00
# TIMESTEP 14939 / e 10 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 2.055053e+00
# TIMESTEP 14985 / e 11 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.091181e+00
# TIMESTEP 15031 / e 11 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.108660e+00
# TIMESTEP 15077 / e 11 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.048481e+00
# TIMESTEP 15123 / e 11 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.115579e+00
# TIMESTEP 15252 / e 11 / bar1_score 1 / bar2_score 3 / REWARD 1 / Q_MAX 2.132751e+00
# TIMESTEP 15381 / e 11 / bar1_score 1 / bar2_score 4 / REWARD -1 / Q_MAX 2.061376e+00
# TIMESTEP 15427 / e 11 / bar1_score 1 / bar2_score 5 / REWARD -1 / Q_MAX 1.982868e+00
# TIMESTEP 15473 / e 11 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 1.902517e+00
# TIMESTEP 15519 / e 11 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 1.851498e+00
# TIMESTEP 15565 / e 11 / bar1_score 1 / bar2_score 8 / REWARD -1 / Q_MAX 1.889540e+00
# TIMESTEP 15611 / e 11 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 1.973756e+00
# TIMESTEP 15657 / e 11 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 2.042916e+00
# TIMESTEP 15703 / e 11 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 2.046859e+00
# TIMESTEP 15749 / e 11 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 1.990634e+00
# TIMESTEP 15795 / e 11 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 2.003854e+00
# TIMESTEP 15841 / e 11 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 2.003365e+00
# TIMESTEP 15887 / e 11 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 2.000279e+00
# TIMESTEP 15933 / e 11 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.955246e+00
# TIMESTEP 15979 / e 11 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.899666e+00
# TIMESTEP 16025 / e 11 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.900702e+00
# TIMESTEP 16071 / e 11 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.912099e+00
# TIMESTEP 16117 / e 12 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.903333e+00
# TIMESTEP 16163 / e 12 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.002541e+00
# TIMESTEP 16376 / e 12 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.761042e+00
# TIMESTEP 16422 / e 12 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.899485e+00
# TIMESTEP 16468 / e 12 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.816483e+00
# TIMESTEP 16514 / e 12 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.752356e+00
# TIMESTEP 16560 / e 12 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.837000e+00
# TIMESTEP 16689 / e 12 / bar1_score 1 / bar2_score 6 / REWARD 1 / Q_MAX 1.859035e+00
# TIMESTEP 16818 / e 12 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 1.564996e+00
# TIMESTEP 16864 / e 12 / bar1_score 1 / bar2_score 8 / REWARD -1 / Q_MAX 1.364890e+00
# TIMESTEP 16910 / e 12 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 1.436421e+00
# TIMESTEP 16956 / e 12 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 1.615066e+00
# TIMESTEP 17002 / e 12 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.548807e+00
# TIMESTEP 17133 / e 12 / bar1_score 2 / bar2_score 11 / REWARD 1 / Q_MAX 1.703807e+00
# TIMESTEP 17262 / e 12 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.722905e+00
# TIMESTEP 17308 / e 12 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 1.590578e+00
# TIMESTEP 17354 / e 12 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.678791e+00
# TIMESTEP 17400 / e 12 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 1.723409e+00
# TIMESTEP 17446 / e 12 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 1.703181e+00
# TIMESTEP 17492 / e 12 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 1.772523e+00
# TIMESTEP 17538 / e 12 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 1.831110e+00
# TIMESTEP 17584 / e 12 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 1.664451e+00
# TIMESTEP 17630 / e 13 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.572743e+00
# TIMESTEP 17676 / e 13 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.536187e+00
# TIMESTEP 17722 / e 13 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.519856e+00
# TIMESTEP 17768 / e 13 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.731482e+00
# TIMESTEP 17814 / e 13 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.479931e+00
# TIMESTEP 17860 / e 13 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.523275e+00
# TIMESTEP 17906 / e 13 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.428587e+00
# TIMESTEP 17952 / e 13 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.401969e+00
# TIMESTEP 17998 / e 13 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.404857e+00
# TIMESTEP 18044 / e 13 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.433297e+00
# TIMESTEP 18090 / e 13 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.416488e+00
# TIMESTEP 18136 / e 13 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.500304e+00
# TIMESTEP 18182 / e 13 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.418557e+00
# TIMESTEP 18314 / e 13 / bar1_score 1 / bar2_score 12 / REWARD 1 / Q_MAX 1.958341e+00
# TIMESTEP 18611 / e 13 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 1.667294e+00
# TIMESTEP 18657 / e 13 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 1.260890e+00
# TIMESTEP 18703 / e 13 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 1.114262e+00
# TIMESTEP 18749 / e 13 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.094152e+00
# TIMESTEP 18795 / e 13 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.068085e+00
# TIMESTEP 18841 / e 13 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.245030e+00
# TIMESTEP 18887 / e 13 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.176573e+00
# TIMESTEP 18933 / e 14 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.238583e+00
# TIMESTEP 18979 / e 14 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.600637e+00
# TIMESTEP 19025 / e 14 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.061883e+00
# TIMESTEP 19071 / e 14 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.291385e+00
# TIMESTEP 19117 / e 14 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.318389e+00
# TIMESTEP 19163 / e 14 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.358538e+00
# TIMESTEP 19209 / e 14 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.196287e+00
# TIMESTEP 19255 / e 14 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.362226e+00
# TIMESTEP 19301 / e 14 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.691845e+00
# TIMESTEP 19347 / e 14 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.659231e+00
# TIMESTEP 19393 / e 14 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.813296e+00
# TIMESTEP 19439 / e 14 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.766319e+00
# TIMESTEP 19485 / e 14 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.907066e+00
# TIMESTEP 19531 / e 14 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.825994e+00
# TIMESTEP 19577 / e 14 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.536210e+00
# TIMESTEP 19623 / e 14 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.406745e+00
# TIMESTEP 19669 / e 14 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.297141e+00
# TIMESTEP 19798 / e 14 / bar1_score 1 / bar2_score 16 / REWARD 1 / Q_MAX 1.814538e+00
# TIMESTEP 19927 / e 14 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.500527e+00
# TIMESTEP 19973 / e 14 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.265041e+00
# TIMESTEP 20019 / e 14 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.168587e+00
# TIMESTEP 20065 / e 15 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.101919e+00
# TIMESTEP 20111 / e 15 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.022440e+00
# TIMESTEP 20157 / e 15 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 7.762422e-01
# TIMESTEP 20203 / e 15 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 9.953177e-01
# TIMESTEP 20249 / e 15 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.062052e+00
# TIMESTEP 20295 / e 15 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.114665e+00
# TIMESTEP 20341 / e 15 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.146288e+00
# TIMESTEP 20387 / e 15 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 9.899704e-01
# TIMESTEP 20433 / e 15 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 9.484504e-01
# TIMESTEP 20479 / e 15 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.170606e+00
# TIMESTEP 20525 / e 15 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.696824e+00
# TIMESTEP 20571 / e 15 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.742242e+00
# TIMESTEP 20617 / e 15 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.639128e+00
# TIMESTEP 20663 / e 15 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.661298e+00
# TIMESTEP 20709 / e 15 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.862251e+00
# TIMESTEP 20755 / e 15 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.785625e+00
# TIMESTEP 20884 / e 15 / bar1_score 1 / bar2_score 15 / REWARD 1 / Q_MAX 1.828923e+00
# TIMESTEP 21013 / e 15 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.608753e+00
# TIMESTEP 21059 / e 15 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.388871e+00
# TIMESTEP 21105 / e 15 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.370685e+00
# TIMESTEP 21151 / e 15 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.014374e+00
# TIMESTEP 21197 / e 16 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.188888e+00
# TIMESTEP 21243 / e 16 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.123931e+00
# TIMESTEP 21289 / e 16 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 7.940133e-01
# TIMESTEP 21418 / e 16 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX 1.893599e+00
# TIMESTEP 21547 / e 16 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX 1.491368e+00
# TIMESTEP 21593 / e 16 / bar1_score 1 / bar2_score 4 / REWARD -1 / Q_MAX 1.072497e+00
# TIMESTEP 21639 / e 16 / bar1_score 1 / bar2_score 5 / REWARD -1 / Q_MAX 1.420038e+00
# TIMESTEP 21685 / e 16 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 1.405197e+00
# TIMESTEP 21731 / e 16 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 1.511643e+00
# TIMESTEP 21777 / e 16 / bar1_score 1 / bar2_score 8 / REWARD -1 / Q_MAX 1.482741e+00
# TIMESTEP 21823 / e 16 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 1.077763e+00
# TIMESTEP 21869 / e 16 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 1.259045e+00
# TIMESTEP 21915 / e 16 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.219046e+00
# TIMESTEP 21961 / e 16 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 9.365227e-01
# TIMESTEP 22007 / e 16 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 1.075052e+00
# TIMESTEP 22053 / e 16 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 1.017836e+00
# TIMESTEP 22099 / e 16 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 1.254301e+00
# TIMESTEP 22145 / e 16 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.287941e+00
# TIMESTEP 22191 / e 16 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.256476e+00
# TIMESTEP 22320 / e 16 / bar1_score 2 / bar2_score 17 / REWARD 1 / Q_MAX 1.977362e+00
# TIMESTEP 22449 / e 16 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 1.656254e+00
# TIMESTEP 22495 / e 16 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 1.673561e+00
# TIMESTEP 22541 / e 17 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.787420e+00
# TIMESTEP 22587 / e 17 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.797775e+00
# TIMESTEP 22633 / e 17 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.569073e+00
# TIMESTEP 22679 / e 17 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.721773e+00
# TIMESTEP 22725 / e 17 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.095545e+00
# TIMESTEP 22771 / e 17 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.183517e+00
# TIMESTEP 22987 / e 17 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.576918e+00
# TIMESTEP 23033 / e 17 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 9.817939e-01
# TIMESTEP 23079 / e 17 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.145603e+00
# TIMESTEP 23125 / e 17 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.293741e+00
# TIMESTEP 23171 / e 17 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.041594e+00
# TIMESTEP 23217 / e 17 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 8.914840e-01
# TIMESTEP 23430 / e 17 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.642038e+00
# TIMESTEP 23476 / e 17 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.231251e+00
# TIMESTEP 23522 / e 17 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 9.685643e-01
# TIMESTEP 23568 / e 17 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 9.363686e-01
# TIMESTEP 23614 / e 17 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.127252e+00
# TIMESTEP 23745 / e 17 / bar1_score 1 / bar2_score 16 / REWARD 1 / Q_MAX 1.656051e+00
# TIMESTEP 24126 / e 17 / bar1_score 2 / bar2_score 16 / REWARD 1 / Q_MAX 1.824468e+00
# TIMESTEP 24255 / e 17 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 1.249475e+00
# TIMESTEP 24301 / e 17 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 8.516119e-01
# TIMESTEP 24347 / e 17 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 9.057877e-01
# TIMESTEP 24393 / e 18 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 8.231881e-01
# TIMESTEP 24439 / e 18 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 7.624605e-01
# TIMESTEP 24485 / e 18 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 7.512673e-01
# TIMESTEP 24531 / e 18 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 9.115453e-01
# TIMESTEP 24577 / e 18 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 9.324882e-01
# TIMESTEP 24623 / e 18 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 9.552276e-01
# TIMESTEP 24754 / e 18 / bar1_score 1 / bar2_score 5 / REWARD 1 / Q_MAX 2.098918e+00
# TIMESTEP 24883 / e 18 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 1.698384e+00
# TIMESTEP 24929 / e 18 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 1.281171e+00
# TIMESTEP 25142 / e 18 / bar1_score 1 / bar2_score 8 / REWARD -1 / Q_MAX 1.773054e+00
# TIMESTEP 25188 / e 18 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 1.367824e+00
# TIMESTEP 25234 / e 18 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 1.063390e+00
# TIMESTEP 25363 / e 18 / bar1_score 2 / bar2_score 10 / REWARD 1 / Q_MAX 1.846761e+00
# TIMESTEP 25492 / e 18 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 1.145269e+00
# TIMESTEP 25538 / e 18 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 9.536700e-01
# TIMESTEP 25751 / e 18 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 1.366613e+00
# TIMESTEP 25797 / e 18 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.230184e+00
# TIMESTEP 26010 / e 18 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 1.540674e+00
# TIMESTEP 26056 / e 18 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 1.392269e+00
# TIMESTEP 26269 / e 18 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 1.268924e+00
# TIMESTEP 26315 / e 18 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 1.013861e+00
# TIMESTEP 26361 / e 18 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 9.525360e-01
# TIMESTEP 26407 / e 19 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.053688e+00
# TIMESTEP 26453 / e 19 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.177052e+00
# TIMESTEP 26499 / e 19 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.121885e+00
# TIMESTEP 26545 / e 19 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.378853e+00
# TIMESTEP 26591 / e 19 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 8.980706e-01
# TIMESTEP 26804 / e 19 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.734664e+00
# TIMESTEP 26850 / e 19 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.558688e+00
# TIMESTEP 27063 / e 19 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.748179e+00
# TIMESTEP 27109 / e 19 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.519311e+00
# TIMESTEP 27155 / e 19 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.173502e+00
# TIMESTEP 27201 / e 19 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.020878e+00
# TIMESTEP 27247 / e 19 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.434581e+00
# TIMESTEP 27376 / e 19 / bar1_score 1 / bar2_score 11 / REWARD 1 / Q_MAX 2.212110e+00
# TIMESTEP 27505 / e 19 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 1.449559e+00
# TIMESTEP 27634 / e 19 / bar1_score 2 / bar2_score 12 / REWARD 1 / Q_MAX 2.303340e+00
# TIMESTEP 27932 / e 19 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 1.722273e+00
# TIMESTEP 27978 / e 19 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.380061e+00
# TIMESTEP 28024 / e 19 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 8.582475e-01
# TIMESTEP 28070 / e 19 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 8.553464e-01
# TIMESTEP 28116 / e 19 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 7.076221e-01
# TIMESTEP 28162 / e 19 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 8.756600e-01
# TIMESTEP 28291 / e 19 / bar1_score 3 / bar2_score 18 / REWARD 1 / Q_MAX 2.187735e+00
# TIMESTEP 28420 / e 19 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 1.279570e+00
# TIMESTEP 28466 / e 20 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 9.975296e-01
# TIMESTEP 28512 / e 20 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.086017e+00
# TIMESTEP 28558 / e 20 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 5.677425e-01
# TIMESTEP 28604 / e 20 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 9.459748e-01
# TIMESTEP 28650 / e 20 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 7.238289e-01
# TIMESTEP 28863 / e 20 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.317989e+00
# TIMESTEP 28909 / e 20 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.442086e+00
# TIMESTEP 28955 / e 20 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.267167e+00
# TIMESTEP 29001 / e 20 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.056173e+00
# TIMESTEP 29047 / e 20 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.258699e+00
# TIMESTEP 29093 / e 20 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.292776e+00
# TIMESTEP 29139 / e 20 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 8.002664e-01
# TIMESTEP 29185 / e 20 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 7.681611e-01
# TIMESTEP 29231 / e 20 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 7.317772e-01
# TIMESTEP 29277 / e 20 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 5.710235e-01
# TIMESTEP 29323 / e 20 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 5.286679e-01
# TIMESTEP 29455 / e 20 / bar1_score 1 / bar2_score 15 / REWARD 1 / Q_MAX 1.960308e+00
# TIMESTEP 29584 / e 20 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.776180e+00
# TIMESTEP 29630 / e 20 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 1.645578e+00
# TIMESTEP 29676 / e 20 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 1.588923e+00
# TIMESTEP 29722 / e 20 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 1.357057e+00
# TIMESTEP 29768 / e 21 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.305907e+00
# TIMESTEP 29814 / e 21 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.490983e+00
# TIMESTEP 29860 / e 21 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 9.787010e-01
# TIMESTEP 29989 / e 21 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX 2.166259e+00
# TIMESTEP 30118 / e 21 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX 1.776954e+00
# TIMESTEP 30247 / e 21 / bar1_score 2 / bar2_score 3 / REWARD 1 / Q_MAX 2.453713e+00
# TIMESTEP 30376 / e 21 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 1.603862e+00
# TIMESTEP 30422 / e 21 / bar1_score 2 / bar2_score 5 / REWARD -1 / Q_MAX 1.220933e+00
# TIMESTEP 30468 / e 21 / bar1_score 2 / bar2_score 6 / REWARD -1 / Q_MAX 1.606596e+00
# TIMESTEP 30514 / e 21 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 1.290446e+00
# TIMESTEP 30727 / e 21 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 1.489004e+00
# TIMESTEP 30773 / e 21 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 1.363831e+00
# TIMESTEP 30819 / e 21 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 1.125100e+00
# TIMESTEP 30865 / e 21 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 5.959285e-01
# TIMESTEP 30911 / e 21 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.024808e+00
# TIMESTEP 30957 / e 21 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 7.211460e-01
# TIMESTEP 31003 / e 21 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 9.772274e-01
# TIMESTEP 31049 / e 21 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 5.619474e-01
# TIMESTEP 31095 / e 21 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 4.993703e-01
# TIMESTEP 31141 / e 21 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 4.761833e-01
# TIMESTEP 31187 / e 21 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 9.454454e-01
# TIMESTEP 31318 / e 21 / bar1_score 3 / bar2_score 18 / REWARD 1 / Q_MAX 1.955051e+00
# TIMESTEP 31447 / e 21 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 9.532129e-01
# TIMESTEP 31493 / e 22 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 6.008502e-01
# TIMESTEP 31539 / e 22 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 9.194524e-01
# TIMESTEP 31585 / e 22 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 5.748653e-01
# TIMESTEP 31631 / e 22 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.025248e+00
# TIMESTEP 31677 / e 22 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.020002e+00
# TIMESTEP 31723 / e 22 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.046416e+00
# TIMESTEP 31769 / e 22 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.225958e+00
# TIMESTEP 31815 / e 22 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.161141e+00
# TIMESTEP 31861 / e 22 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.411062e+00
# TIMESTEP 31907 / e 22 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.207463e+00
# TIMESTEP 32036 / e 22 / bar1_score 1 / bar2_score 9 / REWARD 1 / Q_MAX 2.451476e+00
# TIMESTEP 32165 / e 22 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 1.679093e+00
# TIMESTEP 32211 / e 22 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.133674e+00
# TIMESTEP 32257 / e 22 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 1.268262e+00
# TIMESTEP 32388 / e 22 / bar1_score 2 / bar2_score 12 / REWARD 1 / Q_MAX 1.932792e+00
# TIMESTEP 32517 / e 22 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 1.023293e+00
# TIMESTEP 32563 / e 22 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 6.743419e-01
# TIMESTEP 32609 / e 22 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 8.063160e-01
# TIMESTEP 32655 / e 22 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 4.517286e-01
# TIMESTEP 32701 / e 22 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 7.441127e-01
# TIMESTEP 32830 / e 22 / bar1_score 3 / bar2_score 17 / REWARD 1 / Q_MAX 2.040540e+00
# TIMESTEP 32959 / e 22 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX 1.031806e+00
# TIMESTEP 33005 / e 22 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 6.052704e-01
# TIMESTEP 33051 / e 23 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 5.114159e-01
# TIMESTEP 33097 / e 23 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 3.455999e-01
# TIMESTEP 33143 / e 23 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.596220e-01
# TIMESTEP 33189 / e 23 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 5.461209e-01
# TIMESTEP 33235 / e 23 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 4.607857e-01
# TIMESTEP 33281 / e 23 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 6.209453e-01
# TIMESTEP 33327 / e 23 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 6.986088e-01
# TIMESTEP 33373 / e 23 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.006205e+00
# TIMESTEP 33586 / e 23 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.482640e+00
# TIMESTEP 33632 / e 23 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.340114e+00
# TIMESTEP 33678 / e 23 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.325831e+00
# TIMESTEP 33807 / e 23 / bar1_score 1 / bar2_score 10 / REWARD 1 / Q_MAX 2.548645e+00
# TIMESTEP 33936 / e 23 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.645004e+00
# TIMESTEP 33982 / e 23 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 1.336707e+00
# TIMESTEP 34028 / e 23 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 1.717856e+00
# TIMESTEP 34157 / e 23 / bar1_score 2 / bar2_score 13 / REWARD 1 / Q_MAX 2.555550e+00
# TIMESTEP 34286 / e 23 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.233629e+00
# TIMESTEP 34332 / e 23 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 1.155217e+00
# TIMESTEP 34378 / e 23 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 1.327713e+00
# TIMESTEP 34507 / e 23 / bar1_score 3 / bar2_score 16 / REWARD 1 / Q_MAX 2.543898e+00
# TIMESTEP 34636 / e 23 / bar1_score 3 / bar2_score 17 / REWARD -1 / Q_MAX 9.851326e-01
# TIMESTEP 34682 / e 23 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX 1.246129e+00
# TIMESTEP 34728 / e 23 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 1.141365e+00
# TIMESTEP 34774 / e 24 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 4.755169e-01
# TIMESTEP 34987 / e 24 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.277166e+00
# TIMESTEP 35033 / e 24 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.026353e+00
# TIMESTEP 35246 / e 24 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.394783e+00
# TIMESTEP 35375 / e 24 / bar1_score 1 / bar2_score 3 / REWARD 1 / Q_MAX 2.611632e+00
# TIMESTEP 35504 / e 24 / bar1_score 1 / bar2_score 4 / REWARD -1 / Q_MAX 1.309385e+00
# TIMESTEP 35550 / e 24 / bar1_score 1 / bar2_score 5 / REWARD -1 / Q_MAX 1.105358e+00
# TIMESTEP 35596 / e 24 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 1.390717e+00
# TIMESTEP 35725 / e 24 / bar1_score 2 / bar2_score 6 / REWARD 1 / Q_MAX 2.606035e+00
# TIMESTEP 35854 / e 24 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 1.351462e+00
# TIMESTEP 35900 / e 24 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 1.004513e+00
# TIMESTEP 36115 / e 24 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 1.706476e+00
# TIMESTEP 36161 / e 24 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 1.054079e+00
# TIMESTEP 36374 / e 24 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 8.385449e-01
# TIMESTEP 36420 / e 24 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 8.536864e-01
# TIMESTEP 36466 / e 24 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 5.440766e-01
# TIMESTEP 36512 / e 24 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 5.354040e-01
# TIMESTEP 36558 / e 24 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 6.648778e-01
# TIMESTEP 36687 / e 24 / bar1_score 3 / bar2_score 15 / REWARD 1 / Q_MAX 2.127755e+00
# TIMESTEP 36816 / e 24 / bar1_score 3 / bar2_score 16 / REWARD -1 / Q_MAX 1.046877e+00
# TIMESTEP 36862 / e 24 / bar1_score 3 / bar2_score 17 / REWARD -1 / Q_MAX 6.555367e-01
# TIMESTEP 36908 / e 24 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX 4.690976e-01
# TIMESTEP 37037 / e 24 / bar1_score 4 / bar2_score 18 / REWARD 1 / Q_MAX 2.306119e+00
# TIMESTEP 37166 / e 24 / bar1_score 4 / bar2_score 19 / REWARD -1 / Q_MAX 1.077410e+00
# TIMESTEP 37295 / e 24 / bar1_score 5 / bar2_score 19 / REWARD 1 / Q_MAX 2.385147e+00
# TIMESTEP 37424 / e 25 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 9.432296e-01
# TIMESTEP 37470 / e 25 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.218498e+00
# TIMESTEP 37516 / e 25 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.117220e+00
# TIMESTEP 37645 / e 25 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX 2.452540e+00
# TIMESTEP 37774 / e 25 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX 1.657168e+00
# TIMESTEP 37903 / e 25 / bar1_score 2 / bar2_score 3 / REWARD 1 / Q_MAX 2.610003e+00
# TIMESTEP 38032 / e 25 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 8.702697e-01
# TIMESTEP 38078 / e 25 / bar1_score 2 / bar2_score 5 / REWARD -1 / Q_MAX 6.166638e-01
# TIMESTEP 38124 / e 25 / bar1_score 2 / bar2_score 6 / REWARD -1 / Q_MAX 7.469579e-01
# TIMESTEP 38170 / e 25 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 4.259083e-01
# TIMESTEP 38384 / e 25 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 9.512646e-01
# TIMESTEP 38430 / e 25 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 9.287391e-01
# TIMESTEP 38476 / e 25 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 1.043506e+00
# TIMESTEP 38522 / e 25 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 5.301830e-01
# TIMESTEP 38568 / e 25 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.056341e+00
# TIMESTEP 38697 / e 25 / bar1_score 3 / bar2_score 12 / REWARD 1 / Q_MAX 2.469199e+00
# TIMESTEP 38826 / e 25 / bar1_score 3 / bar2_score 13 / REWARD -1 / Q_MAX 1.263673e+00
# TIMESTEP 38955 / e 25 / bar1_score 4 / bar2_score 13 / REWARD 1 / Q_MAX 2.555196e+00
# TIMESTEP 39084 / e 25 / bar1_score 4 / bar2_score 14 / REWARD -1 / Q_MAX 1.642983e+00
# TIMESTEP 39213 / e 25 / bar1_score 5 / bar2_score 14 / REWARD 1 / Q_MAX 2.643249e+00
# TIMESTEP 39342 / e 25 / bar1_score 5 / bar2_score 15 / REWARD -1 / Q_MAX 1.091904e+00
# TIMESTEP 39388 / e 25 / bar1_score 5 / bar2_score 16 / REWARD -1 / Q_MAX 1.254681e+00
# ...
# TIMESTEP 290323 / e 76 / bar1_score 8 / bar2_score 3 / REWARD -1 / Q_MAX 3.167390e-01
# TIMESTEP 290453 / e 76 / bar1_score 9 / bar2_score 3 / REWARD 1 / Q_MAX 2.198013e+00
# TIMESTEP 290582 / e 76 / bar1_score 9 / bar2_score 4 / REWARD -1 / Q_MAX 5.673824e-01
# TIMESTEP 290628 / e 76 / bar1_score 9 / bar2_score 5 / REWARD -1 / Q_MAX 6.121707e-02
# TIMESTEP 290674 / e 76 / bar1_score 9 / bar2_score 6 / REWARD -1 / Q_MAX 5.388336e-01
# TIMESTEP 290803 / e 76 / bar1_score 10 / bar2_score 6 / REWARD 1 / Q_MAX 2.415468e+00
# TIMESTEP 291100 / e 76 / bar1_score 10 / bar2_score 7 / REWARD -1 / Q_MAX 1.806865e-01
# TIMESTEP 291313 / e 76 / bar1_score 10 / bar2_score 8 / REWARD -1 / Q_MAX 6.087062e-01
# TIMESTEP 291442 / e 76 / bar1_score 11 / bar2_score 8 / REWARD 1 / Q_MAX 2.214625e+00
# TIMESTEP 291827 / e 76 / bar1_score 12 / bar2_score 8 / REWARD 1 / Q_MAX 2.182947e+00
# TIMESTEP 292124 / e 76 / bar1_score 12 / bar2_score 9 / REWARD -1 / Q_MAX 4.470949e-01
# TIMESTEP 292337 / e 76 / bar1_score 12 / bar2_score 10 / REWARD -1 / Q_MAX 1.930171e-01
# TIMESTEP 292466 / e 76 / bar1_score 13 / bar2_score 10 / REWARD 1 / Q_MAX 2.377250e+00
# TIMESTEP 292847 / e 76 / bar1_score 14 / bar2_score 10 / REWARD 1 / Q_MAX 2.565377e+00
# TIMESTEP 293232 / e 76 / bar1_score 15 / bar2_score 10 / REWARD 1 / Q_MAX 2.334529e+00
# TIMESTEP 293615 / e 76 / bar1_score 16 / bar2_score 10 / REWARD 1 / Q_MAX 2.673097e+00
# TIMESTEP 293996 / e 76 / bar1_score 17 / bar2_score 10 / REWARD 1 / Q_MAX 2.608860e+00
# TIMESTEP 294379 / e 76 / bar1_score 18 / bar2_score 10 / REWARD 1 / Q_MAX 2.520473e+00
# TIMESTEP 294761 / e 76 / bar1_score 19 / bar2_score 10 / REWARD 1 / Q_MAX 2.512311e+00
# TIMESTEP 295059 / e 76 / bar1_score 19 / bar2_score 11 / REWARD -1 / Q_MAX 3.162546e-01
# TIMESTEP 295105 / e 76 / bar1_score 19 / bar2_score 12 / REWARD -1 / Q_MAX 4.564627e-01
# TIMESTEP 295234 / e 77 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 2.201921e+00
# TIMESTEP 295615 / e 77 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.233849e+00
# TIMESTEP 295998 / e 77 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 2.289490e+00
# TIMESTEP 296381 / e 77 / bar1_score 3 / bar2_score 0 / REWARD 1 / Q_MAX 2.154293e+00
# TIMESTEP 296680 / e 77 / bar1_score 3 / bar2_score 1 / REWARD -1 / Q_MAX 9.552223e-01
# TIMESTEP 296896 / e 77 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX 3.649420e-01
# TIMESTEP 297025 / e 77 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 3.027594e+00
# TIMESTEP 297154 / e 77 / bar1_score 4 / bar2_score 3 / REWARD -1 / Q_MAX 1.392761e+00
# TIMESTEP 297283 / e 77 / bar1_score 5 / bar2_score 3 / REWARD 1 / Q_MAX 2.454198e+00
# TIMESTEP 297580 / e 77 / bar1_score 5 / bar2_score 4 / REWARD -1 / Q_MAX 4.626905e-02
# TIMESTEP 297794 / e 77 / bar1_score 5 / bar2_score 5 / REWARD -1 / Q_MAX 3.571235e-01
# TIMESTEP 297840 / e 77 / bar1_score 5 / bar2_score 6 / REWARD -1 / Q_MAX 1.133819e-01
# TIMESTEP 298056 / e 77 / bar1_score 5 / bar2_score 7 / REWARD -1 / Q_MAX -8.013207e-02
# TIMESTEP 298102 / e 77 / bar1_score 5 / bar2_score 8 / REWARD -1 / Q_MAX 4.839196e-02
# TIMESTEP 298404 / e 77 / bar1_score 6 / bar2_score 8 / REWARD 1 / Q_MAX 2.274809e+00
# TIMESTEP 298533 / e 77 / bar1_score 6 / bar2_score 9 / REWARD -1 / Q_MAX 6.316726e-01
# TIMESTEP 298662 / e 77 / bar1_score 7 / bar2_score 9 / REWARD 1 / Q_MAX 2.424383e+00
# TIMESTEP 298791 / e 77 / bar1_score 7 / bar2_score 10 / REWARD -1 / Q_MAX 5.673668e-01
# TIMESTEP 298920 / e 77 / bar1_score 8 / bar2_score 10 / REWARD 1 / Q_MAX 2.364530e+00
# TIMESTEP 299049 / e 77 / bar1_score 8 / bar2_score 11 / REWARD -1 / Q_MAX 1.223902e+00
# TIMESTEP 299178 / e 77 / bar1_score 9 / bar2_score 11 / REWARD 1 / Q_MAX 3.133517e+00
# TIMESTEP 299561 / e 77 / bar1_score 10 / bar2_score 11 / REWARD 1 / Q_MAX 3.456917e+00
# TIMESTEP 299942 / e 77 / bar1_score 11 / bar2_score 11 / REWARD 1 / Q_MAX 2.933816e+00
# TIMESTEP 300071 / e 77 / bar1_score 11 / bar2_score 12 / REWARD -1 / Q_MAX 1.794160e+00
# TIMESTEP 300117 / e 77 / bar1_score 11 / bar2_score 13 / REWARD -1 / Q_MAX 1.911114e+00
# TIMESTEP 300163 / e 77 / bar1_score 11 / bar2_score 14 / REWARD -1 / Q_MAX 2.182633e+00
# TIMESTEP 300209 / e 77 / bar1_score 11 / bar2_score 15 / REWARD -1 / Q_MAX 1.451759e+00
# TIMESTEP 300255 / e 77 / bar1_score 11 / bar2_score 16 / REWARD -1 / Q_MAX 2.545635e+00
# TIMESTEP 300386 / e 77 / bar1_score 12 / bar2_score 16 / REWARD 1 / Q_MAX 3.342874e+00
# TIMESTEP 300767 / e 77 / bar1_score 13 / bar2_score 16 / REWARD 1 / Q_MAX 3.188675e+00
# TIMESTEP 301148 / e 77 / bar1_score 14 / bar2_score 16 / REWARD 1 / Q_MAX 3.365556e+00
# TIMESTEP 301531 / e 77 / bar1_score 15 / bar2_score 16 / REWARD 1 / Q_MAX 3.362337e+00
# TIMESTEP 301660 / e 77 / bar1_score 15 / bar2_score 17 / REWARD -1 / Q_MAX 1.789684e+00
# TIMESTEP 301789 / e 77 / bar1_score 16 / bar2_score 17 / REWARD 1 / Q_MAX 3.029619e+00
# TIMESTEP 301918 / e 77 / bar1_score 16 / bar2_score 18 / REWARD -1 / Q_MAX 1.201037e+00
# TIMESTEP 301964 / e 77 / bar1_score 16 / bar2_score 19 / REWARD -1 / Q_MAX 6.735474e-01
# TIMESTEP 302010 / e 78 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 9.233056e-01
# TIMESTEP 302139 / e 78 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 3.163988e+00
# TIMESTEP 302521 / e 78 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 3.402490e+00
# TIMESTEP 302650 / e 78 / bar1_score 2 / bar2_score 1 / REWARD -1 / Q_MAX 1.641780e+00
# TIMESTEP 302779 / e 78 / bar1_score 3 / bar2_score 1 / REWARD 1 / Q_MAX 3.357563e+00
# TIMESTEP 303078 / e 78 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX 1.226943e+00
# TIMESTEP 303124 / e 78 / bar1_score 3 / bar2_score 3 / REWARD -1 / Q_MAX 9.680484e-01
# TIMESTEP 303253 / e 78 / bar1_score 4 / bar2_score 3 / REWARD 1 / Q_MAX 3.378602e+00
# TIMESTEP 303550 / e 78 / bar1_score 4 / bar2_score 4 / REWARD -1 / Q_MAX 1.554742e+00
# TIMESTEP 303596 / e 78 / bar1_score 4 / bar2_score 5 / REWARD -1 / Q_MAX 1.797872e+00
# TIMESTEP 303642 / e 78 / bar1_score 4 / bar2_score 6 / REWARD -1 / Q_MAX 1.186280e+00
# TIMESTEP 303855 / e 78 / bar1_score 4 / bar2_score 7 / REWARD -1 / Q_MAX 1.028721e+00
# TIMESTEP 303984 / e 78 / bar1_score 5 / bar2_score 7 / REWARD 1 / Q_MAX 2.688308e+00
# TIMESTEP 304365 / e 78 / bar1_score 6 / bar2_score 7 / REWARD 1 / Q_MAX 2.818046e+00
# TIMESTEP 304746 / e 78 / bar1_score 7 / bar2_score 7 / REWARD 1 / Q_MAX 2.669127e+00
# TIMESTEP 304875 / e 78 / bar1_score 7 / bar2_score 8 / REWARD -1 / Q_MAX 8.830884e-01
# TIMESTEP 305004 / e 78 / bar1_score 8 / bar2_score 8 / REWARD 1 / Q_MAX 2.645894e+00
# TIMESTEP 305387 / e 78 / bar1_score 9 / bar2_score 8 / REWARD 1 / Q_MAX 2.413952e+00
# TIMESTEP 305685 / e 78 / bar1_score 9 / bar2_score 9 / REWARD -1 / Q_MAX 1.172820e+00
# TIMESTEP 305731 / e 78 / bar1_score 9 / bar2_score 10 / REWARD -1 / Q_MAX 8.478890e-01
# TIMESTEP 305860 / e 78 / bar1_score 10 / bar2_score 10 / REWARD 1 / Q_MAX 2.496388e+00
# TIMESTEP 305989 / e 78 / bar1_score 10 / bar2_score 11 / REWARD -1 / Q_MAX 4.669767e-01
# TIMESTEP 306118 / e 78 / bar1_score 11 / bar2_score 11 / REWARD 1 / Q_MAX 2.301177e+00
# TIMESTEP 306499 / e 78 / bar1_score 12 / bar2_score 11 / REWARD 1 / Q_MAX 2.553670e+00
# TIMESTEP 306628 / e 78 / bar1_score 12 / bar2_score 12 / REWARD -1 / Q_MAX 9.223233e-01
# TIMESTEP 306757 / e 78 / bar1_score 13 / bar2_score 12 / REWARD 1 / Q_MAX 2.222804e+00
# TIMESTEP 307138 / e 78 / bar1_score 14 / bar2_score 12 / REWARD 1 / Q_MAX 2.140262e+00
# TIMESTEP 307520 / e 78 / bar1_score 15 / bar2_score 12 / REWARD 1 / Q_MAX 2.417623e+00
# TIMESTEP 307901 / e 78 / bar1_score 16 / bar2_score 12 / REWARD 1 / Q_MAX 2.782139e+00
# TIMESTEP 308198 / e 78 / bar1_score 16 / bar2_score 13 / REWARD -1 / Q_MAX 3.431974e-01
# TIMESTEP 308411 / e 78 / bar1_score 16 / bar2_score 14 / REWARD -1 / Q_MAX 5.999494e-01
# TIMESTEP 308457 / e 78 / bar1_score 16 / bar2_score 15 / REWARD -1 / Q_MAX 4.628705e-01
# TIMESTEP 308503 / e 78 / bar1_score 16 / bar2_score 16 / REWARD -1 / Q_MAX 7.808896e-01
# TIMESTEP 308634 / e 78 / bar1_score 17 / bar2_score 16 / REWARD 1 / Q_MAX 2.310905e+00
# TIMESTEP 309015 / e 78 / bar1_score 18 / bar2_score 16 / REWARD 1 / Q_MAX 2.488297e+00
# TIMESTEP 309144 / e 78 / bar1_score 18 / bar2_score 17 / REWARD -1 / Q_MAX 5.432566e-01
# TIMESTEP 309273 / e 78 / bar1_score 19 / bar2_score 17 / REWARD 1 / Q_MAX 2.525835e+00
# TIMESTEP 309654 / e 79 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 2.158481e+00
# TIMESTEP 310035 / e 79 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.427406e+00
# TIMESTEP 310418 / e 79 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 2.591815e+00
# TIMESTEP 310547 / e 79 / bar1_score 2 / bar2_score 1 / REWARD -1 / Q_MAX 7.174202e-01
# TIMESTEP 310676 / e 79 / bar1_score 3 / bar2_score 1 / REWARD 1 / Q_MAX 2.612862e+00
# TIMESTEP 310805 / e 79 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX 1.214102e+00
# TIMESTEP 310934 / e 79 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 2.939321e+00
# TIMESTEP 311317 / e 79 / bar1_score 5 / bar2_score 2 / REWARD 1 / Q_MAX 2.985707e+00
# TIMESTEP 311699 / e 79 / bar1_score 6 / bar2_score 2 / REWARD 1 / Q_MAX 2.587744e+00
# TIMESTEP 312080 / e 79 / bar1_score 7 / bar2_score 2 / REWARD 1 / Q_MAX 2.342196e+00
# TIMESTEP 312462 / e 79 / bar1_score 8 / bar2_score 2 / REWARD 1 / Q_MAX 2.570614e+00
# TIMESTEP 312760 / e 79 / bar1_score 8 / bar2_score 3 / REWARD -1 / Q_MAX 2.472562e-01
# TIMESTEP 312806 / e 79 / bar1_score 8 / bar2_score 4 / REWARD -1 / Q_MAX 5.634636e-01
# TIMESTEP 312935 / e 79 / bar1_score 9 / bar2_score 4 / REWARD 1 / Q_MAX 2.488831e+00
# TIMESTEP 313064 / e 79 / bar1_score 9 / bar2_score 5 / REWARD -1 / Q_MAX 1.466581e+00
# TIMESTEP 313193 / e 79 / bar1_score 10 / bar2_score 5 / REWARD 1 / Q_MAX 2.469922e+00
# TIMESTEP 313574 / e 79 / bar1_score 11 / bar2_score 5 / REWARD 1 / Q_MAX 2.293421e+00
# TIMESTEP 313871 / e 79 / bar1_score 11 / bar2_score 6 / REWARD -1 / Q_MAX 4.170585e-01
# TIMESTEP 313917 / e 79 / bar1_score 11 / bar2_score 7 / REWARD -1 / Q_MAX 3.522405e-01
# TIMESTEP 314046 / e 79 / bar1_score 12 / bar2_score 7 / REWARD 1 / Q_MAX 2.426012e+00
# TIMESTEP 314343 / e 79 / bar1_score 12 / bar2_score 8 / REWARD -1 / Q_MAX 1.632635e+00
# TIMESTEP 314389 / e 79 / bar1_score 12 / bar2_score 9 / REWARD -1 / Q_MAX 3.198925e-01
# TIMESTEP 314518 / e 79 / bar1_score 13 / bar2_score 9 / REWARD 1 / Q_MAX 2.196803e+00
# TIMESTEP 314901 / e 79 / bar1_score 14 / bar2_score 9 / REWARD 1 / Q_MAX 2.493323e+00
# TIMESTEP 315284 / e 79 / bar1_score 15 / bar2_score 9 / REWARD 1 / Q_MAX 2.247601e+00
# TIMESTEP 315581 / e 79 / bar1_score 15 / bar2_score 10 / REWARD -1 / Q_MAX 1.330484e+00
# TIMESTEP 315795 / e 79 / bar1_score 15 / bar2_score 11 / REWARD -1 / Q_MAX 3.654320e-01
# TIMESTEP 315924 / e 79 / bar1_score 16 / bar2_score 11 / REWARD 1 / Q_MAX 2.559313e+00
# TIMESTEP 316305 / e 79 / bar1_score 17 / bar2_score 11 / REWARD 1 / Q_MAX 2.476660e+00
# TIMESTEP 316434 / e 79 / bar1_score 17 / bar2_score 12 / REWARD -1 / Q_MAX 1.064069e+00
# TIMESTEP 316563 / e 79 / bar1_score 18 / bar2_score 12 / REWARD 1 / Q_MAX 2.354178e+00
# TIMESTEP 316944 / e 79 / bar1_score 19 / bar2_score 12 / REWARD 1 / Q_MAX 2.442541e+00
# TIMESTEP 317241 / e 79 / bar1_score 19 / bar2_score 13 / REWARD -1 / Q_MAX 3.142902e-01
# TIMESTEP 317455 / e 79 / bar1_score 19 / bar2_score 14 / REWARD -1 / Q_MAX 1.397858e+00
# TIMESTEP 317586 / e 80 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 2.178476e+00
# TIMESTEP 317883 / e 80 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 3.501461e-01
# TIMESTEP 318097 / e 80 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.438192e+00
# TIMESTEP 318226 / e 80 / bar1_score 1 / bar2_score 2 / REWARD 1 / Q_MAX 2.433986e+00
# TIMESTEP 318607 / e 80 / bar1_score 2 / bar2_score 2 / REWARD 1 / Q_MAX 2.528215e+00
# TIMESTEP 318988 / e 80 / bar1_score 3 / bar2_score 2 / REWARD 1 / Q_MAX 2.330995e+00
# TIMESTEP 319369 / e 80 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 2.206692e+00
# TIMESTEP 319750 / e 80 / bar1_score 5 / bar2_score 2 / REWARD 1 / Q_MAX 2.369778e+00
# TIMESTEP 319879 / e 80 / bar1_score 5 / bar2_score 3 / REWARD -1 / Q_MAX 7.663274e-01
# TIMESTEP 320008 / e 80 / bar1_score 6 / bar2_score 3 / REWARD 1 / Q_MAX 2.414757e+00
# TIMESTEP 320137 / e 80 / bar1_score 6 / bar2_score 4 / REWARD -1 / Q_MAX 3.853813e-01
# TIMESTEP 320266 / e 80 / bar1_score 7 / bar2_score 4 / REWARD 1 / Q_MAX 2.450939e+00
# TIMESTEP 320648 / e 80 / bar1_score 8 / bar2_score 4 / REWARD 1 / Q_MAX 2.382982e+00
# TIMESTEP 321029 / e 80 / bar1_score 9 / bar2_score 4 / REWARD 1 / Q_MAX 2.255132e+00
# TIMESTEP 321411 / e 80 / bar1_score 10 / bar2_score 4 / REWARD 1 / Q_MAX 2.332326e+00
# TIMESTEP 321792 / e 80 / bar1_score 11 / bar2_score 4 / REWARD 1 / Q_MAX 2.352811e+00
# TIMESTEP 322173 / e 80 / bar1_score 12 / bar2_score 4 / REWARD 1 / Q_MAX 2.218945e+00
# TIMESTEP 322556 / e 80 / bar1_score 13 / bar2_score 4 / REWARD 1 / Q_MAX 2.197997e+00
# TIMESTEP 322938 / e 80 / bar1_score 14 / bar2_score 4 / REWARD 1 / Q_MAX 2.288948e+00
# TIMESTEP 323319 / e 80 / bar1_score 15 / bar2_score 4 / REWARD 1 / Q_MAX 2.266083e+00
# TIMESTEP 323448 / e 80 / bar1_score 15 / bar2_score 5 / REWARD -1 / Q_MAX 5.674946e-01
# TIMESTEP 323577 / e 80 / bar1_score 16 / bar2_score 5 / REWARD 1 / Q_MAX 2.206999e+00
# TIMESTEP 323706 / e 80 / bar1_score 16 / bar2_score 6 / REWARD -1 / Q_MAX 1.126586e-01
# TIMESTEP 323835 / e 80 / bar1_score 17 / bar2_score 6 / REWARD 1 / Q_MAX 2.202153e+00
# TIMESTEP 323964 / e 80 / bar1_score 17 / bar2_score 7 / REWARD -1 / Q_MAX 5.478187e-01
# TIMESTEP 324093 / e 80 / bar1_score 18 / bar2_score 7 / REWARD 1 / Q_MAX 2.270239e+00
# TIMESTEP 324222 / e 80 / bar1_score 18 / bar2_score 8 / REWARD -1 / Q_MAX 1.152735e+00
# TIMESTEP 324351 / e 80 / bar1_score 19 / bar2_score 8 / REWARD 1 / Q_MAX 2.545005e+00
# TIMESTEP 324732 / e 81 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 2.219897e+00
# TIMESTEP 324861 / e 81 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.108074e+00
# TIMESTEP 324990 / e 81 / bar1_score 1 / bar2_score 1 / REWARD 1 / Q_MAX 2.951212e+00
# TIMESTEP 325119 / e 81 / bar1_score 1 / bar2_score 2 / REWARD -1 / Q_MAX 1.171050e+00
# TIMESTEP 325248 / e 81 / bar1_score 2 / bar2_score 2 / REWARD 1 / Q_MAX 2.818689e+00
# TIMESTEP 325631 / e 81 / bar1_score 3 / bar2_score 2 / REWARD 1 / Q_MAX 2.725828e+00
# TIMESTEP 326012 / e 81 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 2.040619e+00
# TIMESTEP 326309 / e 81 / bar1_score 4 / bar2_score 3 / REWARD -1 / Q_MAX 1.438862e+00
# TIMESTEP 326522 / e 81 / bar1_score 4 / bar2_score 4 / REWARD -1 / Q_MAX 7.958875e-01
# TIMESTEP 326651 / e 81 / bar1_score 5 / bar2_score 4 / REWARD 1 / Q_MAX 2.286192e+00
# TIMESTEP 327034 / e 81 / bar1_score 6 / bar2_score 4 / REWARD 1 / Q_MAX 2.331031e+00
# TIMESTEP 327416 / e 81 / bar1_score 7 / bar2_score 4 / REWARD 1 / Q_MAX 2.262099e+00
# TIMESTEP 327797 / e 81 / bar1_score 8 / bar2_score 4 / REWARD 1 / Q_MAX 2.263578e+00
# TIMESTEP 328179 / e 81 / bar1_score 9 / bar2_score 4 / REWARD 1 / Q_MAX 2.384868e+00
# TIMESTEP 328562 / e 81 / bar1_score 10 / bar2_score 4 / REWARD 1 / Q_MAX 2.288479e+00
# TIMESTEP 328943 / e 81 / bar1_score 11 / bar2_score 4 / REWARD 1 / Q_MAX 1.938675e+00
# TIMESTEP 329326 / e 81 / bar1_score 12 / bar2_score 4 / REWARD 1 / Q_MAX 2.309886e+00
# TIMESTEP 329707 / e 81 / bar1_score 13 / bar2_score 4 / REWARD 1 / Q_MAX 2.275866e+00
# TIMESTEP 330088 / e 81 / bar1_score 14 / bar2_score 4 / REWARD 1 / Q_MAX 2.192470e+00
# TIMESTEP 330385 / e 81 / bar1_score 14 / bar2_score 5 / REWARD -1 / Q_MAX 4.205385e-01
# TIMESTEP 330431 / e 81 / bar1_score 14 / bar2_score 6 / REWARD -1 / Q_MAX 7.276688e-01
# TIMESTEP 330477 / e 81 / bar1_score 14 / bar2_score 7 / REWARD -1 / Q_MAX 1.221954e+00
# TIMESTEP 330523 / e 81 / bar1_score 14 / bar2_score 8 / REWARD -1 / Q_MAX 9.915602e-01
# TIMESTEP 330652 / e 81 / bar1_score 15 / bar2_score 8 / REWARD 1 / Q_MAX 2.999080e+00
# TIMESTEP 330949 / e 81 / bar1_score 15 / bar2_score 9 / REWARD -1 / Q_MAX 1.035554e+00
# TIMESTEP 331164 / e 81 / bar1_score 15 / bar2_score 10 / REWARD -1 / Q_MAX 3.580152e-01
# TIMESTEP 331293 / e 81 / bar1_score 16 / bar2_score 10 / REWARD 1 / Q_MAX 2.525671e+00
# TIMESTEP 331422 / e 81 / bar1_score 16 / bar2_score 11 / REWARD -1 / Q_MAX 4.844977e-01
# TIMESTEP 331551 / e 81 / bar1_score 17 / bar2_score 11 / REWARD 1 / Q_MAX 2.670601e+00

# %%
Jai Gurudev
