# %% [markdown]
# # Deep Q-Learning for Pong

# %%
import tensorflow as tf
import cv2
import sys
import pong_fun as game
import random
import time 
import numpy as np
from collections import deque
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Parameters for environment

# %%
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 500. # timesteps to observe before training
EXPLORE = 500. # frames over which to anneal epsilon
FINAL_EPSILON =  0.05 # final value of epsilon
INITIAL_EPSILON = 1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch

# %% [markdown]
# # Define the DON agent

# %%
np.random.seed(0)
tf.set_random_seed(0)
# Deep Q Network off-policy
class DeepQNetwork:
    def __init__(
            self,
            ACTIONS = 6,
            GAMMA = 0.99,
            OBSERVE = 500., # timesteps to observe before training
            EXPLORE = 500., # frames over which to anneal epsilon
            FINAL_EPSILON =  0.05, # final value of epsilon
            INITIAL_EPSILON = 1, # starting value of epsilon
            REPLAY_MEMORY = 50000,# number of previous transitions to remember
            BATCH = 32, # size of minibatch
            input_size = [84,84,4],
            learning_rate = 1e-6,
            replace_target_iter=200,
    ):
        tf.reset_default_graph()
        self.n_actions = ACTIONS
        self.gamma = GAMMA
        self.observe = OBSERVE  # timesteps to observe before training
        self.explore = EXPLORE # frames over which to anneal epsilon
        self.final_epsilon = FINAL_EPSILON  # final value of epsilon
        self.initial_epsilon = INITIAL_EPSILON  # starting value of epsilon
        self.memory_size = REPLAY_MEMORY # number of previous transitions to remember
        self.batch_size = BATCH # size of minibatch
        self.input_size =input_size 
        self.lr = learning_rate
        self.replace_target_iter = replace_target_iter

        # total learning step
        self.time_step = 0       
        self.epsilon = INITIAL_EPSILON
        #initialize zero memory [s, a, r, s_]
        self.memory = deque()

        # consist of [target_net, evaluate_net]
        self._build_net()

        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='eval_net')

        with tf.variable_scope('soft_replacement'):
            self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]

        self.sess = tf.Session()

        self.sess.run(tf.global_variables_initializer())
        print("---------- Class for the Agent is Ready ------------")
        
    # Building the Deep Q-Network
    def _build_net(self):
        # ------------------ all inputs ------------------------
        self.s = tf.placeholder(tf.float32,[None,self.input_size[0],self.input_size[1],self.input_size[2]],name='s') 
        self.s_next = tf.placeholder(tf.float32,[None,self.input_size[0],self.input_size[1],self.input_size[2]],name='s_')
        self.r = tf.placeholder(tf.float32, [None, ], name='r')  # input Reward
        self.a = tf.placeholder(tf.float32, [None, ACTIONS], name='a')
        self.y = tf.placeholder(tf.float32, [None])

        # Gausian weight initializer
        w_initializer, b_initializer = tf.random_normal_initializer(0., 0.01), tf.constant_initializer(0.01)
        
        # ------------------ build evaluate_net ------------------
        with tf.variable_scope('eval_net'):
            # Convolutional Layer 1
            with tf.variable_scope('conv1'): # hidden layer -1
                # 5x5 conv, 1 input, 32 outputs
                w1 = tf.get_variable('w1',[8, 8, self.input_size[2], 32],initializer=w_initializer)
                b1 = tf.get_variable('b1',[32],initializer=b_initializer)
                # Convolution Layer
                l1 = tf.nn.conv2d(self.s, w1, strides=[1, 4, 4, 1], padding="VALID")
                conv1 = tf.nn.relu(tf.nn.bias_add(l1, b1) )
                #print(conv1.get_shape())
            with tf.variable_scope('conv2'): # hidden layer -2
                # 5x5 conv, 1 input, 32 outputs
                w2 = tf.get_variable('w2',[4, 4, 32, 64],initializer=w_initializer)
                b2 = tf.get_variable('b2',[64],initializer=b_initializer)
                # Convolution Layer
                l2 = tf.nn.conv2d(conv1, w2, strides=[1, 2, 2, 1], padding="VALID")
                conv2 = tf.nn.relu(tf.nn.bias_add(l2, b2))
                #print(conv2.get_shape())
            with tf.variable_scope('conv3'): # hidden layer -3
                # 5x5 conv, 1 input, 32 outputs
                w3 = tf.get_variable('w3',[3, 3, 64, 64],initializer=w_initializer)
                b3 = tf.get_variable('b3',[64],initializer=b_initializer)
                # Convolution Layer
                l3 = tf.nn.conv2d(conv2, w3, strides=[1, 1, 1, 1], padding="VALID")
                conv3 = tf.nn.relu(tf.nn.bias_add(l3, b3) )
                #print(conv3.get_shape())
                # Reshape conv3 output to fit fully connected layer input
                fc1_input = tf.reshape(conv3, [-1, 7*7*64])
                #print(fc1_input.get_shape())
            with tf.variable_scope('fully_connected_layer'):
                # Fully connected layer
                w4 = tf.get_variable('w4',[7*7*64,512],initializer=w_initializer)
                b4 = tf.get_variable('b4',[1, 512],initializer=b_initializer)
                self.fc_out = tf.nn.relu(tf.matmul(fc1_input, w4) + b4)
                #print(self.fc_out.get_shape())
            with tf.variable_scope("output_layer___1"):
                w5 = tf.get_variable('w5',[512, self.n_actions],initializer=w_initializer)
                b5 = tf.get_variable('b5',[1, self.n_actions],initializer=b_initializer)
                #print(w5.get_shape(),"W5shape")
                #print(b5.get_shape(),"W5shape")
                self.q_eval = tf.matmul(self.fc_out, w5) + b5
                #print(self.q_eval)
                print("Building of the Evaluation network is Done _Dola_Ram")
                
        # ------------------ build target_net ------------------
        with tf.variable_scope('target_net'):
            # Convolutional Layer 1
            with tf.variable_scope('conv1'): # hidden layer -1
                # 5x5 conv, 1 input, 32 outputs
                w1 = tf.get_variable('w1',[8, 8, self.input_size[2], 32],initializer=w_initializer)
                b1 = tf.get_variable('b1',[32],initializer=b_initializer)
                # Convolution Layer
                l1 = tf.nn.conv2d(self.s_next, w1, strides=[1, 4, 4, 1], padding="VALID")
                conv1 = tf.nn.relu(tf.nn.bias_add(l1, b1) )
                #print(conv1.get_shape())
            with tf.variable_scope('conv2'): # hidden layer -2
                # 5x5 conv, 1 input, 32 outputs
                w2 = tf.get_variable('w2',[4, 4, 32, 64],initializer=w_initializer)
                b2 = tf.get_variable('b2',[64],initializer=b_initializer)
                # Convolution Layer
                l2 = tf.nn.conv2d(conv1, w2, strides=[1, 2, 2, 1], padding="VALID")
                conv2 = tf.nn.relu(tf.nn.bias_add(l2, b2))
                #print(conv2.get_shape())
            with tf.variable_scope('conv3'): # hidden layer -3
                # 5x5 conv, 1 input, 32 outputs
                w3 = tf.get_variable('w3',[3, 3, 64, 64],initializer=w_initializer)
                b3 = tf.get_variable('b3',[64],initializer=b_initializer)
                # Convolution Layer
                l3 = tf.nn.conv2d(conv2, w3, strides=[1, 1, 1, 1], padding="VALID")
                conv3 = tf.nn.relu(tf.nn.bias_add(l3, b3) )
                #print(conv3.get_shape())
                # Reshape conv3 output to fit fully connected layer input
                fc1_input = tf.reshape(conv3, [-1, 7*7*64])
                #print(fc1_input.get_shape())
            with tf.variable_scope('fully_connected_layer'):
                # Fully connected layer
                w4 = tf.get_variable('w4',[7*7*64,512],initializer=w_initializer)
                b4 = tf.get_variable('b4',[1, 512],initializer=b_initializer)
                self.fc_out = tf.nn.relu(tf.matmul(fc1_input, w4) + b4)
                #print(self.fc_out.get_shape())
            with tf.variable_scope("output_layer___1"):
                w5 = tf.get_variable('w5',[512, self.n_actions],initializer=w_initializer)
                b5 = tf.get_variable('b5',[1, self.n_actions],initializer=b_initializer)
                #print(w5.get_shape(),"W5shape")
                #print(b5.get_shape(),"W5shape")
                self.q_next = tf.matmul(self.fc_out, w5) + b5
                print("Building of the Target network is Done _Dola_Ram")
                
        # ---------- for loss and chossing actions ---------------
        with tf.variable_scope('q_eval'):
            # current value of the Q 
            self.q_eval_wrt_a = tf.reduce_sum(tf.multiply(self.q_eval, self.a), reduction_indices = 1)
            
        with tf.variable_scope('loss'):
            #  Mean squared loss mean((q_target-q_eval_wrt_a)^2)
            self.cost = tf.reduce_mean(tf.square(self.y - self.q_eval_wrt_a))
 
        with tf.variable_scope('train'):
            self.train_step = tf.train.AdamOptimizer(self.lr).minimize(self.cost)
            
    #--------- Choosing action based for the state(observation)----------------------------
    def choose_action(self, s_t):
        self.time_step += 1
         # choose an action epsilon greedily
        q_eval_t = self.sess.run(self.q_eval, feed_dict={self.s: s_t})
        # readout_t = readout.eval(feed_dict = {s : [s_t]})[0]
        a_t = np.zeros([self.n_actions])
        if random.random() <= self.epsilon or self.time_step <= self.observe:
            action_index = random.randrange(self.n_actions)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(q_eval_t)
            a_t[action_index] = 1

        # scale down epsilon
        if self.epsilon > self.final_epsilon and self.time_step > self.observe :
            self.epsilon -= (self.initial_epsilon - self.final_epsilon) / self.explore

        return a_t, self.epsilon, q_eval_t
    
    # ----------- learn the optimal polocy 
    def learn(self):
        # sample batch memory from all memory
        # only train if done observing
        if (self.time_step > self.observe) :
            # check to replace target parameters
            if self.time_step % self.replace_target_iter == 0:
                self.sess.run(self.target_replace_op)
                # print('\n target_params_replaced \n')
            # sample a minibatch to train on
            minibatch = random.sample(self.memory, self.batch_size)
            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]
            y_batch = []
            #readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            readout_j1_batch = self.sess.run(self.q_next, feed_dict = {self.s_next : s_j1_batch})
            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + self.gamma * np.max(readout_j1_batch[i]))
            # perform gradient step
            '''train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch})'''
            _,q_eval = self.sess.run([self.train_step,self.q_eval], feed_dict = {
                self.y : y_batch,
                self.a : a_batch,
                self.s : s_j_batch})
        return q_eval
    
    def store_transition(self, s_t, a_t, r_t, s_t1, terminal):
        # store the transition in replay memory
        self.memory.append((s_t, a_t, r_t, s_t1, terminal))
        if len(self.memory) > REPLAY_MEMORY:
            self.memory.popleft()

# %% [markdown]
# # Trainig the Agent by playing with environment

# %%
RL = DeepQNetwork()
# open up a game state to communicate with emulator
game_state = game.GameState()
# get the first state by doing nothing and preprocess the image to 80x80x4
do_nothing = np.zeros(ACTIONS)
do_nothing[0] = 1
x_t, r_0, terminal, bar1_score, bar2_score = game_state.frame_step(do_nothing)
x_t = cv2.cvtColor(cv2.resize(x_t, (84, 84)), cv2.COLOR_BGR2GRAY)
ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)
t = 0
tick = time.time()
while True:
    # choose an action epsilon greedily
    a_t, epsilon, q_eval_t = RL.choose_action(s_t.reshape(1,84, 84, 4))
    # run the selected action and observe next state and reward
    x_t1_col, r_t, terminal, bar1_score, bar2_score = game_state.frame_step(a_t)
    x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (84, 84)), cv2.COLOR_BGR2GRAY)
    ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
    x_t1 = np.reshape(x_t1, (84, 84, 1))
    s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)
    
    RL.store_transition(s_t, a_t, r_t, s_t1, terminal)
    
    # only train if done observing
    if (t > OBSERVE) :
        q_eval = RL.learn()
            
    # update the old values
    s_t = s_t1
    t += 1
    if r_t!= 0:
        print ("TIMESTEP", t, "/ e",round(epsilon, 3) , "/ Agent_score", bar1_score, "/ bar2_score",bar2_score,\
               "/reward", r_t, "/ Q_max %e" % np.max(q_eval_t))
    if(bar1_score - bar2_score > 18): 
        print("Game_Ends_in Time:",int(time.time() - tick))
        break;
# Out:
# Building of the Evaluation network is Done _Dola_Ram
# Building of the Target network is Done _Dola_Ram
# ---------- Class for the Agent is Ready ------------
# TIMESTEP 129 / e 1 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max 1.000920e-02
# TIMESTEP 175 / e 1 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max 1.444070e-02
# TIMESTEP 221 / e 1 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max 1.126540e-02
# TIMESTEP 267 / e 1 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max 9.906007e-03
# TIMESTEP 313 / e 1 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max 1.034196e-02
# TIMESTEP 443 / e 1 / Agent_score 1 / bar2_score 5 /reward 1 / Q_max 1.206354e-02
# TIMESTEP 572 / e 0.863 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max 1.193446e-02
# TIMESTEP 618 / e 0.776 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max 9.211323e-03
# TIMESTEP 664 / e 0.688 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max 8.338717e-03
# TIMESTEP 710 / e 0.601 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max 8.879194e-03
# TIMESTEP 756 / e 0.514 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max 7.256222e-03
# TIMESTEP 802 / e 0.426 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max 9.417722e-03
# TIMESTEP 848 / e 0.339 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max 7.194275e-03
# TIMESTEP 894 / e 0.251 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max 7.980204e-03
# TIMESTEP 940 / e 0.164 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max 9.757992e-03
# TIMESTEP 986 / e 0.077 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max 8.875379e-03
# TIMESTEP 1032 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max 2.575078e-03
# TIMESTEP 1161 / e 0.05 / Agent_score 2 / bar2_score 16 /reward 1 / Q_max 2.376360e-03
# TIMESTEP 1290 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max 6.493043e-03
# TIMESTEP 1336 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max 1.198877e-02
# TIMESTEP 1382 / e 0.05 / Agent_score 2 / bar2_score 19 /reward -1 / Q_max 7.709553e-03
# TIMESTEP 1428 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max 5.910467e-03
# TIMESTEP 1474 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max 4.942087e-03
# TIMESTEP 1520 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max 3.788121e-03
# TIMESTEP 1566 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max 9.569842e-04
# TIMESTEP 1612 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max 3.640698e-03
# TIMESTEP 1658 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max 2.459388e-03
# TIMESTEP 1704 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max 1.394272e-03
# TIMESTEP 1750 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -1.530024e-03
# TIMESTEP 1796 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max 2.733748e-04
# TIMESTEP 1842 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -2.694014e-03
# TIMESTEP 1888 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -3.357955e-03
# TIMESTEP 1934 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -2.254961e-03
# TIMESTEP 1980 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -2.621728e-03
# TIMESTEP 2026 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -6.511269e-03
# TIMESTEP 2072 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -4.728531e-03
# TIMESTEP 2118 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -8.273083e-03
# TIMESTEP 2164 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -1.230354e-02
# TIMESTEP 2210 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -1.339130e-02
# TIMESTEP 2256 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -1.474327e-02
# TIMESTEP 2302 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -2.003414e-02
# TIMESTEP 2348 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.244904e-02
# TIMESTEP 2394 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -2.189899e-02
# TIMESTEP 2440 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -2.026793e-02
# TIMESTEP 2486 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.899694e-02
# TIMESTEP 2532 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.005879e-02
# TIMESTEP 2578 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -3.015274e-02
# TIMESTEP 2624 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -2.875945e-02
# TIMESTEP 2670 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -3.349235e-02
# TIMESTEP 2716 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -3.037804e-02
# TIMESTEP 2762 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -3.510692e-02
# TIMESTEP 2808 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -3.552584e-02
# TIMESTEP 2854 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -4.174270e-02
# TIMESTEP 2900 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -4.383783e-02
# TIMESTEP 2946 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -4.643863e-02
# TIMESTEP 2992 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -4.469848e-02
# TIMESTEP 3038 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -4.371661e-02
# TIMESTEP 3084 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -5.237243e-02
# TIMESTEP 3130 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -5.179127e-02
# TIMESTEP 3176 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -5.195172e-02
# TIMESTEP 3222 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -5.574762e-02
# TIMESTEP 3268 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -5.988740e-02
# TIMESTEP 3314 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -5.114822e-02
# TIMESTEP 3443 / e 0.05 / Agent_score 1 / bar2_score 1 /reward 1 / Q_max -5.261479e-02
# TIMESTEP 3572 / e 0.05 / Agent_score 1 / bar2_score 2 /reward -1 / Q_max -4.658204e-02
# TIMESTEP 3704 / e 0.05 / Agent_score 2 / bar2_score 2 /reward 1 / Q_max -5.506949e-02
# TIMESTEP 3833 / e 0.05 / Agent_score 2 / bar2_score 3 /reward -1 / Q_max -6.897794e-02
# TIMESTEP 3879 / e 0.05 / Agent_score 2 / bar2_score 4 /reward -1 / Q_max -7.516579e-02
# TIMESTEP 3925 / e 0.05 / Agent_score 2 / bar2_score 5 /reward -1 / Q_max -7.814541e-02
# TIMESTEP 3971 / e 0.05 / Agent_score 2 / bar2_score 6 /reward -1 / Q_max -8.018278e-02
# TIMESTEP 4017 / e 0.05 / Agent_score 2 / bar2_score 7 /reward -1 / Q_max -8.507327e-02
# TIMESTEP 4063 / e 0.05 / Agent_score 2 / bar2_score 8 /reward -1 / Q_max -8.120204e-02
# TIMESTEP 4109 / e 0.05 / Agent_score 2 / bar2_score 9 /reward -1 / Q_max -8.364391e-02
# TIMESTEP 4155 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -8.530892e-02
# TIMESTEP 4201 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -9.534145e-02
# TIMESTEP 4247 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -9.345290e-02
# TIMESTEP 4293 / e 0.05 / Agent_score 2 / bar2_score 13 /reward -1 / Q_max -9.906016e-02
# TIMESTEP 4339 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -9.778415e-02
# TIMESTEP 4385 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -9.099079e-02
# TIMESTEP 4514 / e 0.05 / Agent_score 3 / bar2_score 15 /reward 1 / Q_max -1.006789e-01
# TIMESTEP 4643 / e 0.05 / Agent_score 3 / bar2_score 16 /reward -1 / Q_max -1.000412e-01
# TIMESTEP 4772 / e 0.05 / Agent_score 4 / bar2_score 16 /reward 1 / Q_max -9.845637e-02
# TIMESTEP 4901 / e 0.05 / Agent_score 4 / bar2_score 17 /reward -1 / Q_max -9.165078e-02
# TIMESTEP 4947 / e 0.05 / Agent_score 4 / bar2_score 18 /reward -1 / Q_max -8.995109e-02
# TIMESTEP 4993 / e 0.05 / Agent_score 4 / bar2_score 19 /reward -1 / Q_max -9.007301e-02
# TIMESTEP 5039 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -1.011565e-01
# TIMESTEP 5085 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -1.194960e-01
# TIMESTEP 5131 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -1.020687e-01
# TIMESTEP 5177 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -1.208944e-01
# TIMESTEP 5223 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -1.250908e-01
# TIMESTEP 5269 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -1.218623e-01
# TIMESTEP 5315 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -1.227744e-01
# TIMESTEP 5361 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -1.266356e-01
# TIMESTEP 5407 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -1.203814e-01
# TIMESTEP 5453 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -1.338299e-01
# TIMESTEP 5584 / e 0.05 / Agent_score 1 / bar2_score 9 /reward 1 / Q_max -1.284733e-01
# TIMESTEP 5713 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -1.009747e-01
# TIMESTEP 5759 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -9.495607e-02
# TIMESTEP 5805 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -9.607455e-02
# TIMESTEP 5851 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -1.105399e-01
# TIMESTEP 5897 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -1.048823e-01
# TIMESTEP 5943 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -1.078494e-01
# TIMESTEP 5989 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -1.073801e-01
# TIMESTEP 6118 / e 0.05 / Agent_score 2 / bar2_score 16 /reward 1 / Q_max -1.015213e-01
# TIMESTEP 6247 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -1.534696e-01
# TIMESTEP 6293 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -1.582823e-01
# TIMESTEP 6339 / e 0.05 / Agent_score 2 / bar2_score 19 /reward -1 / Q_max -1.607815e-01
# TIMESTEP 6468 / e 0.05 / Agent_score 3 / bar2_score 19 /reward 1 / Q_max -1.661865e-01
# TIMESTEP 6597 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -1.571076e-01
# TIMESTEP 6643 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -1.759684e-01
# TIMESTEP 6689 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -1.375376e-01
# TIMESTEP 6735 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -1.685179e-01
# TIMESTEP 6781 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -1.814652e-01
# TIMESTEP 6827 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -1.771716e-01
# TIMESTEP 6873 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -1.859315e-01
# TIMESTEP 7004 / e 0.05 / Agent_score 1 / bar2_score 6 /reward 1 / Q_max -1.765218e-01
# TIMESTEP 7133 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -1.382682e-01
# TIMESTEP 7179 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -1.397605e-01
# TIMESTEP 7225 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -1.506481e-01
# TIMESTEP 7271 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -1.497614e-01
# TIMESTEP 7317 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -1.692239e-01
# TIMESTEP 7363 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -1.640433e-01
# TIMESTEP 7409 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -1.707105e-01
# TIMESTEP 7540 / e 0.05 / Agent_score 2 / bar2_score 13 /reward 1 / Q_max -1.587666e-01
# TIMESTEP 7837 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -2.107059e-01
# TIMESTEP 8052 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -2.068151e-01
# TIMESTEP 8098 / e 0.05 / Agent_score 2 / bar2_score 16 /reward -1 / Q_max -2.226402e-01
# TIMESTEP 8144 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -2.170667e-01
# TIMESTEP 8190 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -2.260710e-01
# TIMESTEP 8236 / e 0.05 / Agent_score 2 / bar2_score 19 /reward -1 / Q_max -2.322121e-01
# TIMESTEP 8365 / e 0.05 / Agent_score 3 / bar2_score 19 /reward 1 / Q_max -1.940774e-01
# TIMESTEP 8494 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.087181e-01
# TIMESTEP 8623 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max -2.204773e-01
# TIMESTEP 8752 / e 0.05 / Agent_score 1 / bar2_score 1 /reward -1 / Q_max -1.694544e-01
# TIMESTEP 8798 / e 0.05 / Agent_score 1 / bar2_score 2 /reward -1 / Q_max -1.686315e-01
# TIMESTEP 8844 / e 0.05 / Agent_score 1 / bar2_score 3 /reward -1 / Q_max -1.652654e-01
# TIMESTEP 8890 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -1.949496e-01
# TIMESTEP 8936 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -1.955249e-01
# TIMESTEP 8982 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -1.980173e-01
# TIMESTEP 9028 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -2.058005e-01
# TIMESTEP 9074 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -1.774472e-01
# TIMESTEP 9120 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -1.969044e-01
# TIMESTEP 9249 / e 0.05 / Agent_score 2 / bar2_score 9 /reward 1 / Q_max -1.784246e-01
# TIMESTEP 9378 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -2.000843e-01
# TIMESTEP 9424 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -2.238426e-01
# TIMESTEP 9470 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -2.221310e-01
# TIMESTEP 9516 / e 0.05 / Agent_score 2 / bar2_score 13 /reward -1 / Q_max -2.497188e-01
# TIMESTEP 9562 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -2.423875e-01
# TIMESTEP 9608 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -2.322130e-01
# TIMESTEP 9654 / e 0.05 / Agent_score 2 / bar2_score 16 /reward -1 / Q_max -2.394560e-01
# TIMESTEP 9700 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -2.432267e-01
# TIMESTEP 9746 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -2.626352e-01
# TIMESTEP 9792 / e 0.05 / Agent_score 2 / bar2_score 19 /reward -1 / Q_max -2.481974e-01
# TIMESTEP 9838 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.552560e-01
# TIMESTEP 9969 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max -2.477228e-01
# TIMESTEP 10098 / e 0.05 / Agent_score 1 / bar2_score 1 /reward -1 / Q_max -1.870042e-01
# TIMESTEP 10144 / e 0.05 / Agent_score 1 / bar2_score 2 /reward -1 / Q_max -1.866950e-01
# TIMESTEP 10190 / e 0.05 / Agent_score 1 / bar2_score 3 /reward -1 / Q_max -1.876995e-01
# TIMESTEP 10236 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -2.113604e-01
# TIMESTEP 10282 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -2.274914e-01
# TIMESTEP 10411 / e 0.05 / Agent_score 2 / bar2_score 5 /reward 1 / Q_max -1.835192e-01
# TIMESTEP 10540 / e 0.05 / Agent_score 2 / bar2_score 6 /reward -1 / Q_max -2.385185e-01
# TIMESTEP 10586 / e 0.05 / Agent_score 2 / bar2_score 7 /reward -1 / Q_max -2.472296e-01
# TIMESTEP 10632 / e 0.05 / Agent_score 2 / bar2_score 8 /reward -1 / Q_max -2.326165e-01
# TIMESTEP 10678 / e 0.05 / Agent_score 2 / bar2_score 9 /reward -1 / Q_max -2.665808e-01
# TIMESTEP 10724 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -2.682770e-01
# TIMESTEP 10770 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -2.735775e-01
# TIMESTEP 10816 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -2.898591e-01
# TIMESTEP 10945 / e 0.05 / Agent_score 3 / bar2_score 12 /reward 1 / Q_max -2.544353e-01
# TIMESTEP 11074 / e 0.05 / Agent_score 3 / bar2_score 13 /reward -1 / Q_max -2.410681e-01
# TIMESTEP 11120 / e 0.05 / Agent_score 3 / bar2_score 14 /reward -1 / Q_max -2.348506e-01
# TIMESTEP 11166 / e 0.05 / Agent_score 3 / bar2_score 15 /reward -1 / Q_max -2.536104e-01
# TIMESTEP 11295 / e 0.05 / Agent_score 4 / bar2_score 15 /reward 1 / Q_max -2.109266e-01
# TIMESTEP 11424 / e 0.05 / Agent_score 4 / bar2_score 16 /reward -1 / Q_max -2.203308e-01
# TIMESTEP 11470 / e 0.05 / Agent_score 4 / bar2_score 17 /reward -1 / Q_max -2.501110e-01
# TIMESTEP 11516 / e 0.05 / Agent_score 4 / bar2_score 18 /reward -1 / Q_max -2.588260e-01
# TIMESTEP 11562 / e 0.05 / Agent_score 4 / bar2_score 19 /reward -1 / Q_max -2.569935e-01
# TIMESTEP 11608 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.734691e-01
# TIMESTEP 11654 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -2.905067e-01
# TIMESTEP 11700 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -2.738423e-01
# TIMESTEP 11746 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.880538e-01
# TIMESTEP 11792 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.006094e-01
# TIMESTEP 11838 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -2.898711e-01
# TIMESTEP 11884 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -3.060594e-01
# TIMESTEP 11930 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -3.047892e-01
# TIMESTEP 11976 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -3.119462e-01
# TIMESTEP 12022 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -3.145498e-01
# TIMESTEP 12068 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -3.207856e-01
# TIMESTEP 12114 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -3.163238e-01
# TIMESTEP 12160 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -3.328490e-01
# TIMESTEP 12206 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -3.137125e-01
# TIMESTEP 12252 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -3.245226e-01
# TIMESTEP 12298 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -3.244805e-01
# TIMESTEP 12344 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -3.298649e-01
# TIMESTEP 12390 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -3.104714e-01
# TIMESTEP 12436 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -3.309621e-01
# TIMESTEP 12565 / e 0.05 / Agent_score 1 / bar2_score 18 /reward 1 / Q_max -2.591646e-01
# TIMESTEP 12694 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -2.484440e-01
# TIMESTEP 12740 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.664686e-01
# TIMESTEP 12786 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -3.183331e-01
# TIMESTEP 12915 / e 0.05 / Agent_score 1 / bar2_score 1 /reward 1 / Q_max -2.437781e-01
# TIMESTEP 13044 / e 0.05 / Agent_score 1 / bar2_score 2 /reward -1 / Q_max -2.444628e-01
# TIMESTEP 13173 / e 0.05 / Agent_score 2 / bar2_score 2 /reward 1 / Q_max -2.378405e-01
# TIMESTEP 13302 / e 0.05 / Agent_score 2 / bar2_score 3 /reward -1 / Q_max -3.048988e-01
# TIMESTEP 13348 / e 0.05 / Agent_score 2 / bar2_score 4 /reward -1 / Q_max -3.228121e-01
# TIMESTEP 13394 / e 0.05 / Agent_score 2 / bar2_score 5 /reward -1 / Q_max -3.436608e-01
# TIMESTEP 13440 / e 0.05 / Agent_score 2 / bar2_score 6 /reward -1 / Q_max -3.417665e-01
# TIMESTEP 13486 / e 0.05 / Agent_score 2 / bar2_score 7 /reward -1 / Q_max -3.508671e-01
# TIMESTEP 13615 / e 0.05 / Agent_score 3 / bar2_score 7 /reward 1 / Q_max -2.820718e-01
# TIMESTEP 13744 / e 0.05 / Agent_score 3 / bar2_score 8 /reward -1 / Q_max -2.800008e-01
# TIMESTEP 13790 / e 0.05 / Agent_score 3 / bar2_score 9 /reward -1 / Q_max -3.099225e-01
# TIMESTEP 13836 / e 0.05 / Agent_score 3 / bar2_score 10 /reward -1 / Q_max -3.134957e-01
# TIMESTEP 13967 / e 0.05 / Agent_score 4 / bar2_score 10 /reward 1 / Q_max -2.901748e-01
# TIMESTEP 14096 / e 0.05 / Agent_score 4 / bar2_score 11 /reward -1 / Q_max -2.835310e-01
# TIMESTEP 14142 / e 0.05 / Agent_score 4 / bar2_score 12 /reward -1 / Q_max -3.333906e-01
# TIMESTEP 14188 / e 0.05 / Agent_score 4 / bar2_score 13 /reward -1 / Q_max -3.328864e-01
# TIMESTEP 14234 / e 0.05 / Agent_score 4 / bar2_score 14 /reward -1 / Q_max -3.343752e-01
# TIMESTEP 14280 / e 0.05 / Agent_score 4 / bar2_score 15 /reward -1 / Q_max -3.573984e-01
# TIMESTEP 14326 / e 0.05 / Agent_score 4 / bar2_score 16 /reward -1 / Q_max -3.489834e-01
# TIMESTEP 14372 / e 0.05 / Agent_score 4 / bar2_score 17 /reward -1 / Q_max -3.668324e-01
# TIMESTEP 14418 / e 0.05 / Agent_score 4 / bar2_score 18 /reward -1 / Q_max -3.532992e-01
# TIMESTEP 14464 / e 0.05 / Agent_score 4 / bar2_score 19 /reward -1 / Q_max -3.514850e-01
# TIMESTEP 14510 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -3.202533e-01
# TIMESTEP 14556 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -3.759478e-01
# TIMESTEP 14602 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -3.716365e-01
# TIMESTEP 14648 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -4.037170e-01
# TIMESTEP 14694 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.818828e-01
# TIMESTEP 14740 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -4.070463e-01
# TIMESTEP 14869 / e 0.05 / Agent_score 1 / bar2_score 5 /reward 1 / Q_max -3.058392e-01
# TIMESTEP 15166 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -2.951629e-01
# TIMESTEP 15212 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -3.505784e-01
# TIMESTEP 15343 / e 0.05 / Agent_score 2 / bar2_score 7 /reward 1 / Q_max -2.933398e-01
# TIMESTEP 15472 / e 0.05 / Agent_score 2 / bar2_score 8 /reward -1 / Q_max -3.301805e-01
# TIMESTEP 15518 / e 0.05 / Agent_score 2 / bar2_score 9 /reward -1 / Q_max -3.454500e-01
# TIMESTEP 15564 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -3.763245e-01
# TIMESTEP 15610 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -3.773543e-01
# TIMESTEP 15656 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -4.267064e-01
# TIMESTEP 15702 / e 0.05 / Agent_score 2 / bar2_score 13 /reward -1 / Q_max -4.032393e-01
# TIMESTEP 15748 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -4.113883e-01
# TIMESTEP 15794 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -4.099382e-01
# TIMESTEP 15840 / e 0.05 / Agent_score 2 / bar2_score 16 /reward -1 / Q_max -4.303783e-01
# TIMESTEP 15886 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -3.951822e-01
# TIMESTEP 15932 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -4.363012e-01
# TIMESTEP 16061 / e 0.05 / Agent_score 3 / bar2_score 18 /reward 1 / Q_max -3.049402e-01
# TIMESTEP 16190 / e 0.05 / Agent_score 3 / bar2_score 19 /reward -1 / Q_max -2.731887e-01
# TIMESTEP 16319 / e 0.05 / Agent_score 4 / bar2_score 19 /reward 1 / Q_max -2.561323e-01
# TIMESTEP 16448 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -3.116994e-01
# TIMESTEP 16494 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -3.645234e-01
# TIMESTEP 16540 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -4.108268e-01
# TIMESTEP 16669 / e 0.05 / Agent_score 1 / bar2_score 2 /reward 1 / Q_max -2.086365e-01
# TIMESTEP 16798 / e 0.05 / Agent_score 1 / bar2_score 3 /reward -1 / Q_max -2.800683e-01
# TIMESTEP 16927 / e 0.05 / Agent_score 2 / bar2_score 3 /reward 1 / Q_max -2.549261e-01
# TIMESTEP 17056 / e 0.05 / Agent_score 2 / bar2_score 4 /reward -1 / Q_max -3.205914e-01
# TIMESTEP 17185 / e 0.05 / Agent_score 3 / bar2_score 4 /reward 1 / Q_max -2.655039e-01
# TIMESTEP 17314 / e 0.05 / Agent_score 3 / bar2_score 5 /reward -1 / Q_max -2.682772e-01
# TIMESTEP 17360 / e 0.05 / Agent_score 3 / bar2_score 6 /reward -1 / Q_max -3.291578e-01
# TIMESTEP 17406 / e 0.05 / Agent_score 3 / bar2_score 7 /reward -1 / Q_max -3.535469e-01
# TIMESTEP 17535 / e 0.05 / Agent_score 4 / bar2_score 7 /reward 1 / Q_max -2.614810e-01
# TIMESTEP 17664 / e 0.05 / Agent_score 4 / bar2_score 8 /reward -1 / Q_max -2.940415e-01
# TIMESTEP 17793 / e 0.05 / Agent_score 5 / bar2_score 8 /reward 1 / Q_max -2.453925e-01
# TIMESTEP 17922 / e 0.05 / Agent_score 5 / bar2_score 9 /reward -1 / Q_max -2.759351e-01
# TIMESTEP 18053 / e 0.05 / Agent_score 6 / bar2_score 9 /reward 1 / Q_max -2.734620e-01
# TIMESTEP 18182 / e 0.05 / Agent_score 6 / bar2_score 10 /reward -1 / Q_max -2.720079e-01
# TIMESTEP 18228 / e 0.05 / Agent_score 6 / bar2_score 11 /reward -1 / Q_max -3.403092e-01
# TIMESTEP 18274 / e 0.05 / Agent_score 6 / bar2_score 12 /reward -1 / Q_max -4.219623e-01
# TIMESTEP 18405 / e 0.05 / Agent_score 7 / bar2_score 12 /reward 1 / Q_max -2.862401e-01
# TIMESTEP 18534 / e 0.05 / Agent_score 7 / bar2_score 13 /reward -1 / Q_max -1.996160e-01
# TIMESTEP 18666 / e 0.05 / Agent_score 8 / bar2_score 13 /reward 1 / Q_max -2.146090e-01
# TIMESTEP 18795 / e 0.05 / Agent_score 8 / bar2_score 14 /reward -1 / Q_max -2.409497e-01
# TIMESTEP 18841 / e 0.05 / Agent_score 8 / bar2_score 15 /reward -1 / Q_max -2.498076e-01
# TIMESTEP 18887 / e 0.05 / Agent_score 8 / bar2_score 16 /reward -1 / Q_max -3.826372e-01
# TIMESTEP 18933 / e 0.05 / Agent_score 8 / bar2_score 17 /reward -1 / Q_max -3.609727e-01
# TIMESTEP 18979 / e 0.05 / Agent_score 8 / bar2_score 18 /reward -1 / Q_max -4.385563e-01
# TIMESTEP 19025 / e 0.05 / Agent_score 8 / bar2_score 19 /reward -1 / Q_max -2.584926e-01
# TIMESTEP 19071 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.477580e-01
# TIMESTEP 19117 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -4.127153e-01
# TIMESTEP 19163 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -3.529496e-01
# TIMESTEP 19209 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -3.174170e-01
# TIMESTEP 19255 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -4.552217e-01
# TIMESTEP 19384 / e 0.05 / Agent_score 1 / bar2_score 4 /reward 1 / Q_max -2.610855e-01
# TIMESTEP 19513 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -1.137809e-01
# TIMESTEP 19559 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -2.161792e-01
# TIMESTEP 19605 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -1.344917e-01
# TIMESTEP 19651 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -1.924247e-01
# TIMESTEP 19697 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -1.803094e-01
# TIMESTEP 19743 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -2.306733e-01
# TIMESTEP 19789 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -2.014295e-01
# TIMESTEP 19835 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -2.070021e-01
# TIMESTEP 19881 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -2.640725e-01
# TIMESTEP 19927 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -1.894532e-01
# TIMESTEP 19973 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -3.489287e-01
# TIMESTEP 20019 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -1.947695e-01
# TIMESTEP 20065 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -4.196997e-01
# TIMESTEP 20111 / e 0.05 / Agent_score 1 / bar2_score 18 /reward -1 / Q_max -2.586555e-01
# TIMESTEP 20157 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -4.458731e-01
# TIMESTEP 20203 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -1.430706e-01
# TIMESTEP 20249 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -3.075053e-01
# TIMESTEP 20295 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -2.189333e-01
# TIMESTEP 20341 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -3.740146e-01
# TIMESTEP 20472 / e 0.05 / Agent_score 1 / bar2_score 3 /reward 1 / Q_max -2.416452e-01
# TIMESTEP 20770 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -3.605371e-02
# TIMESTEP 20816 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -2.111673e-01
# TIMESTEP 20862 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -1.650117e-01
# TIMESTEP 20908 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -1.729444e-01
# TIMESTEP 20954 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -1.535440e-01
# TIMESTEP 21000 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -2.028803e-01
# TIMESTEP 21046 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -1.186197e-01
# TIMESTEP 21092 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -2.384932e-01
# TIMESTEP 21138 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -1.946357e-01
# TIMESTEP 21184 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -2.250187e-01
# TIMESTEP 21230 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -3.337335e-01
# TIMESTEP 21276 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -3.142286e-01
# TIMESTEP 21322 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -1.306500e-01
# TIMESTEP 21368 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -2.288997e-01
# TIMESTEP 21414 / e 0.05 / Agent_score 1 / bar2_score 18 /reward -1 / Q_max -1.610335e-01
# TIMESTEP 21460 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -2.399289e-01
# TIMESTEP 21506 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -1.181649e-01
# TIMESTEP 21552 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -2.340439e-01
# TIMESTEP 21598 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -3.950676e-01
# TIMESTEP 21644 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.047886e-01
# TIMESTEP 21690 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -1.811956e-01
# TIMESTEP 21736 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -4.254539e-01
# TIMESTEP 21782 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -1.074731e-01
# TIMESTEP 21828 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -4.121677e-01
# TIMESTEP 21874 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -1.484557e-01
# TIMESTEP 21920 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -4.078633e-01
# TIMESTEP 21966 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -1.273803e-01
# TIMESTEP 22012 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -2.655223e-01
# TIMESTEP 22058 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -1.592225e-01
# TIMESTEP 22104 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -2.252200e-01
# TIMESTEP 22150 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -3.488040e-01
# TIMESTEP 22196 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -2.572126e-01
# TIMESTEP 22242 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -3.391276e-01
# TIMESTEP 22288 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -4.319013e-01
# TIMESTEP 22334 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -1.283596e-01
# TIMESTEP 22380 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -2.487458e-01
# TIMESTEP 22426 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -8.293095e-02
# TIMESTEP 22472 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -4.059581e-01
# TIMESTEP 22518 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -4.624902e-01
# TIMESTEP 22564 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.984774e-01
# TIMESTEP 22694 / e 0.05 / Agent_score 1 / bar2_score 3 /reward 1 / Q_max -1.567916e-01
# TIMESTEP 22992 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -1.848506e-01
# TIMESTEP 23038 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -4.162696e-01
# TIMESTEP 23084 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -1.159658e-01
# TIMESTEP 23130 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -2.004377e-01
# TIMESTEP 23176 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -1.368711e-01
# TIMESTEP 23222 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -4.036091e-01
# TIMESTEP 23268 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -7.302573e-02
# TIMESTEP 23314 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -2.171537e-01
# TIMESTEP 23360 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -1.477551e-01
# TIMESTEP 23406 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -2.272353e-01
# TIMESTEP 23452 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -3.261049e-01
# TIMESTEP 23498 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -3.009585e-01
# TIMESTEP 23544 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -1.443064e-01
# TIMESTEP 23590 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -2.833188e-01
# TIMESTEP 23636 / e 0.05 / Agent_score 1 / bar2_score 18 /reward -1 / Q_max -1.696546e-01
# TIMESTEP 23682 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -2.822217e-01
# TIMESTEP 23728 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -1.011527e-01
# TIMESTEP 23774 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -2.422312e-01
# TIMESTEP 23820 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -1.851724e-01
# TIMESTEP 23866 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.478787e-01
# TIMESTEP 23912 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -1.408976e-01
# TIMESTEP 23958 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -3.532963e-01
# TIMESTEP 24004 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -9.941258e-02
# TIMESTEP 24306 / e 0.05 / Agent_score 1 / bar2_score 6 /reward 1 / Q_max 9.540807e-02
# TIMESTEP 24605 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -1.770195e-01
# TIMESTEP 24651 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -4.604523e-01
# TIMESTEP 24697 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -1.008326e-01
# TIMESTEP 24743 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -4.407220e-01
# TIMESTEP 24789 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -3.137368e-01
# TIMESTEP 24835 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -4.677325e-01
# TIMESTEP 24881 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -4.199333e-01
# TIMESTEP 24927 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -2.854926e-01
# TIMESTEP 24973 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -1.835733e-01
# TIMESTEP 25019 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -3.033331e-01
# TIMESTEP 25065 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -1.747872e-01
# TIMESTEP 25111 / e 0.05 / Agent_score 1 / bar2_score 18 /reward -1 / Q_max -3.377889e-01
# TIMESTEP 25157 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -3.290761e-01
# TIMESTEP 25203 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.224736e-01
# TIMESTEP 25249 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -8.349987e-02
# TIMESTEP 25295 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -4.963767e-01
# TIMESTEP 25341 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -1.725494e-01
# TIMESTEP 25387 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.048983e-01
# TIMESTEP 25433 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -2.141088e-01
# TIMESTEP 25479 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -2.906801e-01
# TIMESTEP 25525 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -1.550838e-01
# TIMESTEP 25571 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -3.724256e-01
# TIMESTEP 25617 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -1.578383e-01
# TIMESTEP 25663 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -3.210381e-01
# TIMESTEP 25709 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -8.965323e-02
# TIMESTEP 25755 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -4.119813e-01
# TIMESTEP 25801 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -1.928655e-01
# TIMESTEP 26017 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -4.272388e-02
# TIMESTEP 26063 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -1.380548e-01
# TIMESTEP 26109 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -3.153902e-01
# TIMESTEP 26155 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -1.249844e-01
# TIMESTEP 26368 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -2.429669e-01
# TIMESTEP 26414 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -1.645332e-01
# TIMESTEP 26460 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -5.100521e-01
# TIMESTEP 26506 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -7.076231e-02
# TIMESTEP 26552 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -5.688258e-01
# TIMESTEP 26598 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -2.793750e-01
# TIMESTEP 26644 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.128943e-01
# TIMESTEP 26690 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -1.458873e-01
# TIMESTEP 26736 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -3.444868e-01
# TIMESTEP 26782 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -1.206288e-01
# TIMESTEP 27083 / e 0.05 / Agent_score 1 / bar2_score 7 /reward 1 / Q_max -1.124679e-01
# TIMESTEP 27212 / e 0.05 / Agent_score 1 / bar2_score 8 /reward -1 / Q_max -8.803691e-02
# TIMESTEP 27258 / e 0.05 / Agent_score 1 / bar2_score 9 /reward -1 / Q_max -1.152176e-01
# TIMESTEP 27304 / e 0.05 / Agent_score 1 / bar2_score 10 /reward -1 / Q_max -5.113825e-01
# TIMESTEP 27350 / e 0.05 / Agent_score 1 / bar2_score 11 /reward -1 / Q_max -3.142162e-01
# TIMESTEP 27396 / e 0.05 / Agent_score 1 / bar2_score 12 /reward -1 / Q_max -5.978603e-01
# TIMESTEP 27442 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -2.471985e-01
# TIMESTEP 27488 / e 0.05 / Agent_score 1 / bar2_score 14 /reward -1 / Q_max -4.897118e-01
# TIMESTEP 27534 / e 0.05 / Agent_score 1 / bar2_score 15 /reward -1 / Q_max -2.957232e-01
# TIMESTEP 27580 / e 0.05 / Agent_score 1 / bar2_score 16 /reward -1 / Q_max -4.758387e-01
# TIMESTEP 27626 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -2.700582e-01
# TIMESTEP 27672 / e 0.05 / Agent_score 1 / bar2_score 18 /reward -1 / Q_max -5.196887e-01
# TIMESTEP 27718 / e 0.05 / Agent_score 1 / bar2_score 19 /reward -1 / Q_max -2.476648e-01
# TIMESTEP 27764 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.699015e-01
# TIMESTEP 27810 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -1.699952e-01
# TIMESTEP 27856 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -5.720913e-01
# TIMESTEP 27902 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -1.901223e-01
# TIMESTEP 27948 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -5.703551e-01
# TIMESTEP 27994 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -2.616806e-01
# TIMESTEP 28040 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -5.160249e-01
# TIMESTEP 28086 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -1.714454e-01
# TIMESTEP 28132 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -5.034764e-01
# TIMESTEP 28178 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -1.849357e-01
# TIMESTEP 28224 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -4.078956e-01
# TIMESTEP 28270 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -3.071278e-01
# TIMESTEP 28316 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -6.239551e-01
# TIMESTEP 28362 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -2.881098e-01
# TIMESTEP 28408 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -4.725962e-01
# TIMESTEP 28454 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -2.866889e-01
# TIMESTEP 28500 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -4.946719e-01
# TIMESTEP 28546 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -2.455437e-01
# TIMESTEP 28592 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -5.450212e-01
# TIMESTEP 28638 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -2.220063e-01
# TIMESTEP 28684 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.022841e-01
# TIMESTEP 28730 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -1.883250e-01
# TIMESTEP 28776 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -6.630110e-01
# TIMESTEP 28822 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -3.273275e-01
# TIMESTEP 28868 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -5.156118e-01
# TIMESTEP 28914 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -2.572117e-01
# TIMESTEP 28960 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -5.003399e-01
# TIMESTEP 29006 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -2.137189e-01
# TIMESTEP 29052 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -6.619877e-01
# TIMESTEP 29098 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -2.232526e-01
# TIMESTEP 29144 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -4.895850e-01
# TIMESTEP 29190 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -1.826654e-01
# TIMESTEP 29406 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -7.352836e-02
# TIMESTEP 29536 / e 0.05 / Agent_score 1 / bar2_score 12 /reward 1 / Q_max 1.128220e-01
# TIMESTEP 29833 / e 0.05 / Agent_score 1 / bar2_score 13 /reward -1 / Q_max -8.039393e-02
# TIMESTEP 30130 / e 0.05 / Agent_score 2 / bar2_score 13 /reward 1 / Q_max -1.422590e-01
# TIMESTEP 30427 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -3.102707e-02
# TIMESTEP 30473 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -7.276635e-01
# TIMESTEP 30519 / e 0.05 / Agent_score 2 / bar2_score 16 /reward -1 / Q_max -2.133302e-01
# TIMESTEP 30565 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -7.096287e-01
# TIMESTEP 30611 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -3.106345e-01
# TIMESTEP 30911 / e 0.05 / Agent_score 3 / bar2_score 18 /reward 1 / Q_max -5.652178e-04
# TIMESTEP 31040 / e 0.05 / Agent_score 3 / bar2_score 19 /reward -1 / Q_max 3.178273e-02
# TIMESTEP 31086 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -7.013944e-02
# TIMESTEP 31132 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -6.245605e-01
# TIMESTEP 31178 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -4.887655e-01
# TIMESTEP 31224 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -7.451769e-01
# TIMESTEP 31270 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -2.739826e-01
# TIMESTEP 31316 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -6.378633e-01
# TIMESTEP 31362 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -2.850676e-01
# TIMESTEP 31408 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -6.799243e-01
# TIMESTEP 31454 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -3.533559e-01
# TIMESTEP 31500 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -6.561002e-01
# TIMESTEP 31546 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -3.251054e-01
# TIMESTEP 31592 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -6.095849e-01
# TIMESTEP 31638 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -4.684647e-01
# TIMESTEP 31684 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -6.956145e-01
# TIMESTEP 31730 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -5.465092e-01
# TIMESTEP 31776 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -7.877654e-01
# TIMESTEP 31822 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -3.703367e-01
# TIMESTEP 32120 / e 0.05 / Agent_score 1 / bar2_score 16 /reward 1 / Q_max 8.887286e-02
# TIMESTEP 32249 / e 0.05 / Agent_score 1 / bar2_score 17 /reward -1 / Q_max -1.327058e-01
# TIMESTEP 32378 / e 0.05 / Agent_score 2 / bar2_score 17 /reward 1 / Q_max 1.159342e-01
# TIMESTEP 32507 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -4.588399e-02
# TIMESTEP 32636 / e 0.05 / Agent_score 3 / bar2_score 18 /reward 1 / Q_max 1.979034e-01
# TIMESTEP 32765 / e 0.05 / Agent_score 3 / bar2_score 19 /reward -1 / Q_max -2.581584e-02
# TIMESTEP 32811 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -2.135246e-01
# TIMESTEP 32857 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -6.330973e-01
# TIMESTEP 32903 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -5.810035e-01
# TIMESTEP 32949 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -7.974390e-01
# TIMESTEP 32995 / e 0.05 / Agent_score 0 / bar2_score 4 /reward -1 / Q_max -3.344488e-01
# TIMESTEP 33041 / e 0.05 / Agent_score 0 / bar2_score 5 /reward -1 / Q_max -8.563001e-01
# TIMESTEP 33087 / e 0.05 / Agent_score 0 / bar2_score 6 /reward -1 / Q_max -3.874668e-01
# TIMESTEP 33133 / e 0.05 / Agent_score 0 / bar2_score 7 /reward -1 / Q_max -8.863001e-01
# TIMESTEP 33179 / e 0.05 / Agent_score 0 / bar2_score 8 /reward -1 / Q_max -4.603781e-01
# TIMESTEP 33225 / e 0.05 / Agent_score 0 / bar2_score 9 /reward -1 / Q_max -8.004373e-01
# TIMESTEP 33271 / e 0.05 / Agent_score 0 / bar2_score 10 /reward -1 / Q_max -4.603473e-01
# TIMESTEP 33317 / e 0.05 / Agent_score 0 / bar2_score 11 /reward -1 / Q_max -9.063720e-01
# TIMESTEP 33363 / e 0.05 / Agent_score 0 / bar2_score 12 /reward -1 / Q_max -5.538117e-01
# TIMESTEP 33409 / e 0.05 / Agent_score 0 / bar2_score 13 /reward -1 / Q_max -8.286263e-01
# TIMESTEP 33455 / e 0.05 / Agent_score 0 / bar2_score 14 /reward -1 / Q_max -5.239474e-01
# TIMESTEP 33501 / e 0.05 / Agent_score 0 / bar2_score 15 /reward -1 / Q_max -9.227286e-01
# TIMESTEP 33547 / e 0.05 / Agent_score 0 / bar2_score 16 /reward -1 / Q_max -4.124911e-01
# TIMESTEP 33593 / e 0.05 / Agent_score 0 / bar2_score 17 /reward -1 / Q_max -9.032132e-01
# TIMESTEP 33639 / e 0.05 / Agent_score 0 / bar2_score 18 /reward -1 / Q_max -4.694839e-01
# TIMESTEP 33685 / e 0.05 / Agent_score 0 / bar2_score 19 /reward -1 / Q_max -9.483806e-01
# TIMESTEP 33731 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.878990e-01
# TIMESTEP 33777 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -7.977367e-01
# TIMESTEP 33823 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -6.706769e-01
# TIMESTEP 33869 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -1.009131e+00
# TIMESTEP 34000 / e 0.05 / Agent_score 1 / bar2_score 3 /reward 1 / Q_max 2.312515e-01
# TIMESTEP 34129 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -5.567976e-02
# TIMESTEP 34258 / e 0.05 / Agent_score 2 / bar2_score 4 /reward 1 / Q_max 2.320123e-01
# TIMESTEP 34387 / e 0.05 / Agent_score 2 / bar2_score 5 /reward -1 / Q_max -4.940460e-02
# TIMESTEP 34433 / e 0.05 / Agent_score 2 / bar2_score 6 /reward -1 / Q_max -2.620460e-01
# TIMESTEP 34479 / e 0.05 / Agent_score 2 / bar2_score 7 /reward -1 / Q_max -8.638977e-01
# TIMESTEP 34525 / e 0.05 / Agent_score 2 / bar2_score 8 /reward -1 / Q_max -3.871318e-01
# TIMESTEP 34571 / e 0.05 / Agent_score 2 / bar2_score 9 /reward -1 / Q_max -9.498081e-01
# TIMESTEP 34617 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -4.997297e-01
# TIMESTEP 34663 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -8.928603e-01
# TIMESTEP 34709 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -5.516899e-01
# TIMESTEP 34755 / e 0.05 / Agent_score 2 / bar2_score 13 /reward -1 / Q_max -9.452887e-01
# TIMESTEP 34801 / e 0.05 / Agent_score 2 / bar2_score 14 /reward -1 / Q_max -5.817221e-01
# TIMESTEP 34847 / e 0.05 / Agent_score 2 / bar2_score 15 /reward -1 / Q_max -1.069962e+00
# TIMESTEP 34893 / e 0.05 / Agent_score 2 / bar2_score 16 /reward -1 / Q_max -5.361369e-01
# TIMESTEP 34939 / e 0.05 / Agent_score 2 / bar2_score 17 /reward -1 / Q_max -1.018290e+00
# TIMESTEP 34985 / e 0.05 / Agent_score 2 / bar2_score 18 /reward -1 / Q_max -6.098630e-01
# TIMESTEP 35031 / e 0.05 / Agent_score 2 / bar2_score 19 /reward -1 / Q_max -1.014841e+00
# TIMESTEP 35077 / e 0.05 / Agent_score 0 / bar2_score 0 /reward -1 / Q_max -4.794849e-01
# TIMESTEP 35293 / e 0.05 / Agent_score 0 / bar2_score 1 /reward -1 / Q_max -3.771604e-02
# TIMESTEP 35339 / e 0.05 / Agent_score 0 / bar2_score 2 /reward -1 / Q_max -5.583752e-01
# TIMESTEP 35385 / e 0.05 / Agent_score 0 / bar2_score 3 /reward -1 / Q_max -9.174701e-01
# TIMESTEP 35516 / e 0.05 / Agent_score 1 / bar2_score 3 /reward 1 / Q_max 2.770395e-01
# TIMESTEP 35645 / e 0.05 / Agent_score 1 / bar2_score 4 /reward -1 / Q_max -7.279401e-02
# TIMESTEP 35691 / e 0.05 / Agent_score 1 / bar2_score 5 /reward -1 / Q_max -3.584239e-01
# TIMESTEP 35737 / e 0.05 / Agent_score 1 / bar2_score 6 /reward -1 / Q_max -8.948876e-01
# TIMESTEP 35783 / e 0.05 / Agent_score 1 / bar2_score 7 /reward -1 / Q_max -4.932920e-01
# TIMESTEP 36085 / e 0.05 / Agent_score 2 / bar2_score 7 /reward 1 / Q_max -5.775965e-02
# TIMESTEP 36214 / e 0.05 / Agent_score 2 / bar2_score 8 /reward -1 / Q_max -1.678400e-01
# TIMESTEP 36260 / e 0.05 / Agent_score 2 / bar2_score 9 /reward -1 / Q_max -4.246601e-01
# TIMESTEP 36306 / e 0.05 / Agent_score 2 / bar2_score 10 /reward -1 / Q_max -9.480321e-01
# TIMESTEP 36352 / e 0.05 / Agent_score 2 / bar2_score 11 /reward -1 / Q_max -4.747261e-01
# TIMESTEP 36398 / e 0.05 / Agent_score 2 / bar2_score 12 /reward -1 / Q_max -1.099479e+00
# TIMESTEP 36444 / e 0.05 / Agent_score 2 / bar2_score 13 /reward -1 / Q_max -6.070428e-01
# ...
# TIMESTEP 291267 / e 0.05 / Agent_score 16 / bar2_score 12 /reward -1 / Q_max 3.777798e-01
# TIMESTEP 291313 / e 0.05 / Agent_score 16 / bar2_score 13 /reward -1 / Q_max -5.144151e-01
# TIMESTEP 291442 / e 0.05 / Agent_score 17 / bar2_score 13 /reward 1 / Q_max 1.531034e+00
# TIMESTEP 291824 / e 0.05 / Agent_score 18 / bar2_score 13 /reward 1 / Q_max 1.525533e+00
# TIMESTEP 292205 / e 0.05 / Agent_score 19 / bar2_score 13 /reward 1 / Q_max 1.642008e+00
# TIMESTEP 292586 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.635297e+00
# TIMESTEP 292967 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.654317e+00
# TIMESTEP 293348 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.636926e+00
# TIMESTEP 293477 / e 0.05 / Agent_score 2 / bar2_score 1 /reward -1 / Q_max -4.148458e-01
# TIMESTEP 293606 / e 0.05 / Agent_score 3 / bar2_score 1 /reward 1 / Q_max 1.619136e+00
# TIMESTEP 293989 / e 0.05 / Agent_score 4 / bar2_score 1 /reward 1 / Q_max 1.560345e+00
# TIMESTEP 294370 / e 0.05 / Agent_score 5 / bar2_score 1 /reward 1 / Q_max 1.665582e+00
# TIMESTEP 294751 / e 0.05 / Agent_score 6 / bar2_score 1 /reward 1 / Q_max 1.612338e+00
# TIMESTEP 294880 / e 0.05 / Agent_score 6 / bar2_score 2 /reward -1 / Q_max 1.578905e-01
# TIMESTEP 295009 / e 0.05 / Agent_score 7 / bar2_score 2 /reward 1 / Q_max 1.456848e+00
# TIMESTEP 295138 / e 0.05 / Agent_score 7 / bar2_score 3 /reward -1 / Q_max 5.861751e-03
# TIMESTEP 295267 / e 0.05 / Agent_score 8 / bar2_score 3 /reward 1 / Q_max 1.342064e+00
# TIMESTEP 295648 / e 0.05 / Agent_score 9 / bar2_score 3 /reward 1 / Q_max 1.553879e+00
# TIMESTEP 296031 / e 0.05 / Agent_score 10 / bar2_score 3 /reward 1 / Q_max 1.329076e+00
# TIMESTEP 296412 / e 0.05 / Agent_score 11 / bar2_score 3 /reward 1 / Q_max 1.603971e+00
# TIMESTEP 296793 / e 0.05 / Agent_score 12 / bar2_score 3 /reward 1 / Q_max 1.594253e+00
# TIMESTEP 297174 / e 0.05 / Agent_score 13 / bar2_score 3 /reward 1 / Q_max 1.640824e+00
# TIMESTEP 297555 / e 0.05 / Agent_score 14 / bar2_score 3 /reward 1 / Q_max 1.574844e+00
# TIMESTEP 297936 / e 0.05 / Agent_score 15 / bar2_score 3 /reward 1 / Q_max 1.531302e+00
# TIMESTEP 298317 / e 0.05 / Agent_score 16 / bar2_score 3 /reward 1 / Q_max 1.549546e+00
# TIMESTEP 298700 / e 0.05 / Agent_score 17 / bar2_score 3 /reward 1 / Q_max 1.408940e+00
# TIMESTEP 299081 / e 0.05 / Agent_score 18 / bar2_score 3 /reward 1 / Q_max 1.552702e+00
# TIMESTEP 299462 / e 0.05 / Agent_score 19 / bar2_score 3 /reward 1 / Q_max 1.565846e+00
# TIMESTEP 299843 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.553394e+00
# TIMESTEP 300226 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.469673e+00
# TIMESTEP 300607 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.615842e+00
# TIMESTEP 300988 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.608695e+00
# TIMESTEP 301369 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.642075e+00
# TIMESTEP 301750 / e 0.05 / Agent_score 5 / bar2_score 0 /reward 1 / Q_max 1.651487e+00
# TIMESTEP 302131 / e 0.05 / Agent_score 6 / bar2_score 0 /reward 1 / Q_max 1.595794e+00
# TIMESTEP 302260 / e 0.05 / Agent_score 6 / bar2_score 1 /reward -1 / Q_max 1.761366e-01
# TIMESTEP 302389 / e 0.05 / Agent_score 7 / bar2_score 1 /reward 1 / Q_max 1.646252e+00
# TIMESTEP 302772 / e 0.05 / Agent_score 8 / bar2_score 1 /reward 1 / Q_max 1.482494e+00
# TIMESTEP 303153 / e 0.05 / Agent_score 9 / bar2_score 1 /reward 1 / Q_max 1.629022e+00
# TIMESTEP 303534 / e 0.05 / Agent_score 10 / bar2_score 1 /reward 1 / Q_max 1.668407e+00
# TIMESTEP 303915 / e 0.05 / Agent_score 11 / bar2_score 1 /reward 1 / Q_max 1.731462e+00
# TIMESTEP 304214 / e 0.05 / Agent_score 11 / bar2_score 2 /reward -1 / Q_max 4.585963e-01
# TIMESTEP 304260 / e 0.05 / Agent_score 11 / bar2_score 3 /reward -1 / Q_max -5.591469e-01
# TIMESTEP 304389 / e 0.05 / Agent_score 12 / bar2_score 3 /reward 1 / Q_max 1.384786e+00
# TIMESTEP 304770 / e 0.05 / Agent_score 13 / bar2_score 3 /reward 1 / Q_max 1.657012e+00
# TIMESTEP 305153 / e 0.05 / Agent_score 14 / bar2_score 3 /reward 1 / Q_max 1.368227e+00
# TIMESTEP 305534 / e 0.05 / Agent_score 15 / bar2_score 3 /reward 1 / Q_max 1.543826e+00
# TIMESTEP 305915 / e 0.05 / Agent_score 16 / bar2_score 3 /reward 1 / Q_max 1.502185e+00
# TIMESTEP 306296 / e 0.05 / Agent_score 17 / bar2_score 3 /reward 1 / Q_max 1.569075e+00
# TIMESTEP 306677 / e 0.05 / Agent_score 18 / bar2_score 3 /reward 1 / Q_max 1.554217e+00
# TIMESTEP 307058 / e 0.05 / Agent_score 19 / bar2_score 3 /reward 1 / Q_max 1.571676e+00
# TIMESTEP 307439 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.568529e+00
# TIMESTEP 307821 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.514778e+00
# TIMESTEP 308202 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.573262e+00
# TIMESTEP 308583 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.599466e+00
# TIMESTEP 308964 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.577041e+00
# TIMESTEP 309345 / e 0.05 / Agent_score 5 / bar2_score 0 /reward 1 / Q_max 1.586441e+00
# TIMESTEP 309726 / e 0.05 / Agent_score 6 / bar2_score 0 /reward 1 / Q_max 1.578537e+00
# TIMESTEP 310107 / e 0.05 / Agent_score 7 / bar2_score 0 /reward 1 / Q_max 1.613587e+00
# TIMESTEP 310488 / e 0.05 / Agent_score 8 / bar2_score 0 /reward 1 / Q_max 1.543646e+00
# TIMESTEP 310869 / e 0.05 / Agent_score 9 / bar2_score 0 /reward 1 / Q_max 1.548980e+00
# TIMESTEP 311250 / e 0.05 / Agent_score 10 / bar2_score 0 /reward 1 / Q_max 1.600896e+00
# TIMESTEP 311633 / e 0.05 / Agent_score 11 / bar2_score 0 /reward 1 / Q_max 1.465241e+00
# TIMESTEP 312014 / e 0.05 / Agent_score 12 / bar2_score 0 /reward 1 / Q_max 1.507194e+00
# TIMESTEP 312395 / e 0.05 / Agent_score 13 / bar2_score 0 /reward 1 / Q_max 1.573585e+00
# TIMESTEP 312778 / e 0.05 / Agent_score 14 / bar2_score 0 /reward 1 / Q_max 1.446510e+00
# TIMESTEP 313160 / e 0.05 / Agent_score 15 / bar2_score 0 /reward 1 / Q_max 1.418322e+00
# TIMESTEP 313289 / e 0.05 / Agent_score 15 / bar2_score 1 /reward -1 / Q_max 3.538685e-01
# TIMESTEP 313418 / e 0.05 / Agent_score 16 / bar2_score 1 /reward 1 / Q_max 1.444506e+00
# TIMESTEP 313799 / e 0.05 / Agent_score 17 / bar2_score 1 /reward 1 / Q_max 1.547778e+00
# TIMESTEP 314180 / e 0.05 / Agent_score 18 / bar2_score 1 /reward 1 / Q_max 1.566160e+00
# TIMESTEP 314561 / e 0.05 / Agent_score 19 / bar2_score 1 /reward 1 / Q_max 1.587581e+00
# TIMESTEP 314943 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.499776e+00
# TIMESTEP 315325 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.466894e+00
# TIMESTEP 315708 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.463212e+00
# TIMESTEP 316091 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.433365e+00
# TIMESTEP 316472 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.576433e+00
# TIMESTEP 316853 / e 0.05 / Agent_score 5 / bar2_score 0 /reward 1 / Q_max 1.558639e+00
# TIMESTEP 317234 / e 0.05 / Agent_score 6 / bar2_score 0 /reward 1 / Q_max 1.573164e+00
# TIMESTEP 317615 / e 0.05 / Agent_score 7 / bar2_score 0 /reward 1 / Q_max 1.573079e+00
# TIMESTEP 317744 / e 0.05 / Agent_score 7 / bar2_score 1 /reward -1 / Q_max -4.580358e-01
# TIMESTEP 317873 / e 0.05 / Agent_score 8 / bar2_score 1 /reward 1 / Q_max 1.505062e+00
# TIMESTEP 318254 / e 0.05 / Agent_score 9 / bar2_score 1 /reward 1 / Q_max 1.554004e+00
# TIMESTEP 318635 / e 0.05 / Agent_score 10 / bar2_score 1 /reward 1 / Q_max 1.539757e+00
# TIMESTEP 319018 / e 0.05 / Agent_score 11 / bar2_score 1 /reward 1 / Q_max 1.513789e+00
# TIMESTEP 319399 / e 0.05 / Agent_score 12 / bar2_score 1 /reward 1 / Q_max 1.505475e+00
# TIMESTEP 319780 / e 0.05 / Agent_score 13 / bar2_score 1 /reward 1 / Q_max 1.579964e+00
# TIMESTEP 320161 / e 0.05 / Agent_score 14 / bar2_score 1 /reward 1 / Q_max 1.525306e+00
# TIMESTEP 320542 / e 0.05 / Agent_score 15 / bar2_score 1 /reward 1 / Q_max 1.514315e+00
# TIMESTEP 320923 / e 0.05 / Agent_score 16 / bar2_score 1 /reward 1 / Q_max 1.494229e+00
# TIMESTEP 321304 / e 0.05 / Agent_score 17 / bar2_score 1 /reward 1 / Q_max 1.531906e+00
# TIMESTEP 321685 / e 0.05 / Agent_score 18 / bar2_score 1 /reward 1 / Q_max 1.483677e+00
# TIMESTEP 322066 / e 0.05 / Agent_score 19 / bar2_score 1 /reward 1 / Q_max 1.480136e+00
# TIMESTEP 322447 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.442663e+00
# TIMESTEP 322828 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.530361e+00
# TIMESTEP 323125 / e 0.05 / Agent_score 1 / bar2_score 1 /reward -1 / Q_max 4.609248e-01
# TIMESTEP 323171 / e 0.05 / Agent_score 1 / bar2_score 2 /reward -1 / Q_max -5.527983e-01
# TIMESTEP 323300 / e 0.05 / Agent_score 2 / bar2_score 2 /reward 1 / Q_max 1.433876e+00
# TIMESTEP 323681 / e 0.05 / Agent_score 3 / bar2_score 2 /reward 1 / Q_max 1.478021e+00
# TIMESTEP 324062 / e 0.05 / Agent_score 4 / bar2_score 2 /reward 1 / Q_max 1.523868e+00
# TIMESTEP 324445 / e 0.05 / Agent_score 5 / bar2_score 2 /reward 1 / Q_max 1.394689e+00
# TIMESTEP 324826 / e 0.05 / Agent_score 6 / bar2_score 2 /reward 1 / Q_max 1.469220e+00
# TIMESTEP 324955 / e 0.05 / Agent_score 6 / bar2_score 3 /reward -1 / Q_max -6.776546e-02
# TIMESTEP 325084 / e 0.05 / Agent_score 7 / bar2_score 3 /reward 1 / Q_max 1.449025e+00
# TIMESTEP 325465 / e 0.05 / Agent_score 8 / bar2_score 3 /reward 1 / Q_max 1.430304e+00
# TIMESTEP 325846 / e 0.05 / Agent_score 9 / bar2_score 3 /reward 1 / Q_max 1.457668e+00
# TIMESTEP 326227 / e 0.05 / Agent_score 10 / bar2_score 3 /reward 1 / Q_max 1.503296e+00
# TIMESTEP 326608 / e 0.05 / Agent_score 11 / bar2_score 3 /reward 1 / Q_max 1.484942e+00
# TIMESTEP 326989 / e 0.05 / Agent_score 12 / bar2_score 3 /reward 1 / Q_max 1.456009e+00
# TIMESTEP 327370 / e 0.05 / Agent_score 13 / bar2_score 3 /reward 1 / Q_max 1.558056e+00
# TIMESTEP 327751 / e 0.05 / Agent_score 14 / bar2_score 3 /reward 1 / Q_max 1.461633e+00
# TIMESTEP 328134 / e 0.05 / Agent_score 15 / bar2_score 3 /reward 1 / Q_max 1.373544e+00
# TIMESTEP 328516 / e 0.05 / Agent_score 16 / bar2_score 3 /reward 1 / Q_max 1.376385e+00
# TIMESTEP 328897 / e 0.05 / Agent_score 17 / bar2_score 3 /reward 1 / Q_max 1.469555e+00
# TIMESTEP 329278 / e 0.05 / Agent_score 18 / bar2_score 3 /reward 1 / Q_max 1.467609e+00
# TIMESTEP 329659 / e 0.05 / Agent_score 19 / bar2_score 3 /reward 1 / Q_max 1.446976e+00
# TIMESTEP 330041 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.375122e+00
# TIMESTEP 330424 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.468986e+00
# TIMESTEP 330807 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.427783e+00
# TIMESTEP 331189 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.387964e+00
# TIMESTEP 331570 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.451289e+00
# TIMESTEP 331951 / e 0.05 / Agent_score 5 / bar2_score 0 /reward 1 / Q_max 1.476460e+00
# TIMESTEP 332333 / e 0.05 / Agent_score 6 / bar2_score 0 /reward 1 / Q_max 1.432839e+00
# TIMESTEP 332714 / e 0.05 / Agent_score 7 / bar2_score 0 /reward 1 / Q_max 1.458964e+00
# TIMESTEP 333097 / e 0.05 / Agent_score 8 / bar2_score 0 /reward 1 / Q_max 1.396374e+00
# TIMESTEP 333478 / e 0.05 / Agent_score 9 / bar2_score 0 /reward 1 / Q_max 1.398316e+00
# TIMESTEP 333859 / e 0.05 / Agent_score 10 / bar2_score 0 /reward 1 / Q_max 1.472092e+00
# TIMESTEP 334240 / e 0.05 / Agent_score 11 / bar2_score 0 /reward 1 / Q_max 1.456822e+00
# TIMESTEP 334621 / e 0.05 / Agent_score 12 / bar2_score 0 /reward 1 / Q_max 1.450362e+00
# TIMESTEP 334919 / e 0.05 / Agent_score 12 / bar2_score 1 /reward -1 / Q_max 6.156875e-01
# TIMESTEP 334965 / e 0.05 / Agent_score 12 / bar2_score 2 /reward -1 / Q_max -4.199609e-01
# TIMESTEP 335094 / e 0.05 / Agent_score 13 / bar2_score 2 /reward 1 / Q_max 1.486380e+00
# TIMESTEP 335475 / e 0.05 / Agent_score 14 / bar2_score 2 /reward 1 / Q_max 1.442027e+00
# TIMESTEP 335856 / e 0.05 / Agent_score 15 / bar2_score 2 /reward 1 / Q_max 1.453804e+00
# TIMESTEP 336239 / e 0.05 / Agent_score 16 / bar2_score 2 /reward 1 / Q_max 1.503879e+00
# TIMESTEP 336620 / e 0.05 / Agent_score 17 / bar2_score 2 /reward 1 / Q_max 1.445378e+00
# TIMESTEP 337002 / e 0.05 / Agent_score 18 / bar2_score 2 /reward 1 / Q_max 1.407905e+00
# TIMESTEP 337383 / e 0.05 / Agent_score 19 / bar2_score 2 /reward 1 / Q_max 1.401438e+00
# TIMESTEP 337764 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.312296e+00
# TIMESTEP 338145 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.509466e+00
# TIMESTEP 338526 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.449798e+00
# TIMESTEP 338907 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.485244e+00
# TIMESTEP 339288 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.502831e+00
# TIMESTEP 339417 / e 0.05 / Agent_score 4 / bar2_score 1 /reward -1 / Q_max -4.377611e-01
# TIMESTEP 339546 / e 0.05 / Agent_score 5 / bar2_score 1 /reward 1 / Q_max 1.458300e+00
# TIMESTEP 339927 / e 0.05 / Agent_score 6 / bar2_score 1 /reward 1 / Q_max 1.525004e+00
# TIMESTEP 340056 / e 0.05 / Agent_score 6 / bar2_score 2 /reward -1 / Q_max -3.464192e-01
# TIMESTEP 340185 / e 0.05 / Agent_score 7 / bar2_score 2 /reward 1 / Q_max 1.441818e+00
# TIMESTEP 340566 / e 0.05 / Agent_score 8 / bar2_score 2 /reward 1 / Q_max 1.412390e+00
# TIMESTEP 340947 / e 0.05 / Agent_score 9 / bar2_score 2 /reward 1 / Q_max 1.460013e+00
# TIMESTEP 341328 / e 0.05 / Agent_score 10 / bar2_score 2 /reward 1 / Q_max 1.442913e+00
# TIMESTEP 341709 / e 0.05 / Agent_score 11 / bar2_score 2 /reward 1 / Q_max 1.456495e+00
# TIMESTEP 342007 / e 0.05 / Agent_score 11 / bar2_score 3 /reward -1 / Q_max 4.877570e-01
# TIMESTEP 342053 / e 0.05 / Agent_score 11 / bar2_score 4 /reward -1 / Q_max -6.497959e-01
# TIMESTEP 342182 / e 0.05 / Agent_score 12 / bar2_score 4 /reward 1 / Q_max 1.441643e+00
# TIMESTEP 342564 / e 0.05 / Agent_score 13 / bar2_score 4 /reward 1 / Q_max 1.479037e+00
# TIMESTEP 342945 / e 0.05 / Agent_score 14 / bar2_score 4 /reward 1 / Q_max 1.479069e+00
# TIMESTEP 343326 / e 0.05 / Agent_score 15 / bar2_score 4 /reward 1 / Q_max 1.421004e+00
# TIMESTEP 343707 / e 0.05 / Agent_score 16 / bar2_score 4 /reward 1 / Q_max 1.410911e+00
# TIMESTEP 344088 / e 0.05 / Agent_score 17 / bar2_score 4 /reward 1 / Q_max 1.424665e+00
# TIMESTEP 344470 / e 0.05 / Agent_score 18 / bar2_score 4 /reward 1 / Q_max 1.444107e+00
# TIMESTEP 344851 / e 0.05 / Agent_score 19 / bar2_score 4 /reward 1 / Q_max 1.380600e+00
# TIMESTEP 345233 / e 0.05 / Agent_score 0 / bar2_score 0 /reward 1 / Q_max 1.316761e+00
# TIMESTEP 345614 / e 0.05 / Agent_score 1 / bar2_score 0 /reward 1 / Q_max 1.470993e+00
# TIMESTEP 345995 / e 0.05 / Agent_score 2 / bar2_score 0 /reward 1 / Q_max 1.376232e+00
# TIMESTEP 346376 / e 0.05 / Agent_score 3 / bar2_score 0 /reward 1 / Q_max 1.422400e+00
# TIMESTEP 346757 / e 0.05 / Agent_score 4 / bar2_score 0 /reward 1 / Q_max 1.431521e+00
# TIMESTEP 347138 / e 0.05 / Agent_score 5 / bar2_score 0 /reward 1 / Q_max 1.377078e+00
# TIMESTEP 347519 / e 0.05 / Agent_score 6 / bar2_score 0 /reward 1 / Q_max 1.379008e+00
# TIMESTEP 347900 / e 0.05 / Agent_score 7 / bar2_score 0 /reward 1 / Q_max 1.376339e+00
# TIMESTEP 348281 / e 0.05 / Agent_score 8 / bar2_score 0 /reward 1 / Q_max 1.337619e+00
# TIMESTEP 348662 / e 0.05 / Agent_score 9 / bar2_score 0 /reward 1 / Q_max 1.364239e+00
# TIMESTEP 349045 / e 0.05 / Agent_score 10 / bar2_score 0 /reward 1 / Q_max 1.436374e+00
# TIMESTEP 349428 / e 0.05 / Agent_score 11 / bar2_score 0 /reward 1 / Q_max 1.304887e+00
# TIMESTEP 349809 / e 0.05 / Agent_score 12 / bar2_score 0 /reward 1 / Q_max 1.316579e+00
# TIMESTEP 350192 / e 0.05 / Agent_score 13 / bar2_score 0 /reward 1 / Q_max 1.359765e+00
# TIMESTEP 350573 / e 0.05 / Agent_score 14 / bar2_score 0 /reward 1 / Q_max 1.345344e+00
# TIMESTEP 350955 / e 0.05 / Agent_score 15 / bar2_score 0 /reward 1 / Q_max 1.324572e+00
# TIMESTEP 351336 / e 0.05 / Agent_score 16 / bar2_score 0 /reward 1 / Q_max 1.264039e+00
# TIMESTEP 351717 / e 0.05 / Agent_score 17 / bar2_score 0 /reward 1 / Q_max 1.298624e+00
# TIMESTEP 352099 / e 0.05 / Agent_score 18 / bar2_score 0 /reward 1 / Q_max 1.292305e+00
# TIMESTEP 352480 / e 0.05 / Agent_score 19 / bar2_score 0 /reward 1 / Q_max 1.322670e+00
# Game_Ends_in Time: 36841
