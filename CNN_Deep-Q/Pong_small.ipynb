# %%
import tensorflow as tf
import cv2
import sys
sys.path.append("Wrapped Game Code/")
import pong_fun as game # whichever is imported "as game" will be used
import dummy_game
#import tetris_fun as game
import random
import time 
import numpy as np
from collections import deque
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
GAME = 'pong' # the name of the game being played for log files
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 500. # timesteps to observe before training
EXPLORE = 500. # frames over which to anneal epsilon
FINAL_EPSILON = 0.05 # final value of epsilon
INITIAL_EPSILON = 1.0 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
K = 1 # only select an action every Kth frame, repeat prev for others

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.01)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.01, shape = shape)
    return tf.Variable(initial)

def conv2d(x, W, stride):
    return tf.nn.conv2d(x, W, strides = [1, stride, stride, 1], padding = "SAME")

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = "SAME")

def createNetwork():
    # network weights
    W_conv1 = weight_variable([8, 8, 4, 32])
    b_conv1 = bias_variable([32])

    W_conv2 = weight_variable([4, 4, 32, 64])
    b_conv2 = bias_variable([64])

    W_conv3 = weight_variable([3, 3, 64, 64])
    b_conv3 = bias_variable([64])
    
    W_fc1 = weight_variable([1600, 512])
    b_fc1 = bias_variable([512])

    W_fc2 = weight_variable([512, ACTIONS])
    b_fc2 = bias_variable([ACTIONS])

    # input layer
    s = tf.placeholder("float", [None, 80, 80, 4])

    # hidden layers
    h_conv1 = tf.nn.relu(conv2d(s, W_conv1, 4) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)

    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2, 2) + b_conv2)
    #h_pool2 = max_pool_2x2(h_conv2)

    h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 1) + b_conv3)
    #h_pool3 = max_pool_2x2(h_conv3)

    #h_pool3_flat = tf.reshape(h_pool3, [-1, 256])
    h_conv3_flat = tf.reshape(h_conv3, [-1, 1600])

    h_fc1 = tf.nn.relu(tf.matmul(h_conv3_flat, W_fc1) + b_fc1)

    # readout layer
    readout = tf.matmul(h_fc1, W_fc2) + b_fc2

    return s, readout, h_fc1

# %%
def trainNetwork(s, readout, h_fc1, sess):
    tick = time.time()
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices = 1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()
    # past 3 wins 
    win_score = []
    win_score.append(0)
    win_score.append(0)
    win_score.append(0)
    win_score.append(0)
    # store the previous observations in replay memory
    D = deque()

    # printing
#     a_file = open("logs_" + GAME + "/readout.txt", 'w')
#     h_file = open("logs_" + GAME + "/hidden.txt", 'w')

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal, bar1_score, bar2_score = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)

    # saving and loading networks
    saver = tf.train.Saver()
    sess.run(tf.initialize_all_variables())
#     checkpoint = tf.train.get_checkpoint_state("saved_networks")
#     if checkpoint and checkpoint.model_checkpoint_path:
#         saver.restore(sess, checkpoint.model_checkpoint_path)
#         print( "Successfully loaded:", checkpoint.model_checkpoint_path)
#     else:
#         print ("Could not find old network weights")

    epsilon = INITIAL_EPSILON
    t = 0
    while "pigs" != "fly":
        # choose an action epsilon greedily
        readout_t = readout.eval(feed_dict = {s : [s_t]})[0]
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if random.random() <= epsilon or t <= OBSERVE:
            action_index = random.randrange(ACTIONS)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(readout_t)
            a_t[action_index] = 1

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        for i in range(0, K):
            # run the selected action and observe next state and reward
            x_t1_col, r_t, terminal, bar1_score, bar2_score = game_state.frame_step(a_t)
            x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (80, 80)), cv2.COLOR_BGR2GRAY)
            ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
            x_t1 = np.reshape(x_t1, (80, 80, 1))
            s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)

            # store the transition in D
            D.append((s_t, a_t, r_t, s_t1, terminal))
            if len(D) > REPLAY_MEMORY:
                D.popleft()
        
        # only train if done observing
        if t > OBSERVE:
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch})

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        if t % 10000 == 0:
            saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"
        #print ("TIMESTEP", t, "/ STATE", state, "/ LINES", game_state.total_lines, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t))
        if r_t!= 0:
            print ("TIMESTEP", t, "/ EPSILON", epsilon, "/ bar1_score", bar1_score, "/ bar2_score", bar2_score, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t))
        
        
        win_score.pop(0)
        win_score.append(bar1_score - bar2_score)
        if(np.matrix(win_score).sum() > 72): #72
            print("Game_Ends_in Time:",int(time.time() - tick))
            break;   
        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

# %%
def playGame():
    sess = tf.InteractiveSession()
    s, readout, h_fc1 = createNetwork()
    trainNetwork(s, readout, h_fc1, sess)

# %%
def main():
    playGame()

if __name__ == "__main__":
    tick = time.time()
    main()
    print("Game_Ends_in Time:",int(time.time() - tick))
    print("____________ END HERE _____________")
# Out:
# WARNING:tensorflow:From /home/cnn/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# TIMESTEP 297 / EPSILON 1.0 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.345254e-02
# TIMESTEP 343 / EPSILON 1.0 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.512715e-02
# TIMESTEP 389 / EPSILON 1.0 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.380204e-02
# TIMESTEP 435 / EPSILON 1.0 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.366744e-02
# TIMESTEP 481 / EPSILON 1.0 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.517603e-02
# TIMESTEP 527 / EPSILON 0.9505999999999997 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.245254e-02
# TIMESTEP 573 / EPSILON 0.8631999999999991 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.255603e-02
# TIMESTEP 619 / EPSILON 0.7757999999999985 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.099862e-02
# TIMESTEP 665 / EPSILON 0.6883999999999979 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.222987e-02
# TIMESTEP 711 / EPSILON 0.6009999999999973 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.053443e-02
# TIMESTEP 757 / EPSILON 0.5135999999999967 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.093250e-02
# TIMESTEP 803 / EPSILON 0.42619999999999614 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.086340e-02
# TIMESTEP 849 / EPSILON 0.33879999999999555 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.405122e-02
# TIMESTEP 895 / EPSILON 0.25139999999999496 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.173141e-02
# TIMESTEP 941 / EPSILON 0.16399999999999437 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.006169e-02
# TIMESTEP 987 / EPSILON 0.07659999999999414 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 8.223911e-03
# TIMESTEP 1033 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 5.970706e-03
# TIMESTEP 1079 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 5.085944e-03
# TIMESTEP 1125 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 7.674433e-04
# TIMESTEP 1171 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 8.356422e-04
# TIMESTEP 1217 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -9.959219e-04
# TIMESTEP 1430 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -6.526911e-03
# TIMESTEP 1476 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -7.236623e-03
# TIMESTEP 1522 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -6.944020e-03
# TIMESTEP 1568 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -8.116986e-03
# TIMESTEP 1784 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.026217e-02
# TIMESTEP 1830 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -2.063241e-02
# TIMESTEP 2046 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -3.289241e-02
# TIMESTEP 2092 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -3.081561e-02
# TIMESTEP 2138 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -2.841946e-02
# TIMESTEP 2184 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -3.937891e-02
# TIMESTEP 2397 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -4.660964e-02
# TIMESTEP 2443 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -4.721142e-02
# TIMESTEP 2489 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -5.639551e-02
# TIMESTEP 2535 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -5.609233e-02
# TIMESTEP 2581 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -7.021773e-02
# TIMESTEP 2627 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -7.509330e-02
# TIMESTEP 2673 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -7.274055e-02
# TIMESTEP 2719 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -8.051538e-02
# TIMESTEP 2935 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -8.352547e-02
# TIMESTEP 2981 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -7.027167e-02
# TIMESTEP 3027 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX
/ EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.183128e-01
# TIMESTEP 22879 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.212897e+00
# TIMESTEP 22925 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -4.260850e-01
# TIMESTEP 22971 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.218884e+00
# TIMESTEP 23017 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -3.877606e-01
# TIMESTEP 23063 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.087174e+00
# TIMESTEP 23109 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -4.084781e-01
# TIMESTEP 23155 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.082374e+00
# TIMESTEP 23201 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -3.577892e-01
# TIMESTEP 23247 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.163008e+00
# TIMESTEP 23293 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -3.924222e-01
# TIMESTEP 23339 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.149284e+00
# TIMESTEP 23385 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -4.589925e-01
# TIMESTEP 23431 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.217241e+00
# TIMESTEP 23477 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -4.461926e-01
# TIMESTEP 23523 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.321401e+00
# TIMESTEP 23569 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -5.469199e-01
# TIMESTEP 23615 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.367026e+00
# TIMESTEP 23661 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -6.299910e-01
# TIMESTEP 23707 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.407693e+00
# TIMESTEP 23753 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -5.760272e-01
# TIMESTEP 23799 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.435971e+00
# TIMESTEP 23845 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -6.208921e-01
# TIMESTEP 23891 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -1.431505e+00
# TIMESTEP 23937 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -5.898513e-01
# TIMESTEP 23983 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -1.269301e+00
# TIMESTEP 24029 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -5.189379e-01
# TIMESTEP 24075 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.244690e+00
# TIMESTEP 24121 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -5.358193e-01
# TIMESTEP 24167 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX -1.372169e+00
# TIMESTEP 24213 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -5.650583e-01
# TIMESTEP 24259 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -1.342723e+00
# TIMESTEP 24305 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX -6.590677e-01
# TIMESTEP 24351 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX -1.378310e+00
# TIMESTEP 24397 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX -6.900651e-01
# TIMESTEP 24443 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX -1.525051e+00
# TIMESTEP 24489 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX -7.162218e-01
# TIMESTEP 24535 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX -1.471789e+00
# TIMESTEP 24581 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX -7.703076e-01
# TIMESTEP 24627 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX -1.569425e+00
# TIMESTEP 24673 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX -7.638720e-01
# TIMESTEP 24719 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX -1.486019e+00
# TIMESTEP 24765 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX -6.121112e-01
# ...
# TIMESTEP 463596 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 1 / REWARD 1 / Q_MAX 1.242186e+00
# TIMESTEP 463977 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 1 / REWARD 1 / Q_MAX 1.378326e+00
# TIMESTEP 464359 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 1 / REWARD 1 / Q_MAX 1.549195e+00
# TIMESTEP 464740 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 1 / REWARD 1 / Q_MAX 1.492506e+00
# TIMESTEP 465122 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 1 / REWARD 1 / Q_MAX 1.538392e+00
# TIMESTEP 465503 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 1 / REWARD 1 / Q_MAX 1.319966e+00
# TIMESTEP 465884 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 1 / REWARD 1 / Q_MAX 1.480013e+00
# TIMESTEP 466265 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 1 / REWARD 1 / Q_MAX 1.389971e+00
# TIMESTEP 466646 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 1 / REWARD 1 / Q_MAX 1.451856e+00
# TIMESTEP 467027 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 1 / REWARD 1 / Q_MAX 1.467445e+00
# TIMESTEP 467409 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 1 / REWARD 1 / Q_MAX 1.311151e+00
# TIMESTEP 467790 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 1 / REWARD 1 / Q_MAX 1.368789e+00
# TIMESTEP 468173 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.330690e+00
# TIMESTEP 468470 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 5.382932e-01
# TIMESTEP 468770 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 1 / REWARD 1 / Q_MAX 9.607981e-01
# TIMESTEP 469151 / EPSILON 0.04999999999999416 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 1.387665e+00
# TIMESTEP 469535 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 1 / REWARD 1 / Q_MAX 1.300656e+00
# TIMESTEP 469917 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 1 / REWARD 1 / Q_MAX 1.433070e+00
# TIMESTEP 470215 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 2 / REWARD -1 / Q_MAX 5.318403e-01
# TIMESTEP 470515 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 2 / REWARD 1 / Q_MAX 8.589968e-01
# TIMESTEP 470898 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 2 / REWARD 1 / Q_MAX 1.540502e+00
# TIMESTEP 471279 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 2 / REWARD 1 / Q_MAX 1.554021e+00
# TIMESTEP 471408 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 3 / REWARD -1 / Q_MAX -4.420664e-01
# TIMESTEP 471537 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 3 / REWARD 1 / Q_MAX 1.266565e+00
# TIMESTEP 471918 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 3 / REWARD 1 / Q_MAX 1.351193e+00
# TIMESTEP 472299 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 3 / REWARD 1 / Q_MAX 1.486067e+00
# TIMESTEP 472682 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 3 / REWARD 1 / Q_MAX 1.419870e+00
# TIMESTEP 473066 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 3 / REWARD 1 / Q_MAX 1.198393e+00
# TIMESTEP 473447 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 3 / REWARD 1 / Q_MAX 1.314899e+00
# TIMESTEP 473828 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 3 / REWARD 1 / Q_MAX 1.353709e+00
# TIMESTEP 474209 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 3 / REWARD 1 / Q_MAX 1.425118e+00
# TIMESTEP 474591 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 3 / REWARD 1 / Q_MAX 1.377630e+00
# TIMESTEP 474972 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 3 / REWARD 1 / Q_MAX 1.408025e+00
# TIMESTEP 475355 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 3 / REWARD 1 / Q_MAX 1.456839e+00
# TIMESTEP 475652 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 4 / REWARD -1 / Q_MAX 5.281894e-01
# TIMESTEP 475698 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 5 / REWARD -1 / Q_MAX -4.097542e-01
# TIMESTEP 475827 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 5 / REWARD 1 / Q_MAX 1.435307e+00
# TIMESTEP 476210 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.516024e+00
# TIMESTEP 476591 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 1.421878e+00
# TIMESTEP 476974 / EPSILON 0.04999999999999416 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 1.587473e+00
# TIMESTEP 477356 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 0 / REWARD 1 / Q_MAX 1.468699e+00
# TIMESTEP 477737 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 0 / REWARD 1 / Q_MAX 1.345427e+00
# TIMESTEP 478118 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 0 / REWARD 1 / Q_MAX 1.240121e+00
# TIMESTEP 478415 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 1 / REWARD -1 / Q_MAX 4.067865e-01
# TIMESTEP 478715 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 1 / REWARD 1 / Q_MAX 7.326283e-01
# TIMESTEP 479098 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 1 / REWARD 1 / Q_MAX 1.520761e+00
# TIMESTEP 479479 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 1 / REWARD 1 / Q_MAX 1.233335e+00
# TIMESTEP 479862 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 1 / REWARD 1 / Q_MAX 1.543369e+00
# TIMESTEP 480243 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 1 / REWARD 1 / Q_MAX 1.370172e+00
# TIMESTEP 480624 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 1 / REWARD 1 / Q_MAX 1.339934e+00
# TIMESTEP 480922 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 2 / REWARD -1 / Q_MAX -5.100093e-01
# TIMESTEP 481136 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 3 / REWARD -1 / Q_MAX 6.528595e-01
# TIMESTEP 481265 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 3 / REWARD 1 / Q_MAX 1.537645e+00
# TIMESTEP 481646 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 3 / REWARD 1 / Q_MAX 1.316159e+00
# TIMESTEP 482029 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 3 / REWARD 1 / Q_MAX 1.549056e+00
# TIMESTEP 482413 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 3 / REWARD 1 / Q_MAX 1.119354e+00
# TIMESTEP 482794 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 3 / REWARD 1 / Q_MAX 1.322942e+00
# TIMESTEP 483175 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 3 / REWARD 1 / Q_MAX 1.310740e+00
# TIMESTEP 483556 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 3 / REWARD 1 / Q_MAX 1.440308e+00
# TIMESTEP 483939 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 3 / REWARD 1 / Q_MAX 1.452405e+00
# TIMESTEP 484236 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 4 / REWARD -1 / Q_MAX -5.866739e-01
# TIMESTEP 484449 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 5 / REWARD -1 / Q_MAX 2.577910e-01
# TIMESTEP 484578 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.370101e+00
# TIMESTEP 484961 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 1.474514e+00
# TIMESTEP 485344 / EPSILON 0.04999999999999416 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 1.470592e+00
# TIMESTEP 485726 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 0 / REWARD 1 / Q_MAX 1.375466e+00
# TIMESTEP 486024 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 1 / REWARD -1 / Q_MAX 4.954871e-01
# TIMESTEP 486070 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX -3.284156e-02
# TIMESTEP 486199 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 1.405696e+00
# TIMESTEP 486328 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 3 / REWARD -1 / Q_MAX -3.598682e-01
# TIMESTEP 486457 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 3 / REWARD 1 / Q_MAX 1.302356e+00
# TIMESTEP 486840 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 3 / REWARD 1 / Q_MAX 1.518745e+00
# TIMESTEP 487137 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 4 / REWARD -1 / Q_MAX 3.766243e-01
# TIMESTEP 487183 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 5 / REWARD -1 / Q_MAX -1.506663e-01
# TIMESTEP 487229 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 6 / REWARD -1 / Q_MAX -6.175013e-01
# TIMESTEP 487442 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 7 / REWARD -1 / Q_MAX 7.447886e-01
# TIMESTEP 487571 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 7 / REWARD 1 / Q_MAX 1.425198e+00
# TIMESTEP 487700 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 8 / REWARD -1 / Q_MAX -5.214808e-01
# TIMESTEP 487832 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 8 / REWARD 1 / Q_MAX 1.069655e+00
# TIMESTEP 488215 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 8 / REWARD 1 / Q_MAX 1.503901e+00
# TIMESTEP 488596 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 8 / REWARD 1 / Q_MAX 1.476559e+00
# TIMESTEP 488978 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 8 / REWARD 1 / Q_MAX 1.366789e+00
# TIMESTEP 489359 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 8 / REWARD 1 / Q_MAX 1.335527e+00
# TIMESTEP 489742 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 8 / REWARD 1 / Q_MAX 1.493922e+00
# TIMESTEP 490123 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 8 / REWARD 1 / Q_MAX 1.479270e+00
# TIMESTEP 490504 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 8 / REWARD 1 / Q_MAX 1.265034e+00
# TIMESTEP 490885 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 8 / REWARD 1 / Q_MAX 1.356138e+00
# TIMESTEP 491266 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 8 / REWARD 1 / Q_MAX 1.309699e+00
# TIMESTEP 491647 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 8 / REWARD 1 / Q_MAX 1.294094e+00
# TIMESTEP 492028 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 8 / REWARD 1 / Q_MAX 1.362323e+00
# TIMESTEP 492325 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 9 / REWARD -1 / Q_MAX 3.592171e-01
# TIMESTEP 492371 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 10 / REWARD -1 / Q_MAX -4.493910e-01
# TIMESTEP 492500 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.537000e+00
# TIMESTEP 492629 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 5.404459e-01
# TIMESTEP 492675 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 3.552048e-02
# TIMESTEP 492889 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 4.014200e-01
# TIMESTEP 493018 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 3 / REWARD 1 / Q_MAX 1.445500e+00
# TIMESTEP 493315 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 4 / REWARD -1 / Q_MAX 3.248990e-01
# TIMESTEP 493615 / EPSILON 0.04999999999999416 / bar1_score 2 / bar2_score 4 / REWARD 1 / Q_MAX 9.137576e-01
# TIMESTEP 493996 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 4 / REWARD 1 / Q_MAX 1.383000e+00
# TIMESTEP 494380 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 4 / REWARD 1 / Q_MAX 9.462717e-01
# TIMESTEP 494762 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 4 / REWARD 1 / Q_MAX 1.314120e+00
# TIMESTEP 495145 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 4 / REWARD 1 / Q_MAX 1.345165e+00
# TIMESTEP 495443 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 5 / REWARD -1 / Q_MAX 4.636294e-01
# TIMESTEP 495657 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 6 / REWARD -1 / Q_MAX 1.521635e-01
# TIMESTEP 495786 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 6 / REWARD 1 / Q_MAX 1.274979e+00
# TIMESTEP 496168 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 6 / REWARD 1 / Q_MAX 1.196719e+00
# TIMESTEP 496551 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 6 / REWARD 1 / Q_MAX 1.377755e+00
# TIMESTEP 496932 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 6 / REWARD 1 / Q_MAX 1.435277e+00
# TIMESTEP 497313 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 6 / REWARD 1 / Q_MAX 1.288986e+00
# TIMESTEP 497694 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 6 / REWARD 1 / Q_MAX 1.259082e+00
# TIMESTEP 498075 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 6 / REWARD 1 / Q_MAX 1.334577e+00
# TIMESTEP 498204 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 7 / REWARD -1 / Q_MAX -4.124115e-01
# TIMESTEP 498333 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 7 / REWARD 1 / Q_MAX 1.434908e+00
# TIMESTEP 498714 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 7 / REWARD 1 / Q_MAX 1.279313e+00
# TIMESTEP 499097 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 7 / REWARD 1 / Q_MAX 1.415661e+00
# TIMESTEP 499480 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 7 / REWARD 1 / Q_MAX 1.396637e+00
# TIMESTEP 499863 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 7 / REWARD 1 / Q_MAX 1.396713e+00
# TIMESTEP 500245 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 7 / REWARD 1 / Q_MAX 1.483099e+00
# TIMESTEP 500628 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.372565e+00
# TIMESTEP 501012 / EPSILON 0.04999999999999416 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 1.167824e+00
# TIMESTEP 501393 / EPSILON 0.04999999999999416 / bar1_score 2 / bar2_score 0 / REWARD 1 / Q_MAX 1.292213e+00
# TIMESTEP 501774 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 0 / REWARD 1 / Q_MAX 1.385598e+00
# TIMESTEP 502072 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 1 / REWARD -1 / Q_MAX 3.013963e-01
# TIMESTEP 502118 / EPSILON 0.04999999999999416 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX -4.393823e-01
# TIMESTEP 502247 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 2 / REWARD 1 / Q_MAX 1.214248e+00
# TIMESTEP 502545 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 3 / REWARD -1 / Q_MAX 2.312270e-01
# TIMESTEP 502591 / EPSILON 0.04999999999999416 / bar1_score 4 / bar2_score 4 / REWARD -1 / Q_MAX -4.116841e-01
# TIMESTEP 502720 / EPSILON 0.04999999999999416 / bar1_score 5 / bar2_score 4 / REWARD 1 / Q_MAX 1.374442e+00
# TIMESTEP 503102 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 4 / REWARD 1 / Q_MAX 1.342094e+00
# TIMESTEP 503399 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 5 / REWARD -1 / Q_MAX 1.917141e-01
# TIMESTEP 503445 / EPSILON 0.04999999999999416 / bar1_score 6 / bar2_score 6 / REWARD -1 / Q_MAX -7.854774e-01
# TIMESTEP 503574 / EPSILON 0.04999999999999416 / bar1_score 7 / bar2_score 6 / REWARD 1 / Q_MAX 1.230303e+00
# TIMESTEP 503955 / EPSILON 0.04999999999999416 / bar1_score 8 / bar2_score 6 / REWARD 1 / Q_MAX 1.270501e+00
# TIMESTEP 504336 / EPSILON 0.04999999999999416 / bar1_score 9 / bar2_score 6 / REWARD 1 / Q_MAX 1.372824e+00
# TIMESTEP 504717 / EPSILON 0.04999999999999416 / bar1_score 10 / bar2_score 6 / REWARD 1 / Q_MAX 1.385363e+00
# TIMESTEP 505098 / EPSILON 0.04999999999999416 / bar1_score 11 / bar2_score 6 / REWARD 1 / Q_MAX 1.362294e+00
# TIMESTEP 505481 / EPSILON 0.04999999999999416 / bar1_score 12 / bar2_score 6 / REWARD 1 / Q_MAX 1.388336e+00
# TIMESTEP 505862 / EPSILON 0.04999999999999416 / bar1_score 13 / bar2_score 6 / REWARD 1 / Q_MAX 1.307472e+00
# TIMESTEP 506243 / EPSILON 0.04999999999999416 / bar1_score 14 / bar2_score 6 / REWARD 1 / Q_MAX 1.349641e+00
# TIMESTEP 506626 / EPSILON 0.04999999999999416 / bar1_score 15 / bar2_score 6 / REWARD 1 / Q_MAX 1.230576e+00
# TIMESTEP 507007 / EPSILON 0.04999999999999416 / bar1_score 16 / bar2_score 6 / REWARD 1 / Q_MAX 1.276235e+00
# TIMESTEP 507388 / EPSILON 0.04999999999999416 / bar1_score 17 / bar2_score 6 / REWARD 1 / Q_MAX 1.363732e+00
# TIMESTEP 507769 / EPSILON 0.04999999999999416 / bar1_score 18 / bar2_score 6 / REWARD 1 / Q_MAX 1.368508e+00
# TIMESTEP 508150 / EPSILON 0.04999999999999416 / bar1_score 19 / bar2_score 6 / REWARD 1 / Q_MAX 1.471980e+00
# TIMESTEP 508532 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 1.326517e+00
# TIMESTEP 508829 / EPSILON 0.04999999999999416 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 2.615124e-01

# %%
32265/60
# Out:
# 537.75

# %%
print("Game_Ends_in Time:",int(time.time() - tick))
